# %% [markdown]
# ## Step 1 Construct features using NLTK

# %%
import nltk
from nltk.corpus import stopwords
import string
import json

# %matplotlib inline 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from __future__ import division

randomState = np.random.seed(2)


# Import works.json: title, words, sentences of 38 pieces
with open('works.json', 'r') as f:
    try:
        works = json.load(f)
    # if the file is empty the ValueError will be thrown
    except ValueError:
        works = {}

# %%
from nltk import FreqDist

def getFreqDist(words):
    nltk_text = nltk.Text(words)
    
    return FreqDist(nltk_text)

# %%
def getCountFrequency(words, freq):
    nltk_text = nltk.Text(words)
    freq_dist = FreqDist(nltk_text)
    
    count = 0
    for key,value in freq_dist.items():
        if value == freq:
            count += 1
    
    return count    

def getHapaxLegomena(words):
    return getCountFrequency(words, 1)

# %%
def getDisLegomena(words):
    return getCountFrequency(words, 2)

# %%
def getNumberUniqueWords(words):
    return len(getFreqDist(words))

# %%
def getWordLengthDistribution(words):
    result = FreqDist()
    for w in words:        
        result[len(w)] += 1
    
    return result

def printFreqDist(freq_dist):
    for key,value in freq_dist.items():
        print (key,value)

# %%
def getSentenceLengthDistribution(sents):
    result = FreqDist()
    for s in sents:        
        result[len(s)] += 1
    
    return result

# %%
def getAverageSentenceLength(words_all, sents):
    
    return len(words_all)/len(sents)

# %%
def getPronounDistribution(sents):
    result = FreqDist()
    pronouns = ['I', 'you', 'he', 'she', 'it', 'we', 'you', 'they', 'thou', 'ye']
    for s in sents:
        count = 0
        for p in pronouns:
            count += s.count(p)
        result[count] += 1
    
    return result

# %%
def getNumberOfPronoun(words):
    pronouns = ['I', 'you', 'he', 'she', 'it', 'we', 'you', 'they', 'thou', 'ye']
    count = 0
         
    for p in pronouns:
        count += words.count(p)
    
    return count

# %%
def getConjunctionDistribution(sents):
    result = FreqDist()
    conjunctions = ['for', 'and', 'nor', 'but', 'or', 'yet', 'so', 'after', 'although', 'as', 'because', 'before', 'if',
                'once', 'since', 'though', 'unless', 'until', 'when', 'where', 'while', 'whether', 'either', 'neither',
                'as', 'than', 'even', 'then', 'lest', 'rather', 'which', 'who', 'why', 'that', 'till']
    for s in sents:
        count = 0
        for c in conjunctions:
            count += s.count(c)
        result[count] += 1
    
    return result

# %%
def getNumberOfConjunction(words):
    count = 0
    conjunctions = ['for', 'and', 'nor', 'but', 'or', 'yet', 'so', 'after', 'although', 'as', 'because', 'before', 'if',
                'once', 'since', 'though', 'unless', 'until', 'when', 'where', 'while', 'whether', 'either', 'neither',
                'as', 'than', 'even', 'then', 'lest', 'rather', 'which', 'who', 'why', 'that', 'till']

    for c in conjunctions:
        count += words.count(c)
    
    return count

# %%
def getNumberOfComma(text):
    return text.count(",")

def getNumberOfDots(text):
    return text.count(".")

def getNumberOfStringList(words, string_list):
    count = 0
    
    for c in string_list:
        count += words.count(c)
    
    return count

def getNumberOfThe(words):
    string_list = ['a', 'an', 'the']
    
    return getNumberOfStringList(words, string_list)

def getNumberOfIn(words):
    string_list = ['in', 'on', 'to', 'of']
    
    return getNumberOfStringList(words, string_list)

def getNumberOfIs(words):
    string_list = ['is', 'are', 'was', 'were']
    
    return getNumberOfStringList(words, string_list)

# %%
# Create a feature table for all acts
# Currently only has some simple features

featureTable = {}

featureTable = {'act': [], 'filename': [], 'HapaxLegomena': [], 'DisLegomena': [], 
                'numberUniqueWords': [], 'averageSentenceLength': [], 'numberOfSentences': [],
                'numberOfPronoun': [], 'numberOfConjunction': [], 'numberOfComma': [], 'numberOfDots': [],
                'numberOfThe': [], 'numberOfIn': [], 'numberOfIs': []}


for act, content in works.items():
    words_nonStemmed = content['words_nonStemmed']
    words_all = content['words_all']
    sentences = content['sentences']
    # Normalize by number of all words
    normalizer = len(words_all)
    featureTable['act'].append(act)
    featureTable['filename'].append(content['filename'])
    featureTable['HapaxLegomena'].append(getHapaxLegomena(words_nonStemmed)/normalizer)
    featureTable['DisLegomena'].append(getDisLegomena(words_nonStemmed)/normalizer)
    featureTable['numberUniqueWords'].append(getNumberUniqueWords(words_nonStemmed)/normalizer)
    featureTable['averageSentenceLength'].append(getAverageSentenceLength(words_all, sentences))
    featureTable['numberOfSentences'].append(len(sentences))
    featureTable['numberOfPronoun'].append(getNumberOfPronoun(words_all)/normalizer)
    featureTable['numberOfConjunction'].append(getNumberOfConjunction(words_all)/normalizer)
    featureTable['numberOfComma'].append(getNumberOfComma(content['text'])/normalizer)
    featureTable['numberOfDots'].append(getNumberOfDots(content['text'])/normalizer)
    featureTable['numberOfThe'].append(getNumberOfThe(words_all)/normalizer)
    featureTable['numberOfIn'].append(getNumberOfIn(words_all)/normalizer)
    featureTable['numberOfIs'].append(getNumberOfIs(words_all)/normalizer)

print(len(featureTable['act']))


df = pd.DataFrame(featureTable)
df.set_index(['act'], inplace=True)
df.head()
# Out:
# 223
#                                                   DisLegomena  HapaxLegomena  \
# act
# THE TRAGEDY OF KING LEAR ACT1606                     0.061538       0.253846
# SECOND PART OF KING HENRY IV ACT IV.                 0.023314       0.105600
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.        0.022165       0.091560
# THE TRAGEDY OF CORIOLANUS ACT I.                     0.023547       0.100047
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III     0.025875       0.101194
#
#                                                   averageSentenceLength  \
# act
# THE TRAGEDY OF KING LEAR ACT1606                               5.652174
# SECOND PART OF KING HENRY IV ACT IV.                          15.190972
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.                  6.973841
# THE TRAGEDY OF CORIOLANUS ACT I.                              11.566396
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III              10.860068
#
#                                                  filename  numberOfComma  \
# act
# THE TRAGEDY OF KING LEAR ACT1606                   18.txt       0.100000
# SECOND PART OF KING HENRY IV ACT IV.               10.txt       0.078286
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.      26.txt       0.071952
# THE TRAGEDY OF CORIOLANUS ACT I.                    6.txt       0.067010
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III    8.txt       0.071234
#
#                                                   numberOfConjunction  \
# act
# THE TRAGEDY OF KING LEAR ACT1606                             0.000000
# SECOND PART OF KING HENRY IV ACT IV.                         0.089371
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.                0.072464
# THE TRAGEDY OF CORIOLANUS ACT I.                             0.081186
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III             0.084433
#
#                                                   numberOfDots  numberOfIn  \
# act
# THE TRAGEDY OF KING LEAR ACT1606                      0.176923    0.130769
# SECOND PART OF KING HENRY IV ACT IV.                  0.054514    0.053486
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.         0.100256    0.030350
# THE TRAGEDY OF CORIOLANUS ACT I.                      0.070173    0.041003
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III      0.073539    0.048502
#
#                                                   numberOfIs  numberOfPronoun  \
# act
# THE TRAGEDY OF KING LEAR ACT1606                    0.000000         0.000000
# SECOND PART OF KING HENRY IV ACT IV.                0.014743         0.049029
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.       0.017391         0.059165
# THE TRAGEDY OF CORIOLANUS ACT I.                    0.017690         0.065722
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III    0.015818         0.055416
#
#                                                   numberOfSentences  \
# act
# THE TRAGEDY OF KING LEAR ACT1606                                 23
# SECOND PART OF KING HENRY IV ACT IV.                            576
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.                   841
# THE TRAGEDY OF CORIOLANUS ACT I.                                738
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III                879
#
#                                                   numberOfThe  \
# act
# THE TRAGEDY OF KING LEAR ACT1606                     0.030769
# SECOND PART OF KING HENRY IV ACT IV.                 0.042514
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.        0.028815
# THE TRAGEDY OF CORIOLANUS ACT I.                     0.041003
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III     0.042636
#
#                                                   numberUniqueWords
# act
# THE TRAGEDY OF KING LEAR ACT1606                           0.353846
# SECOND PART OF KING HENRY IV ACT IV.                       0.168914
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.              0.145610
# THE TRAGEDY OF CORIOLANUS ACT I.                           0.160497
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III           0.161638

# %%
# Filter out wierd acts, e.g. the beginning of a play

# df = df[df['averageSentenceLength'] < 30]

df.drop(["A MIDSUMMER NIGHT'S DREAM ACT1596","ALLS WELL THAT ENDS WELL ACT1603", "AS YOU LIKE IT ACT1601", 
              "CYMBELINE ACT1609","KING HENRY THE EIGHTH ACT1611","KING JOHN ACT1597","KING RICHARD III ACT1593",
             "KING RICHARD THE SECOND ACT1596", "LOVE'S LABOUR'S LOST ACT1595", "MEASURE FOR MEASURE ACT1605",
             "MUCH ADO ABOUT NOTHING ACT1599", "SECOND PART OF KING HENRY IV ACT1598", "THE COMEDY OF ERRORS ACT1593",
             "THE FIRST PART OF HENRY THE SIXTH ACT1592", "THE FIRST PART OF KING HENRY THE FOURTH ACT1598",
             "THE HISTORY OF TROILUS AND CRESSIDA ACT1602", "THE LIFE OF KING HENRY THE FIFTH ACT1599",
             "THE LIFE OF TIMON OF ATHENS ACT1608", "THE MERCHANT OF VENICE ACT1597", "THE MERRY WIVES OF WINDSOR ACT1601",
             "THE SECOND PART OF KING HENRY THE SIXTH ACT1591", "THE TAMING OF THE SHREW ACT1594", "THE TEMPEST ACT1612",
             "THE TRAGEDY OF ANTONY AND CLEOPATRA ACT1607", "THE TRAGEDY OF CORIOLANUS ACT1608",
              "THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT1604","THE TRAGEDY OF JULIUS CAESAR ACT1599",
             "THE TRAGEDY OF KING LEAR ACT1606", "THE TRAGEDY OF MACBETH ACT1606", 
              "THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT1605", "THE TRAGEDY OF ROMEO AND JULIET ACT1595",
             "THE TRAGEDY OF TITUS ANDRONICUS ACT1594", "THE TWO GENTLEMEN OF VERONA ACT1595", "THE WINTER'S TALE ACT1611",
             "TWELFTH NIGHT; OR, WHAT YOU WILL ACT1602", "THE THIRD PART OF KING HENRY THE SIXTH ACT1591"], inplace = True)

# df_2 and df_3 to be REMOVED
df_2 = df[['numberUniqueWords', 'averageSentenceLength']]
df_3 = df[['numberUniqueWords', 'averageSentenceLength', 'numberOfPronoun']]
df = df[['HapaxLegomena', 'DisLegomena', 'numberUniqueWords', 
        'averageSentenceLength', 'numberOfPronoun', 'numberOfConjunction', 'numberOfComma', 'numberOfDots',
                'numberOfThe', 'numberOfIn', 'numberOfIs']]

# %%
pd.scatter_matrix(df, alpha=0.2, figsize=(16, 16), diagonal='kde')
plt.show()

# %% [markdown]
# ## Step 2 Construct n-grams using sklearn

# %%
title = []
text = []

for act in df.index:
    content = works[act]
    title.append(act)
    text.append(content['text'])

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from __future__ import print_function

from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer
from sklearn import metrics

from sklearn.cluster import KMeans, MiniBatchKMeans, AffinityPropagation, AgglomerativeClustering, MeanShift, SpectralClustering, DBSCAN, Birch 
import numpy as np

# %%
# excluding stop words, n-grams is an input
def getTfidf(ngram_range):
    count_vect = CountVectorizer(ngram_range=ngram_range, stop_words='english')
    X_counts = count_vect.fit_transform(text)

    tfidf_transformer = TfidfTransformer(use_idf=True)
    X_tfidf = tfidf_transformer.fit_transform(X_counts)
    return X_tfidf

# %%
def getSVD(X_tfidf, n_components):
    
    svd = TruncatedSVD(n_components = n_components, random_state = randomState)
    lsa = make_pipeline(svd, Normalizer(copy=False))
    X = lsa.fit_transform(X_tfidf)

    explained_variance = svd.explained_variance_ratio_.sum()
    print("Explained variance of the SVD step: {}%".format(
        int(explained_variance * 100)))
    
    return X

# %%
# Features from n-grams, use fewer components
X_tfidf = getTfidf(ngram_range = (2,4))
X = getSVD(X_tfidf, n_components = 6)
df_ngrams = pd.DataFrame(data=X, index = title, 
                         columns=['n-gram 1st component', 'n-gram 2nd compoent', 'n-gram 3rd', 'n-gram 4th', 'n-gram 5th', 'n-gram 6th',])
df_ngrams.head()
# Out:
# Explained variance of the SVD step: 4%
#                                                   n-gram 1st component  \
# SECOND PART OF KING HENRY IV ACT IV.                          0.364829
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.                 0.002391
# THE TRAGEDY OF CORIOLANUS ACT I.                              0.620438
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III             -0.121937
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.                -0.020084
#
#                                                   n-gram 2nd compoent  \
# SECOND PART OF KING HENRY IV ACT IV.                         0.802141
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.                0.208937
# THE TRAGEDY OF CORIOLANUS ACT I.                            -0.005898
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III             0.113590
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.                0.296629
#
#                                                   n-gram 3rd  n-gram 4th  \
# SECOND PART OF KING HENRY IV ACT IV.               -0.053422    0.364815
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.      -0.139848    0.270982
# THE TRAGEDY OF CORIOLANUS ACT I.                   -0.062116    0.178548
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III   -0.385463   -0.268549
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.       0.008910   -0.297216
#
#                                                   n-gram 5th  n-gram 6th
# SECOND PART OF KING HENRY IV ACT IV.               -0.275615   -0.107525
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.       0.711964    0.597041
# THE TRAGEDY OF CORIOLANUS ACT I.                   -0.338052    0.681912
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III    0.017314    0.866735
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.      -0.863695    0.277889

# %% [markdown]
# ## Step 3 Combine n-grams and other features

# %%
# Merge all features
df_all = df.join(df_ngrams)
df_all.head()
# Out:
#                                                   HapaxLegomena  DisLegomena  \
# act
# SECOND PART OF KING HENRY IV ACT IV.                   0.105600     0.023314
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.          0.091560     0.022165
# THE TRAGEDY OF CORIOLANUS ACT I.                       0.100047     0.023547
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III       0.101194     0.025875
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.          0.111672     0.026061
#
#                                                   numberUniqueWords  \
# act
# SECOND PART OF KING HENRY IV ACT IV.                       0.168914
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.              0.145610
# THE TRAGEDY OF CORIOLANUS ACT I.                           0.160497
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III           0.161638
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.              0.175844
#
#                                                   averageSentenceLength  \
# act
# SECOND PART OF KING HENRY IV ACT IV.                          15.190972
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.                  6.973841
# THE TRAGEDY OF CORIOLANUS ACT I.                              11.566396
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III              10.860068
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.                 12.200000
#
#                                                   numberOfPronoun  \
# act
# SECOND PART OF KING HENRY IV ACT IV.                     0.049029
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.            0.059165
# THE TRAGEDY OF CORIOLANUS ACT I.                         0.065722
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III         0.055416
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.            0.053804
#
#                                                   numberOfConjunction  \
# act
# SECOND PART OF KING HENRY IV ACT IV.                         0.089371
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.                0.072464
# THE TRAGEDY OF CORIOLANUS ACT I.                             0.081186
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III             0.084433
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.                0.089393
#
#                                                   numberOfComma  numberOfDots  \
# act
# SECOND PART OF KING HENRY IV ACT IV.                   0.078286      0.054514
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.          0.071952      0.100256
# THE TRAGEDY OF CORIOLANUS ACT I.                       0.067010      0.070173
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III       0.071234      0.073539
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.          0.074961      0.067255
#
#                                                   numberOfThe  numberOfIn  \
# act
# SECOND PART OF KING HENRY IV ACT IV.                 0.042514    0.053486
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.        0.028815    0.030350
# THE TRAGEDY OF CORIOLANUS ACT I.                     0.041003    0.041003
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III     0.042636    0.048502
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.        0.041334    0.053944
#
#                                                   numberOfIs  \
# act
# SECOND PART OF KING HENRY IV ACT IV.                0.014743
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.       0.017391
# THE TRAGEDY OF CORIOLANUS ACT I.                    0.017690
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III    0.015818
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.       0.017234
#
#                                                   n-gram 1st component  \
# act
# SECOND PART OF KING HENRY IV ACT IV.                          0.364829
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.                 0.002391
# THE TRAGEDY OF CORIOLANUS ACT I.                              0.620438
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III             -0.121937
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.                -0.020084
#
#                                                   n-gram 2nd compoent  \
# act
# SECOND PART OF KING HENRY IV ACT IV.                         0.802141
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.                0.208937
# THE TRAGEDY OF CORIOLANUS ACT I.                            -0.005898
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III             0.113590
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.                0.296629
#
#                                                   n-gram 3rd  n-gram 4th  \
# act
# SECOND PART OF KING HENRY IV ACT IV.               -0.053422    0.364815
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.      -0.139848    0.270982
# THE TRAGEDY OF CORIOLANUS ACT I.                   -0.062116    0.178548
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III   -0.385463   -0.268549
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.       0.008910   -0.297216
#
#                                                   n-gram 5th  n-gram 6th
# act
# SECOND PART OF KING HENRY IV ACT IV.               -0.275615   -0.107525
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V.       0.711964    0.597041
# THE TRAGEDY OF CORIOLANUS ACT I.                   -0.338052    0.681912
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III    0.017314    0.866735
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.      -0.863695    0.277889

# %% [markdown]
# ## Step 4 Clustering

# %%
def getLabels(X, n_clusters = 8, method = 'KMeans'):
    
    if method == 'KMeans':
        cluster = KMeans(n_clusters=n_clusters, init='k-means++', max_iter=500, 
                         n_init=5, random_state = randomState)   
    elif method == 'AffinityPropagation':
        cluster = AffinityPropagation(max_iter=1000)
    elif method == 'AgglomerativeClustering':
        cluster = AgglomerativeClustering(n_clusters=n_clusters)
    elif method == 'Birch':
        cluster = Birch()
    elif method == 'DBSCAN':
        cluster = DBSCAN(random_state = randomState, eps=0.1, min_samples=3)
    elif method == 'SpectralClustering':
        cluster = SpectralClustering(n_clusters=n_clusters)
    elif method == 'MeanShift':
        cluster = MeanShift()
        

    return cluster.fit_predict(X)
        

def printClusters(labels):
    for i in set(labels):
        index = np.squeeze(np.argwhere(labels == i)).tolist()
        print(index)
    
        print(np.array(title)[index])
        print('\n')
        
def print2D(X, x_label, y_label, title, labels):
    plt.figure(figsize = (9,7))
    plt.scatter(X[:,0], X[:,1], c=labels, marker='+', s=100, linewidths=2)
    plt.ylabel(y_label, fontsize=14, fontweight='bold')
    plt.xlabel(x_label, fontsize=14, fontweight='bold')
    plt.title(title, fontsize=14, fontweight='bold')
    
    ax = plt.gca()
    for i in range(len(labels)):
        if labels.tolist().count(labels[i]) <= 3:
            ax.annotate(df_all.index[i], xy=X[i,:], fontweight='bold')
    
    xmin = min(X[:,0])
    xmax = max(X[:,0])
    ymin = min(X[:,1])
    ymax = max(X[:,1])
    
    xrange = xmax - xmin
    yrange = ymax - ymin
    
    xmin = xmin - xrange/10
    xmax = xmax + xrange/10
    
    ymin = ymin - yrange/10
    ymax = ymax + yrange/10
    
    plt.xlim([xmin, xmax])
    plt.ylim([ymin, ymax])
    plt.show()

# %%
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn import metrics
from sklearn.manifold import MDS

def clusterDocuments(X, scaled = False, PCA_X = False, n_clusters = 8, 
                     method = 'KMeans', visualize = 'PCA', verbose = True):
        
    
    if scaled:
        X = preprocessing.scale(X)
        
    if PCA_X:
        X = PCA().fit_transform(X)
        
    if PCA_X:
        X_2D_PCA = X[:, 0:2]
    else: 
        X_2D_PCA = PCA(n_components=2).fit_transform(X)
        X_2D_MDS = MDS(n_components=2).fit_transform(X)
        
    labels = getLabels(X, n_clusters, method)
        
    if visualize == 'PCA':
        print2D(X_2D_PCA, 'PCA 1st component', 'PCA 2nd component', method, labels)
    elif visualize == 'MDS':
        print2D(X_2D_MDS, 'MDS 1st component', 'MDS 2nd component', method, labels)
        
    
    print('Number of clusters: ', len(set(labels)))
    print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(X, labels, random_state=randomState))
    
    if verbose:
        printClusters(labels)

def visualizeCovariance(X, scaled = False):
    if scaled:
        X = preprocessing.scale(X)
        title = 'Standardized'
    else:
        title = 'Non-Standardized'
    
    pca = PCA(n_components=None)
    pca.fit(X)
    
    covariance = pca.get_covariance()
    
    
    width = 0.5
    ind = np.arange(len(pca.explained_variance_ratio_))

    plt.figure()
    ax = plt.gca()
    ax.bar(ind, pca.explained_variance_ratio_, width, color='gray')
    plt.ylabel('Explained Variance Ratio')
    plt.xlabel('Components')
    plt.title(title, fontweight='bold')
    plt.show()
    
    fig, ax = plt.subplots()
    heatmap = ax.pcolor(covariance, cmap=plt.cm.Blues, alpha=0.8)
    # Format
    fig = plt.gcf()
    fig.set_size_inches(8, 8)
    # turn off the frame
    ax.set_frame_on(False)
    # put the major ticks at the middle of each cell
    ax.set_yticks(np.arange(covariance.shape[0]) + 0.5, minor=False)
    ax.set_xticks(np.arange(covariance.shape[1]) + 0.5, minor=False)
    # want a more natural, table-like display
    ax.invert_yaxis()
    ax.xaxis.tick_top()
    # Set the labels
    # label source:https://en.wikipedia.org/wiki/Basketball_statistics
    labels = df_all.columns
    # note I could have used nba_sort.columns but made "labels" instead
    ax.set_xticklabels(labels, minor=False)
    ax.set_yticklabels(labels, minor=False)
    # rotate the
    plt.xticks(rotation=90)
    ax.grid(False)
    # Turn off all the ticks
    ax = plt.gca()
    for t in ax.xaxis.get_major_ticks():
        t.tick1On = False
        t.tick2On = False
    for t in ax.yaxis.get_major_ticks():
        t.tick1On = False
        t.tick2On = False
    plt.title(title, fontweight='bold', y=0)
    plt.show()

# %%
# Cluster only using n-grams as features
# X_tfidf = getTfidf(ngram_range = (2,4))
# X = getSVD(X_tfidf, n_components = 20)
# labels = getLabels(X, n_clusters = 20)
# printClusters(labels)

# %% [markdown]
# > By only using n-grams + td-idf + SVD (20 components), acts are grouped mainly according to their topics. Acts of the same play go to the same cluster.

# %%
X = df_all.values
visualizeCovariance(X, scaled = False)
visualizeCovariance(X, scaled = True)

# %% [markdown]
# ### K-Means

# %%
# Cluster using all features
X = df_all.values
for n in np.arange(2,30,1):
    clusterDocuments(X, scaled=True, PCA_X = True, n_clusters = n, method = 'KMeans', visualize = 'None', verbose = False)
# Out:
# Number of clusters:  2
# Silhouette Coefficient: 0.137
# Number of clusters:  3
# Silhouette Coefficient: 0.135
# Number of clusters:  4
# Silhouette Coefficient: 0.093
# Number of clusters:  5
# Silhouette Coefficient: 0.082
# Number of clusters:  6
# Silhouette Coefficient: 0.086
# Number of clusters:  7
# Silhouette Coefficient: 0.073
# Number of clusters:  8
# Silhouette Coefficient: 0.087
# Number of clusters:  9
# Silhouette Coefficient: 0.082
# Number of clusters:  10
# Silhouette Coefficient: 0.098
# Number of clusters:  11
# Silhouette Coefficient: 0.092
# Number of clusters:  12
# Silhouette Coefficient: 0.108
# Number of clusters:  13
# Silhouette Coefficient: 0.109
# Number of clusters:  14
# Silhouette Coefficient: 0.101
# Number of clusters:  15
# Silhouette Coefficient: 0.100
# Number of clusters:  16
# Silhouette Coefficient: 0.090
# Number of clusters:  17
# Silhouette Coefficient: 0.108
# Number of clusters:  18
# Silhouette Coefficient: 0.112
# Number of clusters:  19
# Silhouette Coefficient: 0.117
# Number of clusters:  20
# Silhouette Coefficient: 0.096
# Number of clusters:  21
# Silhouette Coefficient: 0.109
# Number of clusters:  22
# Silhouette Coefficient: 0.104
# Number of clusters:  23
# Silhouette Coefficient: 0.107
# Number of clusters:  24
# Silhouette Coefficient: 0.115
# Number of clusters:  25
# Silhouette Coefficient: 0.121
# Number of clusters:  26
# Silhouette Coefficient: 0.105
# Number of clusters:  27
# Silhouette Coefficient: 0.113
# Number of clusters:  28
# Silhouette Coefficient: 0.110
# Number of clusters:  29
# Silhouette Coefficient: 0.103
# /Users/bingao/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
X = df_all.values
clusterDocuments(X, scaled = True, PCA_X = True, n_clusters = 20, method = 'KMeans', visualize = 'PCA', verbose = True)
# Out:
# Number of clusters:  20
# Silhouette Coefficient: 0.117
# [7, 12, 40, 45, 64, 68, 93, 101, 102, 112, 119, 140, 142, 145, 175]
# ['SECOND PART OF KING HENRY IV ACT II.' 'THE TRAGEDY OF MACBETH ACT II.'
#  'THE MERRY WIVES OF WINDSOR ACT V. '
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT IV.' 'THE MERCHANT OF VENICE ACT II.'
#  'THE TRAGEDY OF MACBETH ACT IV.' 'SECOND PART OF KING HENRY IV ACT V. '
#  'THE TRAGEDY OF MACBETH ACT V. ' 'THE TRAGEDY OF MACBETH ACT I. '
#  'CYMBELINE ACT IV.' 'ALLS WELL THAT ENDS WELL ACT IV '
#  'THE TRAGEDY OF MACBETH ACT III' "LOVE'S LABOUR'S LOST ACT III"
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT II.'
#  "THE WINTER'S TALE ACT I. "]
#
#
# [10, 18, 87, 90, 128, 144, 173]
# ['ALLS WELL THAT ENDS WELL ACT I. ' "LOVE'S LABOUR'S LOST ACT I. "
#  'THE LIFE OF KING HENRY THE FIFTH ACT IV.'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT II.'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT V. '
#  'THE MERCHANT OF VENICE ACT V. ' 'MUCH ADO ABOUT NOTHING ACT I. ']
#
#
# 60
# THE TWO GENTLEMEN OF VERONA ACT_4|S
#
#
# [14, 33, 34, 49, 81, 99, 116, 132, 139, 153, 172, 180, 186]
# ['THE LIFE OF KING HENRY THE FIFTH ACT I. '
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT III'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT I. '
#  'THE FIRST PART OF HENRY THE SIXTH ACT V. '
#  "A MIDSUMMER NIGHT'S DREAM ACT II."
#  'THE FIRST PART OF HENRY THE SIXTH ACT III'
#  'THE FIRST PART OF HENRY THE SIXTH ACT II.'
#  'KING HENRY THE EIGHTH ACT IV.' 'THE LIFE OF KING HENRY THE FIFTH ACT V. '
#  'THE FIRST PART OF HENRY THE SIXTH ACT IV.'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT V. ' "THE WINTER'S TALE ACT III"
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT V. ']
#
#
# [17, 41, 76, 77, 80, 121, 168, 174, 176, 182, 184]
# ['THE TWO GENTLEMEN OF VERONA ACT II.' "A MIDSUMMER NIGHT'S DREAM ACT V. "
#  'THE TAMING OF THE SHREW ACT III' 'THE TEMPEST ACT V. '
#  "A MIDSUMMER NIGHT'S DREAM ACT III" 'THE TRAGEDY OF JULIUS CAESAR ACT IV.'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT_5|S'
#  'THE TRAGEDY OF KING LEAR ACT V. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT I. '
#  'MUCH ADO ABOUT NOTHING ACT IV.' 'THE TEMPEST ACT II.']
#
#
# [15, 21, 32, 63, 70, 88, 91, 113, 123, 126]
# ['THE TRAGEDY OF JULIUS CAESAR ACT III' "A MIDSUMMER NIGHT'S DREAM ACT IV."
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT_3|S'
#  'THE FIRST PART OF HENRY THE SIXTH ACT I. '
#  'THE TWO GENTLEMEN OF VERONA ACT V. ' 'KING HENRY THE EIGHTH ACT I. '
#  'THE TEMPEST ACT III' 'MEASURE FOR MEASURE ACT V. '
#  'THE TRAGEDY OF ROMEO AND JULIET ACT I. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT_2|S']
#
#
# [124, 129]
# ["A LOVER'S COMPLAINT ACT1609" 'THE SONNETS ACT1609']
#
#
# [1, 27, 43, 72, 82, 95, 104, 122, 137, 154, 165, 177, 183]
# ['THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V. '
#  'THE TRAGEDY OF ROMEO AND JULIET ACT V. '
#  'THE TRAGEDY OF KING LEAR ACT III' 'THE LIFE OF TIMON OF ATHENS ACT III'
#  'THE LIFE OF TIMON OF ATHENS ACT II.' 'THE TRAGEDY OF KING LEAR ACT IV.'
#  "LOVE'S LABOUR'S LOST ACT II."
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT V. '
#  'THE TRAGEDY OF JULIUS CAESAR ACT V. '
#  'THE TRAGEDY OF ROMEO AND JULIET ACT IV.'
#  'THE LIFE OF TIMON OF ATHENS ACT I. ' 'THE TRAGEDY OF KING LEAR ACT II.'
#  'THE TWO GENTLEMEN OF VERONA ACT I. ']
#
#
# [0, 2, 4, 8, 23, 36, 62, 66, 73, 74, 85, 96, 97, 100, 105, 134, 136, 147, 159, 163, 167, 169]
# ['SECOND PART OF KING HENRY IV ACT IV.' 'THE TRAGEDY OF CORIOLANUS ACT I. '
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I. '
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.'
#  'THE LIFE OF KING HENRY THE FIFTH ACT III'
#  'THE TRAGEDY OF CORIOLANUS ACT V. ' 'ALLS WELL THAT ENDS WELL ACT IV.'
#  'THE MERCHANT OF VENICE ACT IV.' "LOVE'S LABOUR'S LOST ACT IV."
#  'THE TWO GENTLEMEN OF VERONA ACT III' 'THE TRAGEDY OF CORIOLANUS ACT IV.'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT V. '
#  'MUCH ADO ABOUT NOTHING ACT II.' 'THE LIFE OF TIMON OF ATHENS ACT V. '
#  'THE TRAGEDY OF ROMEO AND JULIET ACT II.' 'CYMBELINE ACT III'
#  'CYMBELINE ACT II.' "THE WINTER'S TALE ACT V. " 'CYMBELINE ACT V. '
#  "THE WINTER'S TALE ACT IV." 'THE TRAGEDY OF CORIOLANUS ACT II.'
#  'CYMBELINE ACT I. ']
#
#
# [3, 6, 22, 28, 37, 39, 52, 59, 84, 98, 106, 107, 109, 115, 117, 125, 155, 156, 158, 162, 164, 166, 185]
# ['THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III'
#  'AS YOU LIKE IT ACT IV.' 'THE TAMING OF THE SHREW ACT I. '
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT IV.'
#  'THE TRAGEDY OF JULIUS CAESAR ACT I. ' "LOVE'S LABOUR'S LOST ACT V. "
#  'MEASURE FOR MEASURE ACT III'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT I. '
#  'THE TRAGEDY OF JULIUS CAESAR ACT II.' 'THE TAMING OF THE SHREW ACT V. '
#  'THE TWO GENTLEMEN OF VERONA ACT IV.'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.'
#  'MEASURE FOR MEASURE ACT II.'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT IV.'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT III'
#  'THE TRAGEDY OF CORIOLANUS ACT III' 'AS YOU LIKE IT ACT I. '
#  'MUCH ADO ABOUT NOTHING ACT V. ' 'MUCH ADO ABOUT NOTHING ACT III'
#  'ALLS WELL THAT ENDS WELL ACT V S' 'THE TRAGEDY OF KING LEAR ACT I. '
#  "THE WINTER'S TALE ACT II." 'THE TAMING OF THE SHREW ACT Il.']
#
#
# [5, 20, 24, 29, 57, 61, 65, 75, 110, 127, 135, 138, 149, 151, 170]
# ['KING JOHN ACT III' 'THE SECOND PART OF KING HENRY THE SIXTH ACT IV.'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT IV.'
#  'THE MERCHANT OF VENICE ACT III' 'KING JOHN ACT II.'
#  'KING HENRY THE EIGHTH ACT III' 'AS YOU LIKE IT ACT II.'
#  'MEASURE FOR MEASURE ACT I. '
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT I. ' 'KING JOHN ACT I. '
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT III' 'KING JOHN ACT IV.'
#  'KING JOHN ACT V. ' "A MIDSUMMER NIGHT'S DREAM ACT I. "
#  'THE LIFE OF KING HENRY THE FIFTH ACT II.']
#
#
# [13, 94, 114, 152, 179]
# ['THE MERRY WIVES OF WINDSOR ACT II.'
#  'SECOND PART OF KING HENRY IV ACT III'
#  'THE MERRY WIVES OF WINDSOR ACT III' 'THE MERRY WIVES OF WINDSOR ACT IV.'
#  'THE MERRY WIVES OF WINDSOR ACT I. ']
#
#
# [30, 31, 54, 89, 111, 143, 150, 161]
# ['TWELFTH NIGHT; OR, WHAT YOU WILL ACT V. '
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT III'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT II.'
#  'THE TRAGEDY OF ROMEO AND JULIET ACT III'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT I. '
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT II.'
#  'THE TAMING OF THE SHREW ACT IV.']
#
#
# [9, 11, 35, 42, 69, 131, 146, 157]
# ['KING RICHARD III ACT IV.' 'KING RICHARD THE SECOND ACT V. '
#  'KING RICHARD THE SECOND ACT II.' 'KING RICHARD THE SECOND ACT I. '
#  'KING RICHARD III ACT V. ' 'THE TRAGEDY OF TITUS ANDRONICUS ACT 1. '
#  'KING RICHARD THE SECOND ACT III' 'KING RICHARD THE SECOND ACT IV.']
#
#
# [25, 26, 38, 46, 48, 50, 55, 56, 58, 79, 83, 118, 120, 130, 133, 171]
# ['KING RICHARD III ACT III' 'KING RICHARD III ACT I. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT V. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT II.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT V. '
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT IV.' 'THE TEMPEST ACT I. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT III'
#  'THE LIFE OF TIMON OF ATHENS ACT IV.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT III'
#  'KING RICHARD III ACT II.'
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT I. '
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT II.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT II.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT I. '
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT III']
#
#
# [44, 53, 71, 78, 108, 178]
# ['THE COMEDY OF ERRORS ACT V. ' 'KING HENRY THE EIGHTH ACT II.'
#  'THE COMEDY OF ERRORS ACT Il.' 'THE COMEDY OF ERRORS ACT IV.'
#  'THE COMEDY OF ERRORS ACT III' 'THE COMEDY OF ERRORS ACT I. ']
#
#
# [16, 47, 67, 181]
# ['THE TRAGEDY OF ANTONY AND CLEOPATRA ACT_4|S'
#  'KING HENRY THE EIGHTH ACT V. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III' 'THE TEMPEST ACT IV.']
#
#
# 141
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.
#
#
# [86, 92, 160]
# ['ALLS WELL THAT ENDS WELL ACT II.' 'ALLS WELL THAT ENDS WELL ACT III'
#  'ALLS WELL THAT ENDS WELL ACT V. ']
#
#
# [19, 51, 103, 148]
# ['SECOND PART OF KING HENRY IV ACT I. ' 'AS YOU LIKE IT ACT III'
#  'THE MERCHANT OF VENICE ACT I. ' 'AS YOU LIKE IT ACT V. ']
# /Users/bingao/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %% [markdown]
# > By adding the features of average sentence length, number of unique words normalized by total number of words, fequency of conjunctions, and etc., acts are clustered according to the writing style (need to be verified by visualization).

# %% [markdown]
# ### Affinity Propagation

# %%
print('No mormalization')
clusterDocuments(X, scaled = False, PCA_X=False, method = 'AffinityPropagation', visualize = 'None', verbose = False)
print('Normalize to N(0,1)')
clusterDocuments(X, scaled = True, method = 'AffinityPropagation', visualize = 'None', verbose = False)
# Out:
# No mormalization
# Number of clusters:  19
# Silhouette Coefficient: 0.195
# Normalize to N(0,1)
# Number of clusters:  26
# Silhouette Coefficient: 0.104
# /Users/bingao/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
clusterDocuments(X, scaled = True, PCA_X = True, method = 'AffinityPropagation')
# Out:
# Number of clusters:  26
# Silhouette Coefficient: 0.104
# [3, 10, 18, 20, 39, 43, 52, 61, 65, 75, 104, 164, 170, 173, 177]
# ['THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III'
#  'ALLS WELL THAT ENDS WELL ACT I. ' "LOVE'S LABOUR'S LOST ACT I. "
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT IV.'
#  "LOVE'S LABOUR'S LOST ACT V. " 'THE TRAGEDY OF KING LEAR ACT III'
#  'MEASURE FOR MEASURE ACT III' 'KING HENRY THE EIGHTH ACT III'
#  'AS YOU LIKE IT ACT II.' 'MEASURE FOR MEASURE ACT I. '
#  "LOVE'S LABOUR'S LOST ACT II." 'THE TRAGEDY OF KING LEAR ACT I. '
#  'THE LIFE OF KING HENRY THE FIFTH ACT II.'
#  'MUCH ADO ABOUT NOTHING ACT I. ' 'THE TRAGEDY OF KING LEAR ACT II.']
#
#
# [4, 28, 107, 115, 117, 128, 135, 144, 155, 156, 158, 162]
# ['THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I. '
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT IV.'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT IV.'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT III'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT V. '
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT III'
#  'THE MERCHANT OF VENICE ACT V. ' 'AS YOU LIKE IT ACT I. '
#  'MUCH ADO ABOUT NOTHING ACT V. ' 'MUCH ADO ABOUT NOTHING ACT III'
#  'ALLS WELL THAT ENDS WELL ACT V S']
#
#
# [33, 49, 56, 99, 116, 127, 139, 153, 172, 180, 186]
# ['THE HISTORY OF TROILUS AND CRESSIDA ACT III'
#  'THE FIRST PART OF HENRY THE SIXTH ACT V. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT III'
#  'THE FIRST PART OF HENRY THE SIXTH ACT III'
#  'THE FIRST PART OF HENRY THE SIXTH ACT II.' 'KING JOHN ACT I. '
#  'THE LIFE OF KING HENRY THE FIFTH ACT V. '
#  'THE FIRST PART OF HENRY THE SIXTH ACT IV.'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT V. ' "THE WINTER'S TALE ACT III"
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT V. ']
#
#
# [19, 51, 103, 148]
# ['SECOND PART OF KING HENRY IV ACT I. ' 'AS YOU LIKE IT ACT III'
#  'THE MERCHANT OF VENICE ACT I. ' 'AS YOU LIKE IT ACT V. ']
#
#
# [53, 178]
# ['KING HENRY THE EIGHTH ACT II.' 'THE COMEDY OF ERRORS ACT I. ']
#
#
# 60
# THE TWO GENTLEMEN OF VERONA ACT_4|S
#
#
# [47, 67, 181]
# ['KING HENRY THE EIGHTH ACT V. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III' 'THE TEMPEST ACT IV.']
#
#
# [22, 41, 76, 77, 80, 86, 98, 106, 151, 166, 168]
# ['THE TAMING OF THE SHREW ACT I. ' "A MIDSUMMER NIGHT'S DREAM ACT V. "
#  'THE TAMING OF THE SHREW ACT III' 'THE TEMPEST ACT V. '
#  "A MIDSUMMER NIGHT'S DREAM ACT III" 'ALLS WELL THAT ENDS WELL ACT II.'
#  'THE TAMING OF THE SHREW ACT V. ' 'THE TWO GENTLEMEN OF VERONA ACT IV.'
#  "A MIDSUMMER NIGHT'S DREAM ACT I. " "THE WINTER'S TALE ACT II."
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT_5|S']
#
#
# [6, 8, 29, 37, 59, 73, 84, 105, 109, 125, 137, 154, 159, 161, 185]
# ['AS YOU LIKE IT ACT IV.' 'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.'
#  'THE MERCHANT OF VENICE ACT III' 'THE TRAGEDY OF JULIUS CAESAR ACT I. '
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT I. '
#  "LOVE'S LABOUR'S LOST ACT IV." 'THE TRAGEDY OF JULIUS CAESAR ACT II.'
#  'THE TRAGEDY OF ROMEO AND JULIET ACT II.' 'MEASURE FOR MEASURE ACT II.'
#  'THE TRAGEDY OF CORIOLANUS ACT III' 'THE TRAGEDY OF JULIUS CAESAR ACT V. '
#  'THE TRAGEDY OF ROMEO AND JULIET ACT IV.' 'CYMBELINE ACT V. '
#  'THE TAMING OF THE SHREW ACT IV.' 'THE TAMING OF THE SHREW ACT Il.']
#
#
# [15, 16, 81, 91, 132]
# ['THE TRAGEDY OF JULIUS CAESAR ACT III'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT_4|S'
#  "A MIDSUMMER NIGHT'S DREAM ACT II." 'THE TEMPEST ACT III'
#  'KING HENRY THE EIGHTH ACT IV.']
#
#
# 92
# ALLS WELL THAT ENDS WELL ACT III
#
#
# [7, 17, 40, 45, 93, 122, 145]
# ['SECOND PART OF KING HENRY IV ACT II.'
#  'THE TWO GENTLEMEN OF VERONA ACT II.' 'THE MERRY WIVES OF WINDSOR ACT V. '
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT IV.'
#  'SECOND PART OF KING HENRY IV ACT V. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT V. '
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT II.']
#
#
# [44, 71, 78, 108]
# ['THE COMEDY OF ERRORS ACT V. ' 'THE COMEDY OF ERRORS ACT Il.'
#  'THE COMEDY OF ERRORS ACT IV.' 'THE COMEDY OF ERRORS ACT III']
#
#
# [12, 27, 64, 70, 72, 82, 95, 101, 102, 112, 119, 140, 163, 175]
# ['THE TRAGEDY OF MACBETH ACT II.' 'THE TRAGEDY OF ROMEO AND JULIET ACT V. '
#  'THE MERCHANT OF VENICE ACT II.' 'THE TWO GENTLEMEN OF VERONA ACT V. '
#  'THE LIFE OF TIMON OF ATHENS ACT III'
#  'THE LIFE OF TIMON OF ATHENS ACT II.' 'THE TRAGEDY OF KING LEAR ACT IV.'
#  'THE TRAGEDY OF MACBETH ACT V. ' 'THE TRAGEDY OF MACBETH ACT I. '
#  'CYMBELINE ACT IV.' 'ALLS WELL THAT ENDS WELL ACT IV '
#  'THE TRAGEDY OF MACBETH ACT III' "THE WINTER'S TALE ACT IV."
#  "THE WINTER'S TALE ACT I. "]
#
#
# [0, 21, 23, 63, 68, 88, 97, 113, 123]
# ['SECOND PART OF KING HENRY IV ACT IV.' "A MIDSUMMER NIGHT'S DREAM ACT IV."
#  'THE LIFE OF KING HENRY THE FIFTH ACT III'
#  'THE FIRST PART OF HENRY THE SIXTH ACT I. '
#  'THE TRAGEDY OF MACBETH ACT IV.' 'KING HENRY THE EIGHTH ACT I. '
#  'MUCH ADO ABOUT NOTHING ACT II.' 'MEASURE FOR MEASURE ACT V. '
#  'THE TRAGEDY OF ROMEO AND JULIET ACT I. ']
#
#
# 124
# A LOVER'S COMPLAINT ACT1609
#
#
# 129
# THE SONNETS ACT1609
#
#
# [25, 26, 38, 46, 48, 50, 55, 58, 79, 83, 87, 118, 120, 130, 133, 171]
# ['KING RICHARD III ACT III' 'KING RICHARD III ACT I. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT V. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT II.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT V. '
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT IV.' 'THE TEMPEST ACT I. '
#  'THE LIFE OF TIMON OF ATHENS ACT IV.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT III'
#  'KING RICHARD III ACT II.' 'THE LIFE OF KING HENRY THE FIFTH ACT IV.'
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT I. '
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT II.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT II.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT I. '
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT III']
#
#
# 141
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.
#
#
# [9, 11, 35, 42, 69, 131, 146, 157]
# ['KING RICHARD III ACT IV.' 'KING RICHARD THE SECOND ACT V. '
#  'KING RICHARD THE SECOND ACT II.' 'KING RICHARD THE SECOND ACT I. '
#  'KING RICHARD III ACT V. ' 'THE TRAGEDY OF TITUS ANDRONICUS ACT 1. '
#  'KING RICHARD THE SECOND ACT III' 'KING RICHARD THE SECOND ACT IV.']
#
#
# [5, 14, 24, 34, 57, 110, 138, 149]
# ['KING JOHN ACT III' 'THE LIFE OF KING HENRY THE FIFTH ACT I. '
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT IV.'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT I. ' 'KING JOHN ACT II.'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT I. ' 'KING JOHN ACT IV.'
#  'KING JOHN ACT V. ']
#
#
# [30, 31, 54, 89, 111, 143, 150]
# ['TWELFTH NIGHT; OR, WHAT YOU WILL ACT V. '
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT III'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT II.'
#  'THE TRAGEDY OF ROMEO AND JULIET ACT III'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT I. '
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT II.']
#
#
# [1, 13, 94, 114, 152, 179]
# ['THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V. '
#  'THE MERRY WIVES OF WINDSOR ACT II.'
#  'SECOND PART OF KING HENRY IV ACT III'
#  'THE MERRY WIVES OF WINDSOR ACT III' 'THE MERRY WIVES OF WINDSOR ACT IV.'
#  'THE MERRY WIVES OF WINDSOR ACT I. ']
#
#
# 160
# ALLS WELL THAT ENDS WELL ACT V.
#
#
# [2, 36, 62, 66, 74, 85, 96, 100, 134, 136, 147, 165, 167, 169, 183]
# ['THE TRAGEDY OF CORIOLANUS ACT I. ' 'THE TRAGEDY OF CORIOLANUS ACT V. '
#  'ALLS WELL THAT ENDS WELL ACT IV.' 'THE MERCHANT OF VENICE ACT IV.'
#  'THE TWO GENTLEMEN OF VERONA ACT III' 'THE TRAGEDY OF CORIOLANUS ACT IV.'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT V. '
#  'THE LIFE OF TIMON OF ATHENS ACT V. ' 'CYMBELINE ACT III'
#  'CYMBELINE ACT II.' "THE WINTER'S TALE ACT V. "
#  'THE LIFE OF TIMON OF ATHENS ACT I. ' 'THE TRAGEDY OF CORIOLANUS ACT II.'
#  'CYMBELINE ACT I. ' 'THE TWO GENTLEMEN OF VERONA ACT I. ']
#
#
# [32, 90, 121, 126, 142, 174, 176, 182, 184]
# ['THE TRAGEDY OF ANTONY AND CLEOPATRA ACT_3|S'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT II.'
#  'THE TRAGEDY OF JULIUS CAESAR ACT IV.'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT_2|S'
#  "LOVE'S LABOUR'S LOST ACT III" 'THE TRAGEDY OF KING LEAR ACT V. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT I. '
#  'MUCH ADO ABOUT NOTHING ACT IV.' 'THE TEMPEST ACT II.']
# /Users/bingao/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
clusterDocuments(X, scaled = True, method = 'AffinityPropagation', visualize = 'PCA', verbose = False)
clusterDocuments(X, scaled = True, method = 'AffinityPropagation', visualize = 'MDS', verbose = False)
# Out:
# Number of clusters:  26
# Silhouette Coefficient: 0.104
# /Users/bingao/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# Number of clusters:  26
# Silhouette Coefficient: 0.104

# %%
X = df_all.values
for n in np.arange(2,30,1):
    clusterDocuments(X, scaled=True, PCA_X = True, n_clusters = n, method = 'AgglomerativeClustering', visualize = False, verbose = False)
# Out:
# Number of clusters:  2
# Silhouette Coefficient: 0.778
# Number of clusters:  3
# Silhouette Coefficient: 0.087
# Number of clusters:  4
# Silhouette Coefficient: 0.090
# Number of clusters:  5
# Silhouette Coefficient: 0.099
# Number of clusters:  6
# Silhouette Coefficient: 0.112
# Number of clusters:  7
# Silhouette Coefficient: 0.103
# Number of clusters:  8
# Silhouette Coefficient: 0.081
# Number of clusters:  9
# Silhouette Coefficient: 0.085
# Number of clusters:  10
# Silhouette Coefficient: 0.095
# Number of clusters:  11
# Silhouette Coefficient: 0.100
# Number of clusters:  12
# Silhouette Coefficient: 0.082
# Number of clusters:  13
# Silhouette Coefficient: 0.088
# Number of clusters:  14
# Silhouette Coefficient: 0.096
# Number of clusters:  15
# Silhouette Coefficient: 0.098
# Number of clusters:  16
# Silhouette Coefficient: 0.098
# Number of clusters:  17
# Silhouette Coefficient: 0.096
# Number of clusters:  18
# Silhouette Coefficient: 0.097
# Number of clusters:  19
# Silhouette Coefficient: 0.102
# Number of clusters:  20
# Silhouette Coefficient: 0.106
# Number of clusters:  21
# Silhouette Coefficient: 0.107
# Number of clusters:  22
# Silhouette Coefficient: 0.104
# Number of clusters:  23
# Silhouette Coefficient: 0.109
# Number of clusters:  24
# Silhouette Coefficient: 0.115
# Number of clusters:  25
# Silhouette Coefficient: 0.118
# Number of clusters:  26
# Silhouette Coefficient: 0.119
# Number of clusters:  27
# Silhouette Coefficient: 0.118
# Number of clusters:  28
# Silhouette Coefficient: 0.122
# Number of clusters:  29
# Silhouette Coefficient: 0.125
# /Users/bingao/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
clusterDocuments(X, n_clusters = 23, scaled = True, PCA_X = True, method = 'AgglomerativeClustering')
# Out:
# Number of clusters:  23
# Silhouette Coefficient: 0.109
# [44, 53, 71, 78, 108, 178]
# ['THE COMEDY OF ERRORS ACT V. ' 'KING HENRY THE EIGHTH ACT II.'
#  'THE COMEDY OF ERRORS ACT Il.' 'THE COMEDY OF ERRORS ACT IV.'
#  'THE COMEDY OF ERRORS ACT III' 'THE COMEDY OF ERRORS ACT I. ']
#
#
# [10, 23, 56, 73, 87, 90, 120, 144, 180]
# ['ALLS WELL THAT ENDS WELL ACT I. '
#  'THE LIFE OF KING HENRY THE FIFTH ACT III'
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT III'
#  "LOVE'S LABOUR'S LOST ACT IV." 'THE LIFE OF KING HENRY THE FIFTH ACT IV.'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT II.'
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT II.' 'THE MERCHANT OF VENICE ACT V. '
#  "THE WINTER'S TALE ACT III"]
#
#
# [14, 34, 124]
# ['THE LIFE OF KING HENRY THE FIFTH ACT I. '
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT I. '
#  "A LOVER'S COMPLAINT ACT1609"]
#
#
# [2, 15, 17, 36, 62, 66, 74, 84, 91, 96, 100, 105, 134, 136, 147, 159, 167, 169]
# ['THE TRAGEDY OF CORIOLANUS ACT I. ' 'THE TRAGEDY OF JULIUS CAESAR ACT III'
#  'THE TWO GENTLEMEN OF VERONA ACT II.' 'THE TRAGEDY OF CORIOLANUS ACT V. '
#  'ALLS WELL THAT ENDS WELL ACT IV.' 'THE MERCHANT OF VENICE ACT IV.'
#  'THE TWO GENTLEMEN OF VERONA ACT III'
#  'THE TRAGEDY OF JULIUS CAESAR ACT II.' 'THE TEMPEST ACT III'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT V. '
#  'THE LIFE OF TIMON OF ATHENS ACT V. '
#  'THE TRAGEDY OF ROMEO AND JULIET ACT II.' 'CYMBELINE ACT III'
#  'CYMBELINE ACT II.' "THE WINTER'S TALE ACT V. " 'CYMBELINE ACT V. '
#  'THE TRAGEDY OF CORIOLANUS ACT II.' 'CYMBELINE ACT I. ']
#
#
# [1, 27, 43, 72, 82, 95, 98, 107, 117, 137, 154, 156, 164, 165, 177, 183]
# ['THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V. '
#  'THE TRAGEDY OF ROMEO AND JULIET ACT V. '
#  'THE TRAGEDY OF KING LEAR ACT III' 'THE LIFE OF TIMON OF ATHENS ACT III'
#  'THE LIFE OF TIMON OF ATHENS ACT II.' 'THE TRAGEDY OF KING LEAR ACT IV.'
#  'THE TAMING OF THE SHREW ACT V. '
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT III'
#  'THE TRAGEDY OF JULIUS CAESAR ACT V. '
#  'THE TRAGEDY OF ROMEO AND JULIET ACT IV.' 'MUCH ADO ABOUT NOTHING ACT V. '
#  'THE TRAGEDY OF KING LEAR ACT I. ' 'THE LIFE OF TIMON OF ATHENS ACT I. '
#  'THE TRAGEDY OF KING LEAR ACT II.' 'THE TWO GENTLEMEN OF VERONA ACT I. ']
#
#
# [12, 32, 64, 70, 102, 104, 112, 119, 122, 140, 175]
# ['THE TRAGEDY OF MACBETH ACT II.'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT_3|S'
#  'THE MERCHANT OF VENICE ACT II.' 'THE TWO GENTLEMEN OF VERONA ACT V. '
#  'THE TRAGEDY OF MACBETH ACT I. ' "LOVE'S LABOUR'S LOST ACT II."
#  'CYMBELINE ACT IV.' 'ALLS WELL THAT ENDS WELL ACT IV '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT V. '
#  'THE TRAGEDY OF MACBETH ACT III' "THE WINTER'S TALE ACT I. "]
#
#
# [7, 13, 40, 45, 68, 93, 94, 101, 114, 145, 152, 179]
# ['SECOND PART OF KING HENRY IV ACT II.'
#  'THE MERRY WIVES OF WINDSOR ACT II.' 'THE MERRY WIVES OF WINDSOR ACT V. '
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT IV.' 'THE TRAGEDY OF MACBETH ACT IV.'
#  'SECOND PART OF KING HENRY IV ACT V. '
#  'SECOND PART OF KING HENRY IV ACT III' 'THE TRAGEDY OF MACBETH ACT V. '
#  'THE MERRY WIVES OF WINDSOR ACT III'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT II.'
#  'THE MERRY WIVES OF WINDSOR ACT IV.' 'THE MERRY WIVES OF WINDSOR ACT I. ']
#
#
# [22, 37, 52, 76, 80, 106, 109, 125, 151, 163, 166, 168, 185]
# ['THE TAMING OF THE SHREW ACT I. ' 'THE TRAGEDY OF JULIUS CAESAR ACT I. '
#  'MEASURE FOR MEASURE ACT III' 'THE TAMING OF THE SHREW ACT III'
#  "A MIDSUMMER NIGHT'S DREAM ACT III" 'THE TWO GENTLEMEN OF VERONA ACT IV.'
#  'MEASURE FOR MEASURE ACT II.' 'THE TRAGEDY OF CORIOLANUS ACT III'
#  "A MIDSUMMER NIGHT'S DREAM ACT I. " "THE WINTER'S TALE ACT IV."
#  "THE WINTER'S TALE ACT II." 'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT_5|S'
#  'THE TAMING OF THE SHREW ACT Il.']
#
#
# [4, 6, 8, 18, 85, 97, 128, 155, 158, 162, 173]
# ['THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I. ' 'AS YOU LIKE IT ACT IV.'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.'
#  "LOVE'S LABOUR'S LOST ACT I. " 'THE TRAGEDY OF CORIOLANUS ACT IV.'
#  'MUCH ADO ABOUT NOTHING ACT II.'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT V. '
#  'AS YOU LIKE IT ACT I. ' 'MUCH ADO ABOUT NOTHING ACT III'
#  'ALLS WELL THAT ENDS WELL ACT V S' 'MUCH ADO ABOUT NOTHING ACT I. ']
#
#
# [5, 24, 33, 57, 116, 127, 138, 149]
# ['KING JOHN ACT III' 'THE FIRST PART OF KING HENRY THE FOURTH ACT IV.'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT III' 'KING JOHN ACT II.'
#  'THE FIRST PART OF HENRY THE SIXTH ACT II.' 'KING JOHN ACT I. '
#  'KING JOHN ACT IV.' 'KING JOHN ACT V. ']
#
#
# [47, 67, 172, 181]
# ['KING HENRY THE EIGHTH ACT V. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT V. ' 'THE TEMPEST ACT IV.']
#
#
# [16, 41, 142]
# ['THE TRAGEDY OF ANTONY AND CLEOPATRA ACT_4|S'
#  "A MIDSUMMER NIGHT'S DREAM ACT V. " "LOVE'S LABOUR'S LOST ACT III"]
#
#
# [86, 92, 160]
# ['ALLS WELL THAT ENDS WELL ACT II.' 'ALLS WELL THAT ENDS WELL ACT III'
#  'ALLS WELL THAT ENDS WELL ACT V. ']
#
#
# [0, 21, 29, 55, 58, 63, 77, 81, 110, 123, 132]
# ['SECOND PART OF KING HENRY IV ACT IV.' "A MIDSUMMER NIGHT'S DREAM ACT IV."
#  'THE MERCHANT OF VENICE ACT III' 'THE TEMPEST ACT I. '
#  'THE LIFE OF TIMON OF ATHENS ACT IV.'
#  'THE FIRST PART OF HENRY THE SIXTH ACT I. ' 'THE TEMPEST ACT V. '
#  "A MIDSUMMER NIGHT'S DREAM ACT II."
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT I. '
#  'THE TRAGEDY OF ROMEO AND JULIET ACT I. ' 'KING HENRY THE EIGHTH ACT IV.']
#
#
# [9, 11, 35, 42, 69, 131, 146, 157]
# ['KING RICHARD III ACT IV.' 'KING RICHARD THE SECOND ACT V. '
#  'KING RICHARD THE SECOND ACT II.' 'KING RICHARD THE SECOND ACT I. '
#  'KING RICHARD III ACT V. ' 'THE TRAGEDY OF TITUS ANDRONICUS ACT 1. '
#  'KING RICHARD THE SECOND ACT III' 'KING RICHARD THE SECOND ACT IV.']
#
#
# 60
# THE TWO GENTLEMEN OF VERONA ACT_4|S
#
#
# 129
# THE SONNETS ACT1609
#
#
# [30, 31, 54, 88, 89, 111, 113, 115, 143, 150, 161]
# ['TWELFTH NIGHT; OR, WHAT YOU WILL ACT V. '
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT III'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT II.'
#  'KING HENRY THE EIGHTH ACT I. ' 'THE TRAGEDY OF ROMEO AND JULIET ACT III'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.' 'MEASURE FOR MEASURE ACT V. '
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT IV.'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT I. '
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT II.'
#  'THE TAMING OF THE SHREW ACT IV.']
#
#
# [26, 38, 46, 48, 49, 50, 79, 83, 99, 118, 130, 133, 139, 153, 171, 186]
# ['KING RICHARD III ACT I. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT V. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT II.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT V. '
#  'THE FIRST PART OF HENRY THE SIXTH ACT V. '
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT IV.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT III'
#  'KING RICHARD III ACT II.' 'THE FIRST PART OF HENRY THE SIXTH ACT III'
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT I. '
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT II.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT I. '
#  'THE LIFE OF KING HENRY THE FIFTH ACT V. '
#  'THE FIRST PART OF HENRY THE SIXTH ACT IV.'
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT III'
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT V. ']
#
#
# [121, 126, 174, 176, 182, 184]
# ['THE TRAGEDY OF JULIUS CAESAR ACT IV.'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT_2|S'
#  'THE TRAGEDY OF KING LEAR ACT V. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT I. '
#  'MUCH ADO ABOUT NOTHING ACT IV.' 'THE TEMPEST ACT II.']
#
#
# 141
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.
#
#
# [3, 20, 25, 28, 39, 59, 61, 65, 75, 135, 170]
# ['THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III'
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT IV.'
#  'KING RICHARD III ACT III'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT IV.'
#  "LOVE'S LABOUR'S LOST ACT V. "
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT I. '
#  'KING HENRY THE EIGHTH ACT III' 'AS YOU LIKE IT ACT II.'
#  'MEASURE FOR MEASURE ACT I. '
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT III'
#  'THE LIFE OF KING HENRY THE FIFTH ACT II.']
#
#
# [19, 51, 103, 148]
# ['SECOND PART OF KING HENRY IV ACT I. ' 'AS YOU LIKE IT ACT III'
#  'THE MERCHANT OF VENICE ACT I. ' 'AS YOU LIKE IT ACT V. ']
# /Users/bingao/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
clusterDocuments(X, n_clusters = 8, scaled = True, PCA_X = True, method = 'SpectralClustering', verbose = False)
clusterDocuments(X, scaled = True, PCA_X = True, method = 'Birch', verbose = False)
#clusterDocuments(X, scaled = True, PCA_X = True, method = 'DBSCAN')
clusterDocuments(X, scaled = True, PCA_X = True, method = 'MeanShift', verbose = False)
# Out:
# Number of clusters:  8
# Silhouette Coefficient: -0.142
# Number of clusters:  3
# Silhouette Coefficient: 0.087
# /Users/bingao/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# Number of clusters:  6
# Silhouette Coefficient: 0.284

# %%
def print3D(X, x_label, y_label, z_label, title, labels):
    fig = plt.figure(1, figsize=(11, 10))
    plt.clf()
    ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

    plt.cla()
    
    ax.scatter(X[:, 1], X[:, 0], X[:, 2], c=labels.astype(np.float), s=50)
    ax.dist = 11

    ax.w_xaxis.set_ticklabels([])
    ax.w_yaxis.set_ticklabels([])
    ax.w_zaxis.set_ticklabels([])
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.set_zlabel(z_label)
    
pca = PCA(n_components=3)
X_3D_PCA = pca.fit_transform(X)

print3D(X_3D_PCA, 'numberUniqueWords', 'averageSentenceLength', 'numberOfPronoun', 'title', labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-0960320b2857> in <module>()
#      19 X_3D_PCA = pca.fit_transform(X)
#      20
# ---> 21 print3D(X_3D_PCA, 'numberUniqueWords', 'averageSentenceLength', 'numberOfPronoun', 'title', labels)
#
# NameError: name 'labels' is not defined
