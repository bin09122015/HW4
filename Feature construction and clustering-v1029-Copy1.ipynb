# %% [markdown]
# ## Step 1 Construct features using NLTK

# %%
import nltk
from nltk.corpus import stopwords
import string
import json

# %matplotlib inline 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from __future__ import division

randomState = np.random.seed(2)


# Import works.json: title, words, sentences of 38 pieces
with open('works_v1028.json', 'r') as f:
    try:
        works = json.load(f)
    # if the file is empty the ValueError will be thrown
    except ValueError:
        works = {}

# %%
from nltk import FreqDist

def getFreqDist(words):
    nltk_text = nltk.Text(words)
    
    return FreqDist(nltk_text)

# %%
def getCountFrequency(words, freq):
    nltk_text = nltk.Text(words)
    freq_dist = FreqDist(nltk_text)
    
    count = 0
    for key,value in freq_dist.items():
        if value == freq:
            count += 1
    
    return count    

def getHapaxLegomena(words):
    return getCountFrequency(words, 1)

# %%
def getDisLegomena(words):
    return getCountFrequency(words, 2)

# %%
def getNumberUniqueWords(words):
    return len(getFreqDist(words))

# %%
def getWordLengthDistribution(words):
    result = FreqDist()
    for w in words:        
        result[len(w)] += 1
    
    return result

def printFreqDist(freq_dist):
    for key,value in freq_dist.items():
        print (key,value)

# %%
def getSentenceLengthDistribution(sents):
    result = FreqDist()
    for s in sents:        
        result[len(s)] += 1
    
    return result

# %%
def getAverageSentenceLength(words_all, sents):
    
    return len(words_all)/len(sents)

# %%
def getPronounDistribution(sents):
    result = FreqDist()
    pronouns = ['I', 'you', 'he', 'she', 'it', 'we', 'you', 'they', 'thou', 'ye']
    for s in sents:
        count = 0
        for p in pronouns:
            count += s.count(p)
        result[count] += 1
    
    return result

# %%
def getNumberOfPronoun(words):
    pronouns = ['I', 'you', 'he', 'she', 'it', 'we', 'you', 'they', 'thou', 'ye']
    count = 0
         
    for p in pronouns:
        count += words.count(p)
    
    return count

# %%
def getConjunctionDistribution(sents):
    result = FreqDist()
    conjunctions = ['for', 'and', 'nor', 'but', 'or', 'yet', 'so', 'after', 'although', 'as', 'because', 'before', 'if',
                'once', 'since', 'though', 'unless', 'until', 'when', 'where', 'while', 'whether', 'either', 'neither',
                'as', 'than', 'even', 'then', 'lest', 'rather', 'which', 'who', 'why', 'that', 'till']
    for s in sents:
        count = 0
        for c in conjunctions:
            count += s.count(c)
        result[count] += 1
    
    return result

# %%
def getNumberOfConjunction(words):
    count = 0
    conjunctions = ['for', 'and', 'nor', 'but', 'or', 'yet', 'so', 'after', 'although', 'as', 'because', 'before', 'if',
                'once', 'since', 'though', 'unless', 'until', 'when', 'where', 'while', 'whether', 'either', 'neither',
                'as', 'than', 'even', 'then', 'lest', 'rather', 'which', 'who', 'why', 'that', 'till']

    for c in conjunctions:
        count += words.count(c)
    
    return count

# %%
def getNumberOfComma(text):
    return text.count(",")

def getNumberOfDots(text):
    return text.count(".")

def getNumberOfStringList(words, string_list):
    count = 0
    
    for c in string_list:
        count += words.count(c)
    
    return count

def getNumberOfThe(words):
    string_list = ['a', 'an', 'the']
    
    return getNumberOfStringList(words, string_list)

def getNumberOfIn(words):
    string_list = ['in', 'on', 'to', 'of']
    
    return getNumberOfStringList(words, string_list)

def getNumberOfIs(words):
    string_list = ['is', 'are', 'was', 'were']
    
    return getNumberOfStringList(words, string_list)

# %%
# Create a feature table for all acts
# Currently only has some simple features

featureTable = {}

featureTable = {'act': [], 'filename': [], 'HapaxLegomena': [], 'DisLegomena': [], 
                'numberUniqueWords': [], 'averageSentenceLength': [], 'numberOfSentences': [],
                'numberOfPronoun': [], 'numberOfConjunction': [], 'numberOfComma': [], 'numberOfDots': [],
                'numberOfThe': [], 'numberOfIn': [], 'numberOfIs': []}


for act, content in works.items():
    words_nonStemmed = content['words_nonStemmed']
    words_all = content['words_all']
    sentences = content['sentences']
    # Normalize by number of all words
    normalizer = len(words_all)
    featureTable['act'].append(act)
    featureTable['filename'].append(content['filename'])
    featureTable['HapaxLegomena'].append(getHapaxLegomena(words_nonStemmed)/normalizer)
    featureTable['DisLegomena'].append(getDisLegomena(words_nonStemmed)/normalizer)
    featureTable['numberUniqueWords'].append(getNumberUniqueWords(words_nonStemmed)/normalizer)
    featureTable['averageSentenceLength'].append(getAverageSentenceLength(words_all, sentences))
    featureTable['numberOfSentences'].append(len(sentences))
    featureTable['numberOfPronoun'].append(getNumberOfPronoun(words_all)/normalizer)
    featureTable['numberOfConjunction'].append(getNumberOfConjunction(words_all)/normalizer)
    featureTable['numberOfComma'].append(getNumberOfComma(content['text'])/normalizer)
    featureTable['numberOfDots'].append(getNumberOfDots(content['text'])/normalizer)
    featureTable['numberOfThe'].append(getNumberOfThe(words_all)/normalizer)
    featureTable['numberOfIn'].append(getNumberOfIn(words_all)/normalizer)
    featureTable['numberOfIs'].append(getNumberOfIs(words_all)/normalizer)

print(len(featureTable['act']))


df = pd.DataFrame(featureTable)
df.set_index(['act'], inplace=True)
df.head()
# Out:
# 218
#                                                 DisLegomena  HapaxLegomena  \
# act
# LOVE'S LABOUR'S LOST ACT V.                        0.025578       0.089181
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.            0.024670       0.103865
# CYMBELINE ACT V.                                   0.025312       0.102219
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.     0.023689       0.091230
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III        0.026426       0.099820
#
#                                                 averageSentenceLength  \
# act
# LOVE'S LABOUR'S LOST ACT V.                                 10.085125
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.                     10.117647
# CYMBELINE ACT V.                                            13.112994
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.               8.077449
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III                  9.657773
#
#                                                filename  numberOfComma  \
# act
# LOVE'S LABOUR'S LOST ACT V.                      19.txt       0.077756
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.          35.txt       0.067725
# CYMBELINE ACT V.                                  7.txt       0.078738
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.   26.txt       0.071066
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III       3.txt       0.069189
#
#                                                 numberOfConjunction  \
# act
# LOVE'S LABOUR'S LOST ACT V.                                0.076562
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.                    0.083124
# CYMBELINE ACT V.                                           0.088001
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.             0.078398
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III                0.076036
#
#                                                 numberOfDots  numberOfIn  \
# act
# LOVE'S LABOUR'S LOST ACT V.                         0.083639    0.047915
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.             0.078567    0.043526
# CYMBELINE ACT V.                                    0.061504    0.044054
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.      0.092217    0.033136
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III         0.085646    0.042162
#
#                                                 numberOfIs  numberOfPronoun  \
# act
# LOVE'S LABOUR'S LOST ACT V.                       0.017308         0.053884
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.           0.019642         0.061282
# CYMBELINE ACT V.                                  0.018634         0.048470
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.    0.014664         0.063170
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III       0.015015         0.049009
#
#                                                 numberOfSentences  \
# act
# LOVE'S LABOUR'S LOST ACT V.                                  1163
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.                       629
# CYMBELINE ACT V.                                              708
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.                878
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III                   862
#
#                                                 numberOfThe  numberUniqueWords
# act
# LOVE'S LABOUR'S LOST ACT V.                        0.044590           0.148862
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.            0.037712           0.163734
# CYMBELINE ACT V.                                   0.038776           0.166092
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.     0.031021           0.148054
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III        0.033994           0.162643

# %%
# Filter out wierd acts, e.g. the beginning of a play

# df = df[df['averageSentenceLength'] < 30]

df.drop(["A MIDSUMMER NIGHT'S DREAM ACT1596","ALLS WELL THAT ENDS WELL ACT1603", "AS YOU LIKE IT ACT1601", 
              "CYMBELINE ACT1609","KING HENRY THE EIGHTH ACT1611","KING JOHN ACT1597","KING RICHARD III ACT1593",
             "KING RICHARD THE SECOND ACT1596", "LOVE'S LABOUR'S LOST ACT1595", "MEASURE FOR MEASURE ACT1605",
             "MUCH ADO ABOUT NOTHING ACT1599", "SECOND PART OF KING HENRY IV ACT1598", "THE COMEDY OF ERRORS ACT1593",
             "THE FIRST PART OF HENRY THE SIXTH ACT1592", "THE FIRST PART OF KING HENRY THE FOURTH ACT1598",
             "THE HISTORY OF TROILUS AND CRESSIDA ACT1602", "THE LIFE OF KING HENRY THE FIFTH ACT1599",
             "THE LIFE OF TIMON OF ATHENS ACT1608", "THE MERCHANT OF VENICE ACT1597", "THE MERRY WIVES OF WINDSOR ACT1601",
             "THE SECOND PART OF KING HENRY THE SIXTH ACT1591", "THE TAMING OF THE SHREW ACT1594", "THE TEMPEST ACT1612",
             "THE TRAGEDY OF ANTONY AND CLEOPATRA ACT1607", "THE TRAGEDY OF CORIOLANUS ACT1608",
              "THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT1604","THE TRAGEDY OF JULIUS CAESAR ACT1599",
             "THE TRAGEDY OF KING LEAR ACT1606", "THE TRAGEDY OF MACBETH ACT1606", 
              "THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT1605", "THE TRAGEDY OF ROMEO AND JULIET ACT1595",
             "THE TRAGEDY OF TITUS ANDRONICUS ACT1594", "THE TWO GENTLEMEN OF VERONA ACT1595", "THE WINTER'S TALE ACT1611",
             "TWELFTH NIGHT; OR, WHAT YOU WILL ACT1602", "THE THIRD PART OF KING HENRY THE SIXTH ACT1591"], inplace = True)

df_2 = df[['numberUniqueWords', 'averageSentenceLength']]
df_3 = df[['numberUniqueWords', 'averageSentenceLength', 'numberOfPronoun']]
df = df[['HapaxLegomena', 'DisLegomena', 'numberUniqueWords', 
        'averageSentenceLength', 'numberOfPronoun', 'numberOfConjunction', 'numberOfComma', 'numberOfDots',
                'numberOfThe', 'numberOfIn', 'numberOfIs']]

# %%
pd.scatter_matrix(df, alpha=0.2, figsize=(16, 16), diagonal='kde')
plt.show()
# Out:
# /Users/byan/anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# ## Step 2 Construct n-grams using sklearn

# %%
title = []
text = []

for act in df.index:
    content = works[act]
    title.append(act)
    text.append(content['text'])

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from __future__ import print_function

from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer
from sklearn import metrics

from sklearn.cluster import KMeans, MiniBatchKMeans, AffinityPropagation, AgglomerativeClustering, MeanShift, SpectralClustering, DBSCAN, Birch 
import numpy as np

# %%
# excluding stop words, n-grams is an input
def getTfidf(ngram_range):
    count_vect = CountVectorizer(ngram_range=ngram_range, stop_words='english')
    X_counts = count_vect.fit_transform(text)

    tfidf_transformer = TfidfTransformer(use_idf=True)
    X_tfidf = tfidf_transformer.fit_transform(X_counts)
    return X_tfidf

# %%
def getSVD(X_tfidf, n_components):
    
    svd = TruncatedSVD(n_components = n_components, random_state = randomState)
    lsa = make_pipeline(svd, Normalizer(copy=False))
    X = lsa.fit_transform(X_tfidf)

    explained_variance = svd.explained_variance_ratio_.sum()
    print("Explained variance of the SVD step: {}%".format(
        int(explained_variance * 100)))
    
    return X

# %%
# Features from n-grams, use fewer components
X_tfidf = getTfidf(ngram_range = (3,5))
X = getSVD(X_tfidf, n_components = 6)
df_ngrams = pd.DataFrame(data=X, index = title, 
                         columns=['n-gram 1st component', 'n-gram 2nd compoent', 'n-gram 3rd', 'n-gram 4th', 'n-gram 5th', 'n-gram 6th',])
df_ngrams.head()
# Out:
# Explained variance of the SVD step: 3%
#                                                 n-gram 1st component  \
# LOVE'S LABOUR'S LOST ACT V.                                 0.568233
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.                    -0.138265
# CYMBELINE ACT V.                                           -0.525270
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.             -0.386848
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III                -0.000565
#
#                                                 n-gram 2nd compoent  \
# LOVE'S LABOUR'S LOST ACT V.                                0.612220
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.                   -0.576301
# CYMBELINE ACT V.                                           0.340175
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.            -0.750992
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III               -0.121923
#
#                                                 n-gram 3rd  n-gram 4th  \
# LOVE'S LABOUR'S LOST ACT V.                       0.115134    0.388225
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.           0.320598    0.715138
# CYMBELINE ACT V.                                  0.596819   -0.151990
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.   -0.206266   -0.177251
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III      -0.328591    0.511496
#
#                                                 n-gram 5th  n-gram 6th
# LOVE'S LABOUR'S LOST ACT V.                       0.370085   -0.036875
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.           0.168120   -0.079309
# CYMBELINE ACT V.                                  0.220658    0.424722
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.    0.456494   -0.063317
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III      -0.638313   -0.456171

# %% [markdown]
# ## Step 3 Combine n-grams and other features

# %%
# Merge all features
df_all = df.join(df_ngrams)
df_all.head()
# Out:
#                                                 HapaxLegomena  DisLegomena  \
# act
# LOVE'S LABOUR'S LOST ACT V.                          0.089181     0.025578
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.              0.103865     0.024670
# CYMBELINE ACT V.                                     0.102219     0.025312
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.       0.091230     0.023689
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III          0.099820     0.026426
#
#                                                 numberUniqueWords  \
# act
# LOVE'S LABOUR'S LOST ACT V.                              0.148862
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.                  0.163734
# CYMBELINE ACT V.                                         0.166092
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.           0.148054
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III              0.162643
#
#                                                 averageSentenceLength  \
# act
# LOVE'S LABOUR'S LOST ACT V.                                 10.085125
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.                     10.117647
# CYMBELINE ACT V.                                            13.112994
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.               8.077449
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III                  9.657773
#
#                                                 numberOfPronoun  \
# act
# LOVE'S LABOUR'S LOST ACT V.                            0.053884
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.                0.061282
# CYMBELINE ACT V.                                       0.048470
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.         0.063170
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III            0.049009
#
#                                                 numberOfConjunction  \
# act
# LOVE'S LABOUR'S LOST ACT V.                                0.076562
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.                    0.083124
# CYMBELINE ACT V.                                           0.088001
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.             0.078398
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III                0.076036
#
#                                                 numberOfComma  numberOfDots  \
# act
# LOVE'S LABOUR'S LOST ACT V.                          0.077756      0.083639
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.              0.067725      0.078567
# CYMBELINE ACT V.                                     0.078738      0.061504
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.       0.071066      0.092217
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III          0.069189      0.085646
#
#                                                 numberOfThe  numberOfIn  \
# act
# LOVE'S LABOUR'S LOST ACT V.                        0.044590    0.047915
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.            0.037712    0.043526
# CYMBELINE ACT V.                                   0.038776    0.044054
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.     0.031021    0.033136
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III        0.033994    0.042162
#
#                                                 numberOfIs  \
# act
# LOVE'S LABOUR'S LOST ACT V.                       0.017308
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.           0.019642
# CYMBELINE ACT V.                                  0.018634
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.    0.014664
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III       0.015015
#
#                                                 n-gram 1st component  \
# act
# LOVE'S LABOUR'S LOST ACT V.                                 0.568233
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.                    -0.138265
# CYMBELINE ACT V.                                           -0.525270
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.             -0.386848
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III                -0.000565
#
#                                                 n-gram 2nd compoent  \
# act
# LOVE'S LABOUR'S LOST ACT V.                                0.612220
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.                   -0.576301
# CYMBELINE ACT V.                                           0.340175
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.            -0.750992
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III               -0.121923
#
#                                                 n-gram 3rd  n-gram 4th  \
# act
# LOVE'S LABOUR'S LOST ACT V.                       0.115134    0.388225
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.           0.320598    0.715138
# CYMBELINE ACT V.                                  0.596819   -0.151990
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.   -0.206266   -0.177251
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III      -0.328591    0.511496
#
#                                                 n-gram 5th  n-gram 6th
# act
# LOVE'S LABOUR'S LOST ACT V.                       0.370085   -0.036875
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT I.           0.168120   -0.079309
# CYMBELINE ACT V.                                  0.220658    0.424722
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.    0.456494   -0.063317
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III      -0.638313   -0.456171

# %% [markdown]
# ## Step 4 Clustering

# %%
def getLabels(X, n_clusters = 8, method = 'KMeans'):
    
    if method == 'KMeans':
        cluster = KMeans(n_clusters=n_clusters, init='k-means++', max_iter=500, 
                         n_init=5, random_state = randomState)   
    elif method == 'AffinityPropagation':
        cluster = AffinityPropagation(max_iter=1000)
    elif method == 'AgglomerativeClustering':
        cluster = AgglomerativeClustering(n_clusters=n_clusters)
    elif method == 'Birch':
        cluster = Birch()
    elif method == 'DBSCAN':
        cluster = DBSCAN(random_state = randomState, eps=0.1, min_samples=3)
    elif method == 'SpectralClustering':
        cluster = SpectralClustering(n_clusters=n_clusters)
    elif method == 'MeanShift':
        cluster = MeanShift()
        

    return cluster.fit_predict(X)
        

def printClusters(labels):
    for i in set(labels):
        index = np.squeeze(np.argwhere(labels == i)).tolist()
        print(index)
    
        print(np.array(title)[index])
        print('\n')
        
def print2D(X, x_label, y_label, title, labels, n_labels):
    plt.figure(figsize = (9,7))
    plt.scatter(X[:,0], X[:,1], c=labels, marker='+', s=100, linewidths=2)
    plt.ylabel(y_label, fontsize=14, fontweight='bold')
    plt.xlabel(x_label, fontsize=14, fontweight='bold')
    plt.title(title, fontsize=14, fontweight='bold')
    
    ax = plt.gca()
    for i in range(len(labels)):
        if labels.tolist().count(labels[i]) <= n_labels:
            ax.annotate(df_all.index[i], xy=X[i,:], fontweight='bold')
    
    xmin = min(X[:,0])
    xmax = max(X[:,0])
    ymin = min(X[:,1])
    ymax = max(X[:,1])
    
    xrange = xmax - xmin
    yrange = ymax - ymin
    
    xmin = xmin - xrange/10
    xmax = xmax + xrange/10
    
    ymin = ymin - yrange/10
    ymax = ymax + yrange/10
    
    plt.xlim([xmin, xmax])
    plt.ylim([ymin, ymax])
    plt.show()

# %%
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn import metrics
from sklearn.manifold import MDS

def clusterDocuments(X, scaled = False, PCA_X = False, n_clusters = 8, 
                     method = 'KMeans', visualize = 'PCA', verbose = True, n_labels=3):
        
    
    if scaled:
        X = preprocessing.scale(X)
        
    if PCA_X:
        X = PCA().fit_transform(X)
        
    if PCA_X:
        X_2D_PCA = X[:, 0:2]
    else: 
        X_2D_PCA = PCA(n_components=2).fit_transform(X)
        X_2D_MDS = MDS(n_components=2).fit_transform(X)
        
    labels = getLabels(X, n_clusters, method)
        
    if visualize == 'PCA':
        print2D(X_2D_PCA, 'PCA 1st component', 'PCA 2nd component', method, labels, n_labels)
    elif visualize == 'MDS':
        print2D(X_2D_MDS, 'MDS 1st component', 'MDS 2nd component', method, labels, n_labels)
        
    
    print('Number of clusters: ', len(set(labels)))
    print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(X, labels, random_state=randomState))
    
    if verbose:
        printClusters(labels)

def visualizeCovariance(X, scaled = False):
    if scaled:
        X = preprocessing.scale(X)
        title = 'Standardized'
    else:
        title = 'Non-Standardized'
    
    pca = PCA(n_components=None)
    pca.fit(X)
    
    covariance = pca.get_covariance()
    
    
    width = 0.5
    ind = np.arange(len(pca.explained_variance_ratio_))

    plt.figure()
    ax = plt.gca()
    ax.bar(ind, pca.explained_variance_ratio_, width, color='gray')
    plt.ylabel('Explained Variance Ratio')
    plt.xlabel('Components')
    plt.title(title, fontweight='bold')
    plt.show()
    
    fig, ax = plt.subplots()
    heatmap = ax.pcolor(covariance, cmap=plt.cm.Blues, alpha=0.8)
    # Format
    fig = plt.gcf()
    fig.set_size_inches(8, 8)
    # turn off the frame
    ax.set_frame_on(False)
    # put the major ticks at the middle of each cell
    ax.set_yticks(np.arange(covariance.shape[0]) + 0.5, minor=False)
    ax.set_xticks(np.arange(covariance.shape[1]) + 0.5, minor=False)
    # want a more natural, table-like display
    ax.invert_yaxis()
    ax.xaxis.tick_top()
    # Set the labels
    # label source:https://en.wikipedia.org/wiki/Basketball_statistics
    labels = df_all.columns
    # note I could have used nba_sort.columns but made "labels" instead
    ax.set_xticklabels(labels, minor=False)
    ax.set_yticklabels(labels, minor=False)
    # rotate the
    plt.xticks(rotation=90)
    ax.grid(False)
    # Turn off all the ticks
    ax = plt.gca()
    for t in ax.xaxis.get_major_ticks():
        t.tick1On = False
        t.tick2On = False
    for t in ax.yaxis.get_major_ticks():
        t.tick1On = False
        t.tick2On = False
    plt.title(title, fontweight='bold', y=0)
    plt.show()

# %%
X = df_all.values
visualizeCovariance(X, scaled = False)
visualizeCovariance(X, scaled = True)
# Out:
# /Users/byan/anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# ### K-Means

# %%
# Cluster using all features
X = df_all.values
for n in np.arange(5,30,1):
    clusterDocuments(X, scaled=True, PCA_X = True, n_clusters = n, method = 'KMeans', visualize = 'None', verbose = False)
# Out:
# Number of clusters:  5
# Silhouette Coefficient: 0.070
# Number of clusters:  6
# Silhouette Coefficient: 0.071
# Number of clusters:  7
# Silhouette Coefficient: 0.080
# Number of clusters:  8
# Silhouette Coefficient: 0.070
# Number of clusters:  9
# Silhouette Coefficient: 0.073
# Number of clusters:  10
# Silhouette Coefficient: 0.072
# Number of clusters:  11
# Silhouette Coefficient: 0.077
# Number of clusters:  12
# Silhouette Coefficient: 0.079
# Number of clusters:  13
# Silhouette Coefficient: 0.072
# Number of clusters:  14
# Silhouette Coefficient: 0.080
# Number of clusters:  15
# Silhouette Coefficient: 0.076
# Number of clusters:  16
# Silhouette Coefficient: 0.080
# Number of clusters:  17
# Silhouette Coefficient: 0.074
# Number of clusters:  18
# Silhouette Coefficient: 0.087
# Number of clusters:  19
# Silhouette Coefficient: 0.084
# Number of clusters:  20
# Silhouette Coefficient: 0.074
# Number of clusters:  21
# Silhouette Coefficient: 0.077
# Number of clusters:  22
# Silhouette Coefficient: 0.083
# Number of clusters:  23
# Silhouette Coefficient: 0.082
# Number of clusters:  24
# Silhouette Coefficient: 0.079
# Number of clusters:  25
# Silhouette Coefficient: 0.078
# Number of clusters:  26
# Silhouette Coefficient: 0.070
# Number of clusters:  27
# Silhouette Coefficient: 0.088
# Number of clusters:  28
# Silhouette Coefficient: 0.083
# Number of clusters:  29
# Silhouette Coefficient: 0.085
# /Users/byan/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
X = df_all.values
clusterDocuments(X, scaled = True, PCA_X = True, n_clusters = 25, method = 'KMeans', visualize = 'PCA', verbose = True)
# Out:
# Number of clusters:  25
# Silhouette Coefficient: 0.081
# [3, 20, 28, 37, 68, 124, 128, 129, 140, 167, 172]
# ['THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT III'
#  'THE TRAGEDY OF KING LEAR ACT V. ' 'THE TAMING OF THE SHREW ACT IV.'
#  'MUCH ADO ABOUT NOTHING ACT IV.' 'THE TWO GENTLEMEN OF VERONA ACT IV.'
#  'MEASURE FOR MEASURE ACT II.'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT II.'
#  'THE TAMING OF THE SHREW ACT V. ' 'THE TRAGEDY OF JULIUS CAESAR ACT IV.'
#  'THE LIFE OF TIMON OF ATHENS ACT III']
#
#
# [9, 38, 66, 92, 101, 117]
# ['THE TRAGEDY OF MACBETH ACT I. ' 'THE TRAGEDY OF MACBETH ACT IV.'
#  'ALLS WELL THAT ENDS WELL ACT IV ' "LOVE'S LABOUR'S LOST ACT II."
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT III'
#  'THE FIRST PART OF HENRY THE SIXTH ACT II.']
#
#
# [40, 46, 70, 73, 77, 113, 123, 179]
# ['THE FIRST PART OF KING HENRY THE FOURTH ACT III'
#  "A MIDSUMMER NIGHT'S DREAM ACT I. "
#  'THE FIRST PART OF HENRY THE SIXTH ACT IV.'
#  'THE LIFE OF KING HENRY THE FIFTH ACT II.'
#  'KING RICHARD THE SECOND ACT IV.'
#  'THE LIFE OF KING HENRY THE FIFTH ACT V. '
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT I. '
#  'KING HENRY THE EIGHTH ACT II.']
#
#
# [0, 34, 44, 119, 130, 155, 161]
# ["LOVE'S LABOUR'S LOST ACT V. " 'THE TRAGEDY OF JULIUS CAESAR ACT II.'
#  'AS YOU LIKE IT ACT V. ' 'MEASURE FOR MEASURE ACT III'
#  'THE COMEDY OF ERRORS ACT IV.' 'THE TRAGEDY OF CORIOLANUS ACT IV.'
#  'THE LIFE OF KING HENRY THE FIFTH ACT IV.']
#
#
# [1, 41, 52, 71, 99, 170, 181]
# ['TWELFTH NIGHT; OR, WHAT YOU WILL ACT I. '
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I. '
#  'THE MERCHANT OF VENICE ACT IV.' 'THE TRAGEDY OF MACBETH ACT II.'
#  'MUCH ADO ABOUT NOTHING ACT II.' 'MEASURE FOR MEASURE ACT I. '
#  'ALLS WELL THAT ENDS WELL ACT IV.']
#
#
# [19, 31, 35, 53, 85, 87, 93, 111, 162, 164, 169, 177]
# ['KING RICHARD III ACT II.' 'THE COMEDY OF ERRORS ACT V. '
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT II.'
#  "A MIDSUMMER NIGHT'S DREAM ACT III"
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT IV.'
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT V. '
#  "THE WINTER'S TALE ACT II." 'THE HISTORY OF TROILUS AND CRESSIDA ACT IV.'
#  "THE WINTER'S TALE ACT I. " 'THE TAMING OF THE SHREW ACT III'
#  'THE TAMING OF THE SHREW ACT Il.' 'THE TRAGEDY OF JULIUS CAESAR ACT I. ']
#
#
# [57, 63, 65, 82, 112, 114, 178]
# ['CYMBELINE ACT I. ' 'MUCH ADO ABOUT NOTHING ACT I. '
#  'THE MERCHANT OF VENICE ACT V. ' 'THE MERCHANT OF VENICE ACT III'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT IV.'
#  'AS YOU LIKE IT ACT III' "THE WINTER'S TALE ACT V. "]
#
#
# [58, 61, 100, 104, 108, 116, 139, 159, 171]
# ['KING HENRY THE EIGHTH ACT IV.' 'THE TWO GENTLEMEN OF VERONA ACT V. '
#  'ALLS WELL THAT ENDS WELL ACT I. ' 'ALLS WELL THAT ENDS WELL ACT II.'
#  'THE TEMPEST ACT V. ' 'THE TEMPEST ACT IV.' 'KING JOHN ACT I. '
#  'THE LIFE OF TIMON OF ATHENS ACT II.' 'THE TEMPEST ACT III']
#
#
# 118
# ALLS WELL THAT ENDS WELL ACT V.
#
#
# [6, 21, 24, 33, 80, 84, 90, 98, 109, 146, 154, 160, 163, 165, 175]
# ['MUCH ADO ABOUT NOTHING ACT V. ' 'ALLS WELL THAT ENDS WELL ACT V S'
#  'AS YOU LIKE IT ACT IV.' 'THE TWO GENTLEMEN OF VERONA ACT II.'
#  'SECOND PART OF KING HENRY IV ACT II.'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III'
#  'SECOND PART OF KING HENRY IV ACT III'
#  'THE MERRY WIVES OF WINDSOR ACT I. '
#  'THE TRAGEDY OF ROMEO AND JULIET ACT III'
#  'THE TRAGEDY OF CORIOLANUS ACT III' 'THE MERRY WIVES OF WINDSOR ACT II.'
#  'MEASURE FOR MEASURE ACT V. ' 'THE TRAGEDY OF MACBETH ACT III'
#  'THE TRAGEDY OF CORIOLANUS ACT I. ' 'THE TEMPEST ACT II.']
#
#
# [14, 81, 95]
# ['KING RICHARD THE SECOND ACT III' 'KING RICHARD THE SECOND ACT I. '
#  'KING JOHN ACT II.']
#
#
# [15, 49, 50, 55, 91, 121, 136, 143, 148]
# ['THE FIRST PART OF KING HENRY THE FOURTH ACT II.'
#  'KING RICHARD III ACT IV.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT I. '
#  'THE TRAGEDY OF CORIOLANUS ACT II.' 'THE MERRY WIVES OF WINDSOR ACT V. '
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT V. '
#  "THE WINTER'S TALE ACT IV." 'THE TRAGEDY OF CORIOLANUS ACT V. '
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT I. ']
#
#
# [2, 5, 11, 13, 30, 94, 107, 138, 145]
# ['CYMBELINE ACT V. ' 'SECOND PART OF KING HENRY IV ACT I. '
#  'KING RICHARD III ACT I. ' 'THE TRAGEDY OF ROMEO AND JULIET ACT II.'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT V. ' 'CYMBELINE ACT IV.'
#  'CYMBELINE ACT II.' 'CYMBELINE ACT III' 'THE TAMING OF THE SHREW ACT I. ']
#
#
# [12, 59]
# ['THE HISTORY OF TROILUS AND CRESSIDA ACT V. '
#  'ALLS WELL THAT ENDS WELL ACT III']
#
#
# 25
# THE SONNETS ACT1609
#
#
# [43, 67, 86, 102, 151, 153, 173, 176]
# ['THE SECOND PART OF KING HENRY THE SIXTH ACT I. '
#  "A MIDSUMMER NIGHT'S DREAM ACT IV." "LOVE'S LABOUR'S LOST ACT III"
#  "LOVE'S LABOUR'S LOST ACT IV." "A MIDSUMMER NIGHT'S DREAM ACT II."
#  'THE FIRST PART OF HENRY THE SIXTH ACT V. '
#  'THE MERCHANT OF VENICE ACT I. '
#  'THE FIRST PART OF HENRY THE SIXTH ACT III']
#
#
# [10, 26, 27, 29, 45, 48, 54, 74, 78, 110, 115, 147, 150, 156, 158]
# ['SECOND PART OF KING HENRY IV ACT IV.' 'KING JOHN ACT III'
#  'THE MERCHANT OF VENICE ACT II.' 'THE TWO GENTLEMEN OF VERONA ACT III'
#  'AS YOU LIKE IT ACT II.' "THE WINTER'S TALE ACT III"
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT III'
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT V. '
#  'THE FIRST PART OF HENRY THE SIXTH ACT I. '
#  'THE TRAGEDY OF ROMEO AND JULIET ACT V. '
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT III'
#  'KING RICHARD THE SECOND ACT V. '
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT V. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT IV.']
#
#
# [47, 51, 56, 96, 105, 126]
# ["LOVE'S LABOUR'S LOST ACT I. " 'KING RICHARD THE SECOND ACT II.'
#  "A MIDSUMMER NIGHT'S DREAM ACT V. "
#  'THE LIFE OF KING HENRY THE FIFTH ACT III'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT II.'
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT III']
#
#
# [8, 17, 23, 32, 69, 72, 83, 122, 142, 166]
# ['KING HENRY THE EIGHTH ACT I. ' 'THE TRAGEDY OF JULIUS CAESAR ACT V. '
#  'THE TRAGEDY OF KING LEAR ACT II.' 'THE MERRY WIVES OF WINDSOR ACT III'
#  'THE LIFE OF TIMON OF ATHENS ACT I. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.'
#  'THE TRAGEDY OF ROMEO AND JULIET ACT IV.'
#  'SECOND PART OF KING HENRY IV ACT V. '
#  'THE MERRY WIVES OF WINDSOR ACT IV.' 'THE TRAGEDY OF KING LEAR ACT III']
#
#
# [4, 18, 60, 62, 75, 88, 97, 131, 133, 157]
# ['THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT V. '
#  'THE TRAGEDY OF JULIUS CAESAR ACT III' 'KING RICHARD III ACT III'
#  'THE COMEDY OF ERRORS ACT III'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT I. '
#  'THE COMEDY OF ERRORS ACT Il.'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT V. ' 'AS YOU LIKE IT ACT I. '
#  'MUCH ADO ABOUT NOTHING ACT III']
#
#
# 89
# A LOVER'S COMPLAINT ACT1609
#
#
# [22, 120, 125, 127, 135, 137, 141, 144, 174, 180]
# ['THE TRAGEDY OF MACBETH ACT V. ' 'THE TRAGEDY OF KING LEAR ACT IV.'
#  'THE TRAGEDY OF KING LEAR ACT I. '
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT III'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT II.'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V. '
#  'THE TRAGEDY OF ROMEO AND JULIET ACT I. '
#  'THE TWO GENTLEMEN OF VERONA ACT I. '
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT II.'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.']
#
#
# [36, 39, 42, 64, 76, 79, 106, 134, 168]
# ['KING RICHARD III ACT V. ' 'KING HENRY THE EIGHTH ACT III'
#  'KING JOHN ACT V. ' 'KING JOHN ACT IV.'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT IV.' 'THE TEMPEST ACT I. '
#  'THE LIFE OF TIMON OF ATHENS ACT IV.'
#  'THE LIFE OF TIMON OF ATHENS ACT V. '
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT IV.']
#
#
# [7, 16, 103, 152]
# ['THE HISTORY OF TROILUS AND CRESSIDA ACT I. '
#  'THE LIFE OF KING HENRY THE FIFTH ACT I. ' 'THE COMEDY OF ERRORS ACT I. '
#  'KING HENRY THE EIGHTH ACT V. ']
#
#
# [132, 149]
# ['THE SECOND PART OF KING HENRY THE SIXTH ACT II.'
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT 1. ']
# /Users/byan/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %% [markdown]
# > By adding the features of average sentence length, number of unique words normalized by total number of words, fequency of conjunctions, and etc., acts are clustered according to the writing style (need to be verified by visualization).

# %% [markdown]
# ### Affinity Propagation

# %%
print('No mormalization')
clusterDocuments(X, scaled = False, PCA_X=False, method = 'AffinityPropagation', visualize = 'None', verbose = False)
print('Normalize to N(0,1)')
clusterDocuments(X, scaled = True, method = 'AffinityPropagation', visualize = 'None', verbose = False)
# Out:
# No mormalization
# Number of clusters:  18
# Silhouette Coefficient: 0.147
# Normalize to N(0,1)
# Number of clusters:  26
# Silhouette Coefficient: 0.070
# /Users/byan/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
clusterDocuments(X, scaled = True, PCA_X = True, method = 'AffinityPropagation')
# Out:
# Number of clusters:  26
# Silhouette Coefficient: 0.070
# [0, 32, 34, 80, 102, 119, 122, 130, 142, 154, 161]
# ["LOVE'S LABOUR'S LOST ACT V. " 'THE MERRY WIVES OF WINDSOR ACT III'
#  'THE TRAGEDY OF JULIUS CAESAR ACT II.'
#  'SECOND PART OF KING HENRY IV ACT II.' "LOVE'S LABOUR'S LOST ACT IV."
#  'MEASURE FOR MEASURE ACT III' 'SECOND PART OF KING HENRY IV ACT V. '
#  'THE COMEDY OF ERRORS ACT IV.' 'THE MERRY WIVES OF WINDSOR ACT IV.'
#  'THE MERRY WIVES OF WINDSOR ACT II.'
#  'THE LIFE OF KING HENRY THE FIFTH ACT IV.']
#
#
# [12, 59]
# ['THE HISTORY OF TROILUS AND CRESSIDA ACT V. '
#  'ALLS WELL THAT ENDS WELL ACT III']
#
#
# 25
# THE SONNETS ACT1609
#
#
# [17, 49, 50, 72, 85, 105, 121, 166]
# ['THE TRAGEDY OF JULIUS CAESAR ACT V. ' 'KING RICHARD III ACT IV.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT I. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT IV.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT II.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT V. '
#  'THE TRAGEDY OF KING LEAR ACT III']
#
#
# [1, 4, 6, 33, 37, 60, 62, 137, 157]
# ['TWELFTH NIGHT; OR, WHAT YOU WILL ACT I. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III'
#  'MUCH ADO ABOUT NOTHING ACT V. ' 'THE TWO GENTLEMEN OF VERONA ACT II.'
#  'THE TAMING OF THE SHREW ACT IV.' 'THE TRAGEDY OF JULIUS CAESAR ACT III'
#  'KING RICHARD III ACT III'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V. '
#  'MUCH ADO ABOUT NOTHING ACT III']
#
#
# [20, 68, 128, 140, 155, 167, 172, 177]
# ['THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT III'
#  'MUCH ADO ABOUT NOTHING ACT IV.' 'MEASURE FOR MEASURE ACT II.'
#  'THE TAMING OF THE SHREW ACT V. ' 'THE TRAGEDY OF CORIOLANUS ACT IV.'
#  'THE TRAGEDY OF JULIUS CAESAR ACT IV.'
#  'THE LIFE OF TIMON OF ATHENS ACT III'
#  'THE TRAGEDY OF JULIUS CAESAR ACT I. ']
#
#
# [40, 46, 70, 73, 77, 93, 123, 179]
# ['THE FIRST PART OF KING HENRY THE FOURTH ACT III'
#  "A MIDSUMMER NIGHT'S DREAM ACT I. "
#  'THE FIRST PART OF HENRY THE SIXTH ACT IV.'
#  'THE LIFE OF KING HENRY THE FIFTH ACT II.'
#  'KING RICHARD THE SECOND ACT IV.' "THE WINTER'S TALE ACT II."
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT I. '
#  'KING HENRY THE EIGHTH ACT II.']
#
#
# [14, 26, 35, 48, 74, 115, 117, 132, 147, 149, 158, 168]
# ['KING RICHARD THE SECOND ACT III' 'KING JOHN ACT III'
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT II.' "THE WINTER'S TALE ACT III"
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT V. '
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT III'
#  'THE FIRST PART OF HENRY THE SIXTH ACT II.'
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT II.'
#  'KING RICHARD THE SECOND ACT V. '
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT 1. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT IV.'
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT IV.']
#
#
# [18, 19, 28, 88, 120, 131, 133, 174]
# ['THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT V. '
#  'KING RICHARD III ACT II.' 'THE TRAGEDY OF KING LEAR ACT V. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT I. '
#  'THE TRAGEDY OF KING LEAR ACT IV.'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT V. ' 'AS YOU LIKE IT ACT I. '
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT II.']
#
#
# 89
# A LOVER'S COMPLAINT ACT1609
#
#
# [2, 11, 13, 30, 67, 94, 107, 111, 145]
# ['CYMBELINE ACT V. ' 'KING RICHARD III ACT I. '
#  'THE TRAGEDY OF ROMEO AND JULIET ACT II.'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT V. '
#  "A MIDSUMMER NIGHT'S DREAM ACT IV." 'CYMBELINE ACT IV.'
#  'CYMBELINE ACT II.' 'THE HISTORY OF TROILUS AND CRESSIDA ACT IV.'
#  'THE TAMING OF THE SHREW ACT I. ']
#
#
# [36, 42, 81, 95]
# ['KING RICHARD III ACT V. ' 'KING JOHN ACT V. '
#  'KING RICHARD THE SECOND ACT I. ' 'KING JOHN ACT II.']
#
#
# [5, 44, 47, 56, 66, 96]
# ['SECOND PART OF KING HENRY IV ACT I. ' 'AS YOU LIKE IT ACT V. '
#  "LOVE'S LABOUR'S LOST ACT I. " "A MIDSUMMER NIGHT'S DREAM ACT V. "
#  'ALLS WELL THAT ENDS WELL ACT IV '
#  'THE LIFE OF KING HENRY THE FIFTH ACT III']
#
#
# [31, 75, 97, 113]
# ['THE COMEDY OF ERRORS ACT V. ' 'THE COMEDY OF ERRORS ACT III'
#  'THE COMEDY OF ERRORS ACT Il.' 'THE LIFE OF KING HENRY THE FIFTH ACT V. ']
#
#
# [7, 16, 103, 152]
# ['THE HISTORY OF TROILUS AND CRESSIDA ACT I. '
#  'THE LIFE OF KING HENRY THE FIFTH ACT I. ' 'THE COMEDY OF ERRORS ACT I. '
#  'KING HENRY THE EIGHTH ACT V. ']
#
#
# [21, 45, 57, 63, 65, 82, 112, 114, 124, 127, 138, 169, 178]
# ['ALLS WELL THAT ENDS WELL ACT V S' 'AS YOU LIKE IT ACT II.'
#  'CYMBELINE ACT I. ' 'MUCH ADO ABOUT NOTHING ACT I. '
#  'THE MERCHANT OF VENICE ACT V. ' 'THE MERCHANT OF VENICE ACT III'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT IV.'
#  'AS YOU LIKE IT ACT III' 'THE TWO GENTLEMEN OF VERONA ACT IV.'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT III' 'CYMBELINE ACT III'
#  'THE TAMING OF THE SHREW ACT Il.' "THE WINTER'S TALE ACT V. "]
#
#
# 118
# ALLS WELL THAT ENDS WELL ACT V.
#
#
# [51, 126, 162]
# ['KING RICHARD THE SECOND ACT II.'
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT III'
#  "THE WINTER'S TALE ACT I. "]
#
#
# [9, 39, 64, 76, 87, 92, 100, 101, 110, 134]
# ['THE TRAGEDY OF MACBETH ACT I. ' 'KING HENRY THE EIGHTH ACT III'
#  'KING JOHN ACT IV.' 'THE FIRST PART OF KING HENRY THE FOURTH ACT IV.'
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT V. '
#  "LOVE'S LABOUR'S LOST ACT II." 'ALLS WELL THAT ENDS WELL ACT I. '
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT III'
#  'THE TRAGEDY OF ROMEO AND JULIET ACT V. '
#  'THE LIFE OF TIMON OF ATHENS ACT V. ']
#
#
# [15, 55, 84, 91, 136, 143, 148]
# ['THE FIRST PART OF KING HENRY THE FOURTH ACT II.'
#  'THE TRAGEDY OF CORIOLANUS ACT II.'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III'
#  'THE MERRY WIVES OF WINDSOR ACT V. ' "THE WINTER'S TALE ACT IV."
#  'THE TRAGEDY OF CORIOLANUS ACT V. '
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT I. ']
#
#
# [22, 69, 125, 135, 141, 144, 156]
# ['THE TRAGEDY OF MACBETH ACT V. ' 'THE LIFE OF TIMON OF ATHENS ACT I. '
#  'THE TRAGEDY OF KING LEAR ACT I. '
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT II.'
#  'THE TRAGEDY OF ROMEO AND JULIET ACT I. '
#  'THE TWO GENTLEMEN OF VERONA ACT I. '
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT V. ']
#
#
# [43, 86, 151, 153, 170, 173, 176]
# ['THE SECOND PART OF KING HENRY THE SIXTH ACT I. '
#  "LOVE'S LABOUR'S LOST ACT III" "A MIDSUMMER NIGHT'S DREAM ACT II."
#  'THE FIRST PART OF HENRY THE SIXTH ACT V. ' 'MEASURE FOR MEASURE ACT I. '
#  'THE MERCHANT OF VENICE ACT I. '
#  'THE FIRST PART OF HENRY THE SIXTH ACT III']
#
#
# [3, 10, 24, 41, 90, 98, 99, 109, 160, 163, 165]
# ['THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.'
#  'SECOND PART OF KING HENRY IV ACT IV.' 'AS YOU LIKE IT ACT IV.'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I. '
#  'SECOND PART OF KING HENRY IV ACT III'
#  'THE MERRY WIVES OF WINDSOR ACT I. ' 'MUCH ADO ABOUT NOTHING ACT II.'
#  'THE TRAGEDY OF ROMEO AND JULIET ACT III' 'MEASURE FOR MEASURE ACT V. '
#  'THE TRAGEDY OF MACBETH ACT III' 'THE TRAGEDY OF CORIOLANUS ACT I. ']
#
#
# [53, 58, 79, 104, 108, 116, 139, 159, 164, 171]
# ["A MIDSUMMER NIGHT'S DREAM ACT III" 'KING HENRY THE EIGHTH ACT IV.'
#  'THE TEMPEST ACT I. ' 'ALLS WELL THAT ENDS WELL ACT II.'
#  'THE TEMPEST ACT V. ' 'THE TEMPEST ACT IV.' 'KING JOHN ACT I. '
#  'THE LIFE OF TIMON OF ATHENS ACT II.' 'THE TAMING OF THE SHREW ACT III'
#  'THE TEMPEST ACT III']
#
#
# [8, 23, 27, 29, 38, 54, 61, 78, 83, 106, 129, 146, 150, 175, 180]
# ['KING HENRY THE EIGHTH ACT I. ' 'THE TRAGEDY OF KING LEAR ACT II.'
#  'THE MERCHANT OF VENICE ACT II.' 'THE TWO GENTLEMEN OF VERONA ACT III'
#  'THE TRAGEDY OF MACBETH ACT IV.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT III'
#  'THE TWO GENTLEMEN OF VERONA ACT V. '
#  'THE FIRST PART OF HENRY THE SIXTH ACT I. '
#  'THE TRAGEDY OF ROMEO AND JULIET ACT IV.'
#  'THE LIFE OF TIMON OF ATHENS ACT IV.'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT II.'
#  'THE TRAGEDY OF CORIOLANUS ACT III'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.' 'THE TEMPEST ACT II.'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.']
#
#
# [52, 71, 181]
# ['THE MERCHANT OF VENICE ACT IV.' 'THE TRAGEDY OF MACBETH ACT II.'
#  'ALLS WELL THAT ENDS WELL ACT IV.']
# /Users/byan/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
clusterDocuments(X, scaled = True, method = 'AffinityPropagation', visualize = 'PCA', verbose = False)
clusterDocuments(X, scaled = True, method = 'AffinityPropagation', visualize = 'MDS', verbose = False)
# Out:
# Number of clusters:  26
# Silhouette Coefficient: 0.070
# /Users/byan/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# Number of clusters:  26
# Silhouette Coefficient: 0.070

# %%
#clusterDocuments(X, n_clusters = 8, scaled = True, PCA_X = True, method = 'SpectralClustering', verbose = False)
clusterDocuments(X, scaled = True, method = 'Birch', n_labels = 13)
#clusterDocuments(X, scaled = True, PCA_X = True, method = 'DBSCAN')
clusterDocuments(X, scaled = True, PCA_X = True, method = 'MeanShift', verbose = False)
# Out:
# Number of clusters:  3
# Silhouette Coefficient: 0.104
# [7, 10, 14, 16, 25, 26, 36, 40, 42, 43, 45, 46, 48, 54, 56, 62, 70, 73, 74, 75, 77, 78, 81, 82, 84, 89, 95, 97, 103, 105, 121, 123, 132, 147, 149, 150, 151, 152, 153, 156, 158, 168, 170, 173, 176, 179]
# ['THE HISTORY OF TROILUS AND CRESSIDA ACT I. '
#  'SECOND PART OF KING HENRY IV ACT IV.' 'KING RICHARD THE SECOND ACT III'
#  'THE LIFE OF KING HENRY THE FIFTH ACT I. ' 'THE SONNETS ACT1609'
#  'KING JOHN ACT III' 'KING RICHARD III ACT V. '
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT III' 'KING JOHN ACT V. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT I. ' 'AS YOU LIKE IT ACT II.'
#  "A MIDSUMMER NIGHT'S DREAM ACT I. " "THE WINTER'S TALE ACT III"
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT III'
#  "A MIDSUMMER NIGHT'S DREAM ACT V. " 'KING RICHARD III ACT III'
#  'THE FIRST PART OF HENRY THE SIXTH ACT IV.'
#  'THE LIFE OF KING HENRY THE FIFTH ACT II.'
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT V. ' 'THE COMEDY OF ERRORS ACT III'
#  'KING RICHARD THE SECOND ACT IV.'
#  'THE FIRST PART OF HENRY THE SIXTH ACT I. '
#  'KING RICHARD THE SECOND ACT I. ' 'THE MERCHANT OF VENICE ACT III'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III'
#  "A LOVER'S COMPLAINT ACT1609" 'KING JOHN ACT II.'
#  'THE COMEDY OF ERRORS ACT Il.' 'THE COMEDY OF ERRORS ACT I. '
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT II.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT V. '
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT I. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT II.'
#  'KING RICHARD THE SECOND ACT V. '
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT 1. '
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.'
#  "A MIDSUMMER NIGHT'S DREAM ACT II." 'KING HENRY THE EIGHTH ACT V. '
#  'THE FIRST PART OF HENRY THE SIXTH ACT V. '
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT V. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT IV.'
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT IV.' 'MEASURE FOR MEASURE ACT I. '
#  'THE MERCHANT OF VENICE ACT I. '
#  'THE FIRST PART OF HENRY THE SIXTH ACT III'
#  'KING HENRY THE EIGHTH ACT II.']
#
#
# [0, 1, 2, 3, 4, 5, 6, 8, 11, 13, 15, 17, 18, 19, 20, 21, 22, 23, 24, 27, 28, 30, 31, 32, 33, 34, 35, 37, 41, 44, 47, 49, 50, 51, 52, 53, 55, 57, 60, 63, 65, 67, 68, 69, 71, 72, 79, 80, 83, 85, 86, 88, 90, 91, 93, 94, 96, 98, 99, 102, 106, 107, 109, 110, 111, 112, 113, 114, 115, 119, 120, 122, 124, 125, 126, 127, 128, 129, 130, 131, 133, 135, 136, 137, 138, 140, 141, 142, 143, 144, 145, 146, 148, 154, 155, 157, 160, 161, 163, 164, 165, 166, 167, 169, 172, 177, 178, 181]
# ["LOVE'S LABOUR'S LOST ACT V. " 'TWELFTH NIGHT; OR, WHAT YOU WILL ACT I. '
#  'CYMBELINE ACT V. ' 'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III'
#  'SECOND PART OF KING HENRY IV ACT I. ' 'MUCH ADO ABOUT NOTHING ACT V. '
#  'KING HENRY THE EIGHTH ACT I. ' 'KING RICHARD III ACT I. '
#  'THE TRAGEDY OF ROMEO AND JULIET ACT II.'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT II.'
#  'THE TRAGEDY OF JULIUS CAESAR ACT V. '
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT V. '
#  'KING RICHARD III ACT II.'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT III'
#  'ALLS WELL THAT ENDS WELL ACT V S' 'THE TRAGEDY OF MACBETH ACT V. '
#  'THE TRAGEDY OF KING LEAR ACT II.' 'AS YOU LIKE IT ACT IV.'
#  'THE MERCHANT OF VENICE ACT II.' 'THE TRAGEDY OF KING LEAR ACT V. '
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT V. ' 'THE COMEDY OF ERRORS ACT V. '
#  'THE MERRY WIVES OF WINDSOR ACT III' 'THE TWO GENTLEMEN OF VERONA ACT II.'
#  'THE TRAGEDY OF JULIUS CAESAR ACT II.'
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT II.'
#  'THE TAMING OF THE SHREW ACT IV.'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I. ' 'AS YOU LIKE IT ACT V. '
#  "LOVE'S LABOUR'S LOST ACT I. " 'KING RICHARD III ACT IV.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT I. '
#  'KING RICHARD THE SECOND ACT II.' 'THE MERCHANT OF VENICE ACT IV.'
#  "A MIDSUMMER NIGHT'S DREAM ACT III" 'THE TRAGEDY OF CORIOLANUS ACT II.'
#  'CYMBELINE ACT I. ' 'THE TRAGEDY OF JULIUS CAESAR ACT III'
#  'MUCH ADO ABOUT NOTHING ACT I. ' 'THE MERCHANT OF VENICE ACT V. '
#  "A MIDSUMMER NIGHT'S DREAM ACT IV." 'MUCH ADO ABOUT NOTHING ACT IV.'
#  'THE LIFE OF TIMON OF ATHENS ACT I. ' 'THE TRAGEDY OF MACBETH ACT II.'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.' 'THE TEMPEST ACT I. '
#  'SECOND PART OF KING HENRY IV ACT II.'
#  'THE TRAGEDY OF ROMEO AND JULIET ACT IV.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT IV.'
#  "LOVE'S LABOUR'S LOST ACT III"
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT I. '
#  'SECOND PART OF KING HENRY IV ACT III'
#  'THE MERRY WIVES OF WINDSOR ACT V. ' "THE WINTER'S TALE ACT II."
#  'CYMBELINE ACT IV.' 'THE LIFE OF KING HENRY THE FIFTH ACT III'
#  'THE MERRY WIVES OF WINDSOR ACT I. ' 'MUCH ADO ABOUT NOTHING ACT II.'
#  "LOVE'S LABOUR'S LOST ACT IV." 'THE LIFE OF TIMON OF ATHENS ACT IV.'
#  'CYMBELINE ACT II.' 'THE TRAGEDY OF ROMEO AND JULIET ACT III'
#  'THE TRAGEDY OF ROMEO AND JULIET ACT V. '
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT IV.'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT IV.'
#  'THE LIFE OF KING HENRY THE FIFTH ACT V. ' 'AS YOU LIKE IT ACT III'
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT III' 'MEASURE FOR MEASURE ACT III'
#  'THE TRAGEDY OF KING LEAR ACT IV.' 'SECOND PART OF KING HENRY IV ACT V. '
#  'THE TWO GENTLEMEN OF VERONA ACT IV.' 'THE TRAGEDY OF KING LEAR ACT I. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT III'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT III' 'MEASURE FOR MEASURE ACT II.'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT II.'
#  'THE COMEDY OF ERRORS ACT IV.'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT V. ' 'AS YOU LIKE IT ACT I. '
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT II.' "THE WINTER'S TALE ACT IV."
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V. ' 'CYMBELINE ACT III'
#  'THE TAMING OF THE SHREW ACT V. '
#  'THE TRAGEDY OF ROMEO AND JULIET ACT I. '
#  'THE MERRY WIVES OF WINDSOR ACT IV.' 'THE TRAGEDY OF CORIOLANUS ACT V. '
#  'THE TWO GENTLEMEN OF VERONA ACT I. ' 'THE TAMING OF THE SHREW ACT I. '
#  'THE TRAGEDY OF CORIOLANUS ACT III'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT I. '
#  'THE MERRY WIVES OF WINDSOR ACT II.' 'THE TRAGEDY OF CORIOLANUS ACT IV.'
#  'MUCH ADO ABOUT NOTHING ACT III' 'MEASURE FOR MEASURE ACT V. '
#  'THE LIFE OF KING HENRY THE FIFTH ACT IV.'
#  'THE TRAGEDY OF MACBETH ACT III' 'THE TAMING OF THE SHREW ACT III'
#  'THE TRAGEDY OF CORIOLANUS ACT I. ' 'THE TRAGEDY OF KING LEAR ACT III'
#  'THE TRAGEDY OF JULIUS CAESAR ACT IV.' 'THE TAMING OF THE SHREW ACT Il.'
#  'THE LIFE OF TIMON OF ATHENS ACT III'
#  'THE TRAGEDY OF JULIUS CAESAR ACT I. ' "THE WINTER'S TALE ACT V. "
#  'ALLS WELL THAT ENDS WELL ACT IV.']
#
#
# [9, 12, 29, 38, 39, 58, 59, 61, 64, 66, 76, 87, 92, 100, 101, 104, 108, 116, 117, 118, 134, 139, 159, 162, 171, 174, 175, 180]
# ['THE TRAGEDY OF MACBETH ACT I. '
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT V. '
#  'THE TWO GENTLEMEN OF VERONA ACT III' 'THE TRAGEDY OF MACBETH ACT IV.'
#  'KING HENRY THE EIGHTH ACT III' 'KING HENRY THE EIGHTH ACT IV.'
#  'ALLS WELL THAT ENDS WELL ACT III' 'THE TWO GENTLEMEN OF VERONA ACT V. '
#  'KING JOHN ACT IV.' 'ALLS WELL THAT ENDS WELL ACT IV '
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT IV.'
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT V. '
#  "LOVE'S LABOUR'S LOST ACT II." 'ALLS WELL THAT ENDS WELL ACT I. '
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT III'
#  'ALLS WELL THAT ENDS WELL ACT II.' 'THE TEMPEST ACT V. '
#  'THE TEMPEST ACT IV.' 'THE FIRST PART OF HENRY THE SIXTH ACT II.'
#  'ALLS WELL THAT ENDS WELL ACT V. ' 'THE LIFE OF TIMON OF ATHENS ACT V. '
#  'KING JOHN ACT I. ' 'THE LIFE OF TIMON OF ATHENS ACT II.'
#  "THE WINTER'S TALE ACT I. " 'THE TEMPEST ACT III'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT II.' 'THE TEMPEST ACT II.'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.']
# Number of clusters:  6
# Silhouette Coefficient: 0.308
# /Users/byan/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
