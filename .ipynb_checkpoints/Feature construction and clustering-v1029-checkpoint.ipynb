# %% [markdown]
# ## Step 1 Construct features using NLTK

# %%
import nltk
from nltk.corpus import stopwords
import string
import json

# %matplotlib inline 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from __future__ import division

randomState = np.random.seed(2)


# Import works.json: title, words, sentences of 38 pieces
with open('works_v1028.json', 'r') as f:
    try:
        works = json.load(f)
    # if the file is empty the ValueError will be thrown
    except ValueError:
        works = {}

# %%
from nltk import FreqDist

def getFreqDist(words):
    nltk_text = nltk.Text(words)
    
    return FreqDist(nltk_text)

# %%
def getCountFrequency(words, freq):
    nltk_text = nltk.Text(words)
    freq_dist = FreqDist(nltk_text)
    
    count = 0
    for key,value in freq_dist.items():
        if value == freq:
            count += 1
    
    return count    

def getHapaxLegomena(words):
    return getCountFrequency(words, 1)

# %%
def getDisLegomena(words):
    return getCountFrequency(words, 2)

# %%
def getNumberUniqueWords(words):
    return len(getFreqDist(words))

# %%
def getWordLengthDistribution(words):
    result = FreqDist()
    for w in words:        
        result[len(w)] += 1
    
    return result

def printFreqDist(freq_dist):
    for key,value in freq_dist.items():
        print (key,value)

# %%
def getSentenceLengthDistribution(sents):
    result = FreqDist()
    for s in sents:        
        result[len(s)] += 1
    
    return result

# %%
def getAverageSentenceLength(words_all, sents):
    
    return len(words_all)/len(sents)

# %%
def getPronounDistribution(sents):
    result = FreqDist()
    pronouns = ['I', 'you', 'he', 'she', 'it', 'we', 'you', 'they', 'thou', 'ye']
    for s in sents:
        count = 0
        for p in pronouns:
            count += s.count(p)
        result[count] += 1
    
    return result

# %%
def getNumberOfPronoun(words):
    pronouns = ['I', 'you', 'he', 'she', 'it', 'we', 'you', 'they', 'thou', 'ye']
    count = 0
         
    for p in pronouns:
        count += words.count(p)
    
    return count

# %%
def getConjunctionDistribution(sents):
    result = FreqDist()
    conjunctions = ['for', 'and', 'nor', 'but', 'or', 'yet', 'so', 'after', 'although', 'as', 'because', 'before', 'if',
                'once', 'since', 'though', 'unless', 'until', 'when', 'where', 'while', 'whether', 'either', 'neither',
                'as', 'than', 'even', 'then', 'lest', 'rather', 'which', 'who', 'why', 'that', 'till']
    for s in sents:
        count = 0
        for c in conjunctions:
            count += s.count(c)
        result[count] += 1
    
    return result

# %%
def getNumberOfConjunction(words):
    count = 0
    conjunctions = ['for', 'and', 'nor', 'but', 'or', 'yet', 'so', 'after', 'although', 'as', 'because', 'before', 'if',
                'once', 'since', 'though', 'unless', 'until', 'when', 'where', 'while', 'whether', 'either', 'neither',
                'as', 'than', 'even', 'then', 'lest', 'rather', 'which', 'who', 'why', 'that', 'till']

    for c in conjunctions:
        count += words.count(c)
    
    return count

# %%
def getNumberOfComma(text):
    return text.count(",")

def getNumberOfDots(text):
    return text.count(".")

def getNumberOfStringList(words, string_list):
    count = 0
    
    for c in string_list:
        count += words.count(c)
    
    return count

def getNumberOfThe(words):
    string_list = ['a', 'an', 'the']
    
    return getNumberOfStringList(words, string_list)

def getNumberOfIn(words):
    string_list = ['in', 'on', 'to', 'of']
    
    return getNumberOfStringList(words, string_list)

def getNumberOfIs(words):
    string_list = ['is', 'are', 'was', 'were']
    
    return getNumberOfStringList(words, string_list)

# %%
# Create a feature table for all acts
# Currently only has some simple features

featureTable = {}

featureTable = {'act': [], 'filename': [], 'HapaxLegomena': [], 'DisLegomena': [], 
                'numberUniqueWords': [], 'averageSentenceLength': [], 'numberOfSentences': [],
                'numberOfPronoun': [], 'numberOfConjunction': [], 'numberOfComma': [], 'numberOfDots': [],
                'numberOfThe': [], 'numberOfIn': [], 'numberOfIs': []}


for act, content in works.items():
    words_nonStemmed = content['words_nonStemmed']
    words_all = content['words_all']
    sentences = content['sentences']
    # Normalize by number of all words
    normalizer = len(words_all)
    featureTable['act'].append(act)
    featureTable['filename'].append(content['filename'])
    featureTable['HapaxLegomena'].append(getHapaxLegomena(words_nonStemmed)/normalizer)
    featureTable['DisLegomena'].append(getDisLegomena(words_nonStemmed)/normalizer)
    featureTable['numberUniqueWords'].append(getNumberUniqueWords(words_nonStemmed)/normalizer)
    featureTable['averageSentenceLength'].append(getAverageSentenceLength(words_all, sentences))
    featureTable['numberOfSentences'].append(len(sentences))
    featureTable['numberOfPronoun'].append(getNumberOfPronoun(words_all)/normalizer)
    featureTable['numberOfConjunction'].append(getNumberOfConjunction(words_all)/normalizer)
    featureTable['numberOfComma'].append(getNumberOfComma(content['text'])/normalizer)
    featureTable['numberOfDots'].append(getNumberOfDots(content['text'])/normalizer)
    featureTable['numberOfThe'].append(getNumberOfThe(words_all)/normalizer)
    featureTable['numberOfIn'].append(getNumberOfIn(words_all)/normalizer)
    featureTable['numberOfIs'].append(getNumberOfIs(words_all)/normalizer)

print(len(featureTable['act']))


df = pd.DataFrame(featureTable)
df.set_index(['act'], inplace=True)
df.head()
# Out:
# 218
#                                                  DisLegomena  HapaxLegomena  \
# act
# THE LIFE OF KING HENRY THE FIFTH ACT II.            0.033048       0.129795
# THE TRAGEDY OF JULIUS CAESAR ACT I.                 0.028698       0.107619
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.            0.024525       0.149921
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.         0.023965       0.107621
# THE SECOND PART OF KING HENRY THE SIXTH ACT IV.     0.027801       0.099136
#
#                                                  averageSentenceLength  \
# act
# THE LIFE OF KING HENRY THE FIFTH ACT II.                     14.860051
# THE TRAGEDY OF JULIUS CAESAR ACT I.                          12.120083
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.                     10.318367
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.                   9.317614
# THE SECOND PART OF KING HENRY THE SIXTH ACT IV.              12.394428
#
#                                                 filename  numberOfComma  \
# act
# THE LIFE OF KING HENRY THE FIFTH ACT II.          11.txt       0.076884
# THE TRAGEDY OF JULIUS CAESAR ACT I.               17.txt       0.072942
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.          35.txt       0.071203
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.        3.txt       0.071152
# THE SECOND PART OF KING HENRY THE SIXTH ACT IV.   13.txt       0.068260
#
#                                                  numberOfConjunction  \
# act
# THE LIFE OF KING HENRY THE FIFTH ACT II.                    0.097774
# THE TRAGEDY OF JULIUS CAESAR ACT I.                         0.106252
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.                    0.089003
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.                 0.067877
# THE SECOND PART OF KING HENRY THE SIXTH ACT IV.             0.089909
#
#                                                  numberOfDots  numberOfIn  \
# act
# THE LIFE OF KING HENRY THE FIFTH ACT II.             0.057877    0.054966
# THE TRAGEDY OF JULIUS CAESAR ACT I.                  0.066792    0.043902
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.             0.077532    0.039161
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.          0.086335    0.032450
# THE SECOND PART OF KING HENRY THE SIXTH ACT IV.      0.065775    0.044600
#
#                                                  numberOfIs  numberOfPronoun  \
# act
# THE LIFE OF KING HENRY THE FIFTH ACT II.           0.016610         0.050685
# THE TRAGEDY OF JULIUS CAESAR ACT I.                0.020328         0.067988
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.           0.017405         0.046677
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.        0.014588         0.041084
# THE SECOND PART OF KING HENRY THE SIXTH ACT IV.    0.015379         0.040696
#
#                                                  numberOfSentences  \
# act
# THE LIFE OF KING HENRY THE FIFTH ACT II.                       393
# THE TRAGEDY OF JULIUS CAESAR ACT I.                            483
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.                       245
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.                    721
# THE SECOND PART OF KING HENRY THE SIXTH ACT IV.                682
#
#                                                  numberOfThe  \
# act
# THE LIFE OF KING HENRY THE FIFTH ACT II.            0.039041
# THE TRAGEDY OF JULIUS CAESAR ACT I.                 0.038948
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.            0.026108
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.         0.032599
# THE SECOND PART OF KING HENRY THE SIXTH ACT IV.     0.044954
#
#                                                  numberUniqueWords
# act
# THE LIFE OF KING HENRY THE FIFTH ACT II.                  0.202055
# THE TRAGEDY OF JULIUS CAESAR ACT I.                       0.171677
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.                  0.206487
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.               0.169098
# THE SECOND PART OF KING HENRY THE SIXTH ACT IV.           0.165740

# %%
# Filter out wierd acts, e.g. the beginning of a play

# df = df[df['averageSentenceLength'] < 30]

df.drop(["A MIDSUMMER NIGHT'S DREAM ACT1596","ALLS WELL THAT ENDS WELL ACT1603", "AS YOU LIKE IT ACT1601", 
              "CYMBELINE ACT1609","KING HENRY THE EIGHTH ACT1611","KING JOHN ACT1597","KING RICHARD III ACT1593",
             "KING RICHARD THE SECOND ACT1596", "LOVE'S LABOUR'S LOST ACT1595", "MEASURE FOR MEASURE ACT1605",
             "MUCH ADO ABOUT NOTHING ACT1599", "SECOND PART OF KING HENRY IV ACT1598", "THE COMEDY OF ERRORS ACT1593",
             "THE FIRST PART OF HENRY THE SIXTH ACT1592", "THE FIRST PART OF KING HENRY THE FOURTH ACT1598",
             "THE HISTORY OF TROILUS AND CRESSIDA ACT1602", "THE LIFE OF KING HENRY THE FIFTH ACT1599",
             "THE LIFE OF TIMON OF ATHENS ACT1608", "THE MERCHANT OF VENICE ACT1597", "THE MERRY WIVES OF WINDSOR ACT1601",
             "THE SECOND PART OF KING HENRY THE SIXTH ACT1591", "THE TAMING OF THE SHREW ACT1594", "THE TEMPEST ACT1612",
             "THE TRAGEDY OF ANTONY AND CLEOPATRA ACT1607", "THE TRAGEDY OF CORIOLANUS ACT1608",
              "THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT1604","THE TRAGEDY OF JULIUS CAESAR ACT1599",
             "THE TRAGEDY OF KING LEAR ACT1606", "THE TRAGEDY OF MACBETH ACT1606", 
              "THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT1605", "THE TRAGEDY OF ROMEO AND JULIET ACT1595",
             "THE TRAGEDY OF TITUS ANDRONICUS ACT1594", "THE TWO GENTLEMEN OF VERONA ACT1595", "THE WINTER'S TALE ACT1611",
             "TWELFTH NIGHT; OR, WHAT YOU WILL ACT1602", "THE THIRD PART OF KING HENRY THE SIXTH ACT1591"], inplace = True)

df_2 = df[['numberUniqueWords', 'averageSentenceLength']]
df_3 = df[['numberUniqueWords', 'averageSentenceLength', 'numberOfPronoun']]
df = df[['HapaxLegomena', 'DisLegomena', 'numberUniqueWords', 
        'averageSentenceLength', 'numberOfPronoun', 'numberOfConjunction', 'numberOfComma', 'numberOfDots',
                'numberOfThe', 'numberOfIn', 'numberOfIs']]

# %%
pd.scatter_matrix(df, alpha=0.2, figsize=(16, 16), diagonal='kde')
plt.show()
# Out:
# /Users/binyan/Python/anaconda/envs/py34/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# ## Step 2 Construct n-grams using sklearn

# %%
title = []
text = []

for act in df.index:
    content = works[act]
    title.append(act)
    text.append(content['text'])

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from __future__ import print_function

from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer
from sklearn import metrics

from sklearn.cluster import KMeans, MiniBatchKMeans, AffinityPropagation, AgglomerativeClustering, MeanShift, SpectralClustering, DBSCAN, Birch 
import numpy as np

# %%
# excluding stop words, n-grams is an input
def getTfidf(ngram_range):
    count_vect = CountVectorizer(ngram_range=ngram_range, stop_words='english')
    X_counts = count_vect.fit_transform(text)

    tfidf_transformer = TfidfTransformer(use_idf=True)
    X_tfidf = tfidf_transformer.fit_transform(X_counts)
    return X_tfidf

# %%
def getSVD(X_tfidf, n_components):
    
    svd = TruncatedSVD(n_components = n_components, random_state = randomState)
    lsa = make_pipeline(svd, Normalizer(copy=False))
    X = lsa.fit_transform(X_tfidf)

    explained_variance = svd.explained_variance_ratio_.sum()
    print("Explained variance of the SVD step: {}%".format(
        int(explained_variance * 100)))
    
    return X

# %%
# Features from n-grams, use fewer components
X_tfidf = getTfidf(ngram_range = (2,4))
X = getSVD(X_tfidf, n_components = 6)
df_ngrams = pd.DataFrame(data=X, index = title)
df_ngrams.head()
# Out:
# Explained variance of the SVD step: 4%
#                                                         0         1         2  \
# THE LIFE OF KING HENRY THE FIFTH ACT II.         0.468905  0.346807 -0.370043
# THE TRAGEDY OF JULIUS CAESAR ACT I.              0.263272  0.208835 -0.172346
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.         0.323953  0.621680  0.653068
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.      0.386276  0.258352 -0.382443
# THE SECOND PART OF KING HENRY THE SIXTH ACT IV.  0.405424  0.406324 -0.508192
#
#                                                         3         4         5
# THE LIFE OF KING HENRY THE FIFTH ACT II.        -0.554141 -0.387874 -0.255740
# THE TRAGEDY OF JULIUS CAESAR ACT I.              0.189764  0.708744 -0.564840
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.         0.213956 -0.092001  0.166823
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.      0.292639  0.739718 -0.070444
# THE SECOND PART OF KING HENRY THE SIXTH ACT IV. -0.605349 -0.056412 -0.206502

# %% [markdown]
# ## Step 3 Combine n-grams and other features

# %%
# Merge all features
df_all = df.join(df_ngrams)
df_all.head()
# Out:
#                                                  HapaxLegomena  DisLegomena  \
# act
# THE LIFE OF KING HENRY THE FIFTH ACT II.              0.129795     0.033048
# THE TRAGEDY OF JULIUS CAESAR ACT I.                   0.107619     0.028698
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.              0.149921     0.024525
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.           0.107621     0.023965
# THE SECOND PART OF KING HENRY THE SIXTH ACT IV.       0.099136     0.027801
#
#                                                  numberUniqueWords  \
# act
# THE LIFE OF KING HENRY THE FIFTH ACT II.                  0.202055
# THE TRAGEDY OF JULIUS CAESAR ACT I.                       0.171677
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.                  0.206487
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.               0.169098
# THE SECOND PART OF KING HENRY THE SIXTH ACT IV.           0.165740
#
#                                                  averageSentenceLength  \
# act
# THE LIFE OF KING HENRY THE FIFTH ACT II.                     14.860051
# THE TRAGEDY OF JULIUS CAESAR ACT I.                          12.120083
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.                     10.318367
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.                   9.317614
# THE SECOND PART OF KING HENRY THE SIXTH ACT IV.              12.394428
#
#                                                  numberOfPronoun  \
# act
# THE LIFE OF KING HENRY THE FIFTH ACT II.                0.050685
# THE TRAGEDY OF JULIUS CAESAR ACT I.                     0.067988
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.                0.046677
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.             0.041084
# THE SECOND PART OF KING HENRY THE SIXTH ACT IV.         0.040696
#
#                                                  numberOfConjunction  \
# act
# THE LIFE OF KING HENRY THE FIFTH ACT II.                    0.097774
# THE TRAGEDY OF JULIUS CAESAR ACT I.                         0.106252
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.                    0.089003
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.                 0.067877
# THE SECOND PART OF KING HENRY THE SIXTH ACT IV.             0.089909
#
#                                                  numberOfComma  numberOfDots  \
# act
# THE LIFE OF KING HENRY THE FIFTH ACT II.              0.076884      0.057877
# THE TRAGEDY OF JULIUS CAESAR ACT I.                   0.072942      0.066792
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.              0.071203      0.077532
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.           0.071152      0.086335
# THE SECOND PART OF KING HENRY THE SIXTH ACT IV.       0.068260      0.065775
#
#                                                  numberOfThe  numberOfIn  \
# act
# THE LIFE OF KING HENRY THE FIFTH ACT II.            0.039041    0.054966
# THE TRAGEDY OF JULIUS CAESAR ACT I.                 0.038948    0.043902
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.            0.026108    0.039161
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.         0.032599    0.032450
# THE SECOND PART OF KING HENRY THE SIXTH ACT IV.     0.044954    0.044600
#
#                                                  numberOfIs         0  \
# act
# THE LIFE OF KING HENRY THE FIFTH ACT II.           0.016610  0.468905
# THE TRAGEDY OF JULIUS CAESAR ACT I.                0.020328  0.263272
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.           0.017405  0.323953
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.        0.014588  0.386276
# THE SECOND PART OF KING HENRY THE SIXTH ACT IV.    0.015379  0.405424
#
#                                                         1         2         3  \
# act
# THE LIFE OF KING HENRY THE FIFTH ACT II.         0.346807 -0.370043 -0.554141
# THE TRAGEDY OF JULIUS CAESAR ACT I.              0.208835 -0.172346  0.189764
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.         0.621680  0.653068  0.213956
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.      0.258352 -0.382443  0.292639
# THE SECOND PART OF KING HENRY THE SIXTH ACT IV.  0.406324 -0.508192 -0.605349
#
#                                                         4         5
# act
# THE LIFE OF KING HENRY THE FIFTH ACT II.        -0.387874 -0.255740
# THE TRAGEDY OF JULIUS CAESAR ACT I.              0.708744 -0.564840
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.        -0.092001  0.166823
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.      0.739718 -0.070444
# THE SECOND PART OF KING HENRY THE SIXTH ACT IV. -0.056412 -0.206502

# %% [markdown]
# ## Step 4 Clustering

# %%
def getLabels(X, n_clusters = 8, method = 'KMeans'):
    
    if method == 'KMeans':
        cluster = KMeans(n_clusters=n_clusters, init='k-means++', max_iter=500, 
                         n_init=5, random_state = randomState)   
    elif method == 'AffinityPropagation':
        cluster = AffinityPropagation(max_iter=1000)
    elif method == 'AgglomerativeClustering':
        cluster = AgglomerativeClustering(n_clusters=n_clusters)
    elif method == 'Birch':
        cluster = Birch()
    elif method == 'DBSCAN':
        cluster = DBSCAN(random_state = randomState, eps=0.1, min_samples=3)
    elif method == 'SpectralClustering':
        cluster = SpectralClustering(n_clusters=n_clusters)
    elif method == 'MeanShift':
        cluster = MeanShift()
        

    return cluster.fit_predict(X)
        

def printClusters(labels):
    for i in set(labels):
        index = np.squeeze(np.argwhere(labels == i)).tolist()
        print(index)
    
        print(np.array(title)[index])
        print('\n')
        
def print2D(X, x_label, y_label, title, labels):
    plt.figure(figsize = (9,7))
    plt.scatter(X[:,0], X[:,1], c=labels, marker='+', s=100, linewidths=2)
    plt.ylabel(y_label, fontsize=14, fontweight='bold')
    plt.xlabel(x_label, fontsize=14, fontweight='bold')
    plt.title(title, fontsize=14, fontweight='bold')
    
    ax = plt.gca()
    for i in range(len(labels)):
        if labels.tolist().count(labels[i]) <= 3:
            ax.annotate(df_all.index[i], xy=X[i,:], fontweight='bold')
    
    xmin = min(X[:,0])
    xmax = max(X[:,0])
    ymin = min(X[:,1])
    ymax = max(X[:,1])
    
    xrange = xmax - xmin
    yrange = ymax - ymin
    
    xmin = xmin - xrange/10
    xmax = xmax + xrange/10
    
    ymin = ymin - yrange/10
    ymax = ymax + yrange/10
    
    plt.xlim([xmin, xmax])
    plt.ylim([ymin, ymax])
    plt.show()

# %%
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn import metrics

def clusterDocuments(X, scaled = False, PCA_X = False, n_clusters = 8, 
                     method = 'KMeans', visualize = True, verbose = True):
        
    
    if scaled:
        X = preprocessing.scale(X)
        
    if PCA_X:
        X = PCA().fit_transform(X)
        
    if PCA_X:
        X_2D_PCA = X[:, 0:2]
    else:
        pca = PCA(n_components=2)
        X_2D_PCA = pca.fit_transform(X)
        
    labels = getLabels(X, n_clusters, method)
        
    if visualize:
        print2D(X_2D_PCA, 'PCA 1st component', 'PCA 2nd component', method, labels)
    
    print('Number of clusters: ', len(set(labels)))
    print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(X, labels, random_state=randomState))
    
    if verbose:
        printClusters(labels)

# %%
# Cluster only using n-grams as features
# X_tfidf = getTfidf(ngram_range = (2,4))
# X = getSVD(X_tfidf, n_components = 20)
# labels = getLabels(X, n_clusters = 20)
# printClusters(labels)

# %% [markdown]
# > By only using n-grams + td-idf + SVD (20 components), acts are grouped mainly according to their topics. Acts of the same play go to the same cluster.

# %% [markdown]
# ### K-Means

# %%
# Cluster using all features
X = df_all.values
for n in np.arange(2,30,1):
    clusterDocuments(X, scaled=True, PCA_X = True, n_clusters = n, method = 'KMeans', visualize = False, verbose = False)
# Out:
# Number of clusters:  2
# Silhouette Coefficient: 0.147
# Number of clusters:  3
# Silhouette Coefficient: 0.123
# Number of clusters:  4
# Silhouette Coefficient: 0.151
# Number of clusters:  5
# Silhouette Coefficient: 0.089
# Number of clusters:  6
# Silhouette Coefficient: 0.102
# Number of clusters:  7
# Silhouette Coefficient: 0.093
# Number of clusters:  8
# Silhouette Coefficient: 0.098
# Number of clusters:  9
# Silhouette Coefficient: 0.106
# Number of clusters:  10
# Silhouette Coefficient: 0.107
# Number of clusters:  11
# Silhouette Coefficient: 0.107
# Number of clusters:  12
# Silhouette Coefficient: 0.117
# Number of clusters:  13
# Silhouette Coefficient: 0.121
# Number of clusters:  14
# Silhouette Coefficient: 0.115
# Number of clusters:  15
# Silhouette Coefficient: 0.106
# Number of clusters:  16
# Silhouette Coefficient: 0.107
# Number of clusters:  17
# Silhouette Coefficient: 0.124
# Number of clusters:  18
# Silhouette Coefficient: 0.116
# Number of clusters:  19
# Silhouette Coefficient: 0.105
# Number of clusters:  20
# Silhouette Coefficient: 0.125
# Number of clusters:  21
# Silhouette Coefficient: 0.111
# Number of clusters:  22
# Silhouette Coefficient: 0.102
# Number of clusters:  23
# Silhouette Coefficient: 0.109
# Number of clusters:  24
# Silhouette Coefficient: 0.100
# Number of clusters:  25
# Silhouette Coefficient: 0.107
# Number of clusters:  26
# Silhouette Coefficient: 0.113
# Number of clusters:  27
# Silhouette Coefficient: 0.108
# Number of clusters:  28
# Silhouette Coefficient: 0.107
# Number of clusters:  29
# Silhouette Coefficient: 0.113
# /Users/binyan/Python/anaconda/envs/py34/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
X = df_all.values
clusterDocuments(X, scaled = True, PCA_X = True, n_clusters = 20, method = 'KMeans', visualize = True, verbose = True)
# Out:
# Number of clusters:  20
# Silhouette Coefficient: 0.127
# [14, 37, 59, 66, 82, 113, 115, 120, 170]
# ['THE TRAGEDY OF TITUS ANDRONICUS ACT V. ' 'KING JOHN ACT III'
#  'THE LIFE OF TIMON OF ATHENS ACT IV.' 'THE MERCHANT OF VENICE ACT III'
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT IV.' "LOVE'S LABOUR'S LOST ACT IV."
#  'SECOND PART OF KING HENRY IV ACT IV.'
#  'THE TRAGEDY OF TITUS ANDRONICUS AC
'
#  'THE FIRST PART OF HENRY THE SIXTH ACT IV.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT II.'
#  'THE FIRST PART OF HENRY THE SIXTH ACT III'
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT V. '
#  'KING RICHARD III ACT II.'
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT III'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT V. '
#  'THE LIFE OF KING HENRY THE FIFTH ACT V. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT I. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT II.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT IV.']
#
#
# [3, 22, 52, 90, 99, 109, 124, 147, 158, 176]
# ['THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.'
#  'SECOND PART OF KING HENRY IV ACT III'
#  'THE MERRY WIVES OF WINDSOR ACT IV.' 'THE MERRY WIVES OF WINDSOR ACT I. '
#  'THE MERRY WIVES OF WINDSOR ACT II.' 'THE MERRY WIVES OF WINDSOR ACT III'
#  'SECOND PART OF KING HENRY IV ACT II.'
#  'SECOND PART OF KING HENRY IV ACT V. '
#  'THE MERRY WIVES OF WINDSOR ACT V. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III']
#
#
# [45, 123]
# ['THE HISTORY OF TROILUS AND CRESSIDA ACT V. '
#  'ALLS WELL THAT ENDS WELL ACT III']
#
#
# [24, 61, 69, 142, 171]
# ['THE COMEDY OF ERRORS ACT I. ' 'THE COMEDY OF ERRORS ACT Il.'
#  'THE COMEDY OF ERRORS ACT III' 'THE COMEDY OF ERRORS ACT V. '
#  'THE COMEDY OF ERRORS ACT IV.']
#
#
# [5, 17, 28, 31, 57, 77, 85, 87, 106, 112, 117, 134, 161, 168, 173]
# ['THE LIFE OF TIMON OF ATHENS ACT II.' 'THE TRAGEDY OF KING LEAR ACT II.'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT I. '
#  'THE LIFE OF TIMON OF ATHENS ACT I. '
#  'THE TWO GENTLEMEN OF VERONA ACT V. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT II.'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V. '
#  'KING HENRY THE EIGHTH ACT I. ' 'THE TRAGEDY OF KING LEAR ACT V. '
#  'THE TWO GENTLEMEN OF VERONA ACT I. '
#  'THE TRAGEDY OF JULIUS CAESAR ACT IV.' 'THE TEMPEST ACT II.'
#  'THE TRAGEDY OF KING LEAR ACT IV.' 'THE LIFE OF TIMON OF ATHENS ACT III'
#  'ALLS WELL THAT ENDS WELL ACT II.']
#
#
# 157
# THE SONNETS ACT1609
#
#
# [15, 49, 71, 81, 118, 121, 128, 136, 141, 162]
# ["LOVE'S LABOUR'S LOST ACT III" 'AS YOU LIKE IT ACT III'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT III'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT V. '
#  'MUCH ADO ABOUT NOTHING ACT III' "THE WINTER'S TALE ACT IV."
#  'THE MERCHANT OF VENICE ACT II.'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT V. ' 'CYMBELINE ACT IV.']
#
#
# [38, 46, 60, 93, 96, 100, 105, 132, 149, 155, 179]
# ['SECOND PART OF KING HENRY IV ACT I. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT V. '
#  "LOVE'S LABOUR'S LOST ACT II." 'KING JOHN ACT IV.'
#  'THE MERCHANT OF VENICE ACT V. ' 'CYMBELINE ACT I. '
#  'THE TRAGEDY OF CORIOLANUS ACT V. ' 'ALLS WELL THAT ENDS WELL ACT IV.'
#  'ALLS WELL THAT ENDS WELL ACT I. ' 'CYMBELINE ACT II.'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT II.']
#
#
# [18, 72, 174]
# ['KING HENRY THE EIGHTH ACT V. '
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT I. '
#  'THE LIFE OF KING HENRY THE FIFTH ACT I. ']
#
#
# 152
# A LOVER'S COMPLAINT ACT1609
#
#
# [7, 23, 30, 53, 62, 68, 84, 97, 108, 110, 148, 164]
# ['THE LIFE OF TIMON OF ATHENS ACT V. ' 'KING HENRY THE EIGHTH ACT III'
#  'CYMBELINE ACT V. ' 'KING RICHARD III ACT V. '
#  'KING RICHARD THE SECOND ACT I. ' 'KING RICHARD THE SECOND ACT IV.'
#  'KING RICHARD THE SECOND ACT V. ' 'KING RICHARD THE SECOND ACT III'
#  'CYMBELINE ACT III' 'THE FIRST PART OF HENRY THE SIXTH ACT I. '
#  'KING RICHARD III ACT IV.' 'KING RICHARD THE SECOND ACT II.']
#
#
# [6, 8, 9, 20, 21, 35, 39, 48, 55, 67, 98, 125, 126, 137, 156, 163, 166, 175, 177]
# ['THE TWO GENTLEMEN OF VERONA ACT III' 'ALLS WELL THAT ENDS WELL ACT V S'
#  'THE TRAGEDY OF CORIOLANUS ACT IV.'
#  'THE TRAGEDY OF ROMEO AND JULIET ACT IV.'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT II.'
#  'THE TRAGEDY OF ROMEO AND JULIET ACT III'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT III'
#  'MEASURE FOR MEASURE ACT II.' 'THE TRAGEDY OF CORIOLANUS ACT III'
#  'THE TAMING OF THE SHREW ACT IV.' 'MUCH ADO ABOUT NOTHING ACT V. '
#  'THE TRAGEDY OF KING LEAR ACT I. ' 'THE TAMING OF THE SHREW ACT V. '
#  'THE TWO GENTLEMEN OF VERONA ACT II.'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT IV.'
#  'THE TRAGEDY OF JULIUS CAESAR ACT III'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.'
#  'THE TRAGEDY OF ROMEO AND JULIET ACT II.'
#  'THE TRAGEDY OF JULIUS CAESAR ACT V. ']
#
#
# [2, 43, 63, 78, 79, 146]
# ['TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT IV.'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT V. '
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT III'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT II.'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT I. ']
#
#
# 130
# ALLS WELL THAT ENDS WELL ACT V.
# /Users/binyan/Python/anaconda/envs/py34/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %% [markdown]
# > By adding the features of average sentence length, number of unique words normalized by total number of words, fequency of conjunctions, and etc., acts are clustered according to the writing style (need to be verified by visualization).

# %% [markdown]
# ### Affinity Propagation

# %%
print('No mormalization')
clusterDocuments(X, scaled = False, PCA_X=False, method = 'AffinityPropagation', visualize = False, verbose = False)
print('Normalize to N(0,1)')
clusterDocuments(X, scaled = True, method = 'AffinityPropagation', visualize = False, verbose = False)
# Out:
# No mormalization
# Silhouette Coefficient: 0.203
# Normalize to N(0,1)
# Silhouette Coefficient: 0.106
# /Users/binyan/Python/anaconda/envs/py34/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
clusterDocuments(X, scaled = True, PCA_X = True, method = 'AffinityPropagation')
# Out:
# Number of clusters:  24
# Silhouette Coefficient: 0.106
# [10, 11, 12, 13, 58, 83, 111, 129, 159, 165]
# ['THE THIRD PART OF KING HENRY THE SIXTH ACT III'
#  'KING RICHARD III ACT I. '
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT I. '
#  'KING RICHARD III ACT III'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT II.'
#  'KING RICHARD III ACT II.'
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT III'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT V. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT II.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT IV.']
#
#
# 15
# LOVE'S LABOUR'S LOST ACT III
#
#
# [3, 5, 28, 31, 46, 57, 60, 87, 88, 106, 112, 132, 134, 141, 155, 161, 168, 176, 179]
# ['THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.'
#  'THE LIFE OF TIMON OF ATHENS ACT II.'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT I. '
#  'THE LIFE OF TIMON OF ATHENS ACT I. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT V. '
#  'THE TWO GENTLEMEN OF VERONA ACT V. ' "LOVE'S LABOUR'S LOST ACT II."
#  'KING HENRY THE EIGHTH ACT I. ' 'THE TEMPEST ACT III'
#  'THE TRAGEDY OF KING LEAR ACT V. ' 'THE TWO GENTLEMEN OF VERONA ACT I. '
#  'ALLS WELL THAT ENDS WELL ACT IV.' 'THE TEMPEST ACT II.'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK AC
'
#  'THE LIFE OF KING HENRY THE FIFTH ACT V. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT I. ']
#
#
# [24, 61, 69, 142, 171]
# ['THE COMEDY OF ERRORS ACT I. ' 'THE COMEDY OF ERRORS ACT Il.'
#  'THE COMEDY OF ERRORS ACT III' 'THE COMEDY OF ERRORS ACT V. '
#  'THE COMEDY OF ERRORS ACT IV.']
#
#
# [18, 72, 174]
# ['KING HENRY THE EIGHTH ACT V. '
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT I. '
#  'THE LIFE OF KING HENRY THE FIFTH ACT I. ']
#
#
# [23, 53, 62, 68, 97, 115, 148]
# ['KING HENRY THE EIGHTH ACT III' 'KING RICHARD III ACT V. '
#  'KING RICHARD THE SECOND ACT I. ' 'KING RICHARD THE SECOND ACT IV.'
#  'KING RICHARD THE SECOND ACT III' 'SECOND PART OF KING HENRY IV ACT IV.'
#  'KING RICHARD III ACT IV.']
#
#
# [7, 30, 84, 108, 140, 162, 164]
# ['THE LIFE OF TIMON OF ATHENS ACT V. ' 'CYMBELINE ACT V. '
#  'KING RICHARD THE SECOND ACT V. ' 'CYMBELINE ACT III'
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT III' 'CYMBELINE ACT IV.'
#  'KING RICHARD THE SECOND ACT II.']
#
#
# 130
# ALLS WELL THAT ENDS WELL ACT V.
#
#
# [16, 33, 42, 94, 107, 116, 127, 135, 178]
# ['AS YOU LIKE IT ACT V. ' 'MUCH ADO ABOUT NOTHING ACT I. '
#  'THE TRAGEDY OF CORIOLANUS ACT I. '
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT I. '
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I. '
#  'THE MERCHANT OF VENICE ACT IV.' 'MEASURE FOR MEASURE ACT III'
#  'MUCH ADO ABOUT NOTHING ACT II.']
#
#
# [21, 35, 71, 81, 118, 128, 136]
# ['THE FIRST PART OF KING HENRY THE FOURTH ACT II.'
#  'THE TRAGEDY OF ROMEO AND JULIET ACT III'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT III'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT V. '
#  "THE WINTER'S TALE ACT IV." 'THE MERCHANT OF VENICE ACT II.']
#
#
# [2, 49, 63, 78, 79, 146]
# ['TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.' 'AS YOU LIKE IT ACT III'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT V. '
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT III'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT II.'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT I. ']
#
#
# [1, 8, 25, 38, 65, 66, 75, 96, 113, 122, 131, 144, 149, 150, 172, 180]
# ['THE TRAGEDY OF JULIUS CAESAR ACT I. ' 'ALLS WELL THAT ENDS WELL ACT V S'
#  "THE WINTER'S TALE ACT II." 'SECOND PART OF KING HENRY IV ACT I. '
#  "LOVE'S LABOUR'S LOST ACT I. " 'THE MERCHANT OF VENICE ACT III'
#  'THE TAMING OF THE SHREW ACT Il.' 'THE MERCHANT OF VENICE ACT V. '
#  "LOVE'S LABOUR'S LOST ACT IV." 'AS YOU LIKE IT ACT IV.'
#  'AS YOU LIKE IT ACT II.' 'THE MERCHANT OF VENICE ACT I. '
#  'ALLS WELL THAT ENDS WELL ACT I. ' "THE WINTER'S TALE ACT V. "
#  'THE TRAGEDY OF JULIUS CAESAR ACT II.' "THE WINTER'S TALE ACT I. "]
#
#
# 152
# A LOVER'S COMPLAINT ACT1609
#
#
# [34, 64, 86, 101, 119, 153, 169, 181]
# ["THE WINTER'S TALE ACT III" 'THE HISTORY OF TROILUS AND CRESSIDA ACT III'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT IV.'
#  "A MIDSUMMER NIGHT'S DREAM ACT II." 'KING JOHN ACT II.'
#  'KING JOHN ACT V. ' 'THE FIRST PART OF KING HENRY THE FOURTH ACT I. '
#  'MEASURE FOR MEASURE ACT I. ']
#
#
# 157
# THE SONNETS ACT1609
#
#
# [4, 19, 29, 47, 50, 91, 103, 121, 138, 160]
# ['THE SECOND PART OF KING HENRY THE SIXTH ACT IV.'
#  'THE TRAGEDY OF MACBETH ACT I. '
#  'THE LIFE OF KING HENRY THE FIFTH ACT IV.'
#  'THE TRAGEDY OF MACBETH ACT V. ' 'THE TRAGEDY OF ROMEO AND JULIET ACT V. '
#  'THE LIFE OF KING HENRY THE FIFTH ACT III'
#  'ALLS WELL THAT ENDS WELL ACT IV ' 'MUCH ADO ABOUT NOTHING ACT III'
#  'THE TRAGEDY OF MACBETH ACT II.' 'THE TRAGEDY OF MACBETH ACT III']
#
#
# [14, 36, 37, 59, 82, 93, 120, 147, 167, 170]
# ['THE TRAGEDY OF TITUS ANDRONICUS ACT V. ' 'KING JOHN ACT I. '
#  'KING JOHN ACT III' 'THE LIFE OF TIMON OF ATHENS ACT IV.'
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT IV.' 'KING JOHN ACT IV.'
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT II.'
#  'SECOND PART OF KING HENRY IV ACT V. ' "A MIDSUMMER NIGHT'S DREAM ACT IV."
#  'THE TEMPEST ACT I. ']
# /Users/binyan/Python/anaconda/envs/py34/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
X = df_all.values
for n in np.arange(2,30,1):
    clusterDocuments(X, scaled=True, PCA_X = True, n_clusters = n, method = 'AgglomerativeClustering', visualize = False, verbose = False)
# Out:
# Number of clusters:  2
# Silhouette Coefficient: 0.083
# Number of clusters:  3
# Silhouette Coefficient: 0.088
# Number of clusters:  4
# Silhouette Coefficient: 0.096
# Number of clusters:  5
# Silhouette Coefficient: 0.114
# Number of clusters:  6
# Silhouette Coefficient: 0.096
# Number of clusters:  7
# Silhouette Coefficient: 0.105
# Number of clusters:  8
# Silhouette Coefficient: 0.087
# Number of clusters:  9
# Silhouette Coefficient: 0.089
# Number of clusters:  10
# Silhouette Coefficient: 0.093
# Number of clusters:  11
# Silhouette Coefficient: 0.094
# Number of clusters:  12
# Silhouette Coefficient: 0.099
# Number of clusters:  13
# Silhouette Coefficient: 0.106
# Number of clusters:  14
# Silhouette Coefficient: 0.107
# Number of clusters:  15
# Silhouette Coefficient: 0.110
# Number of clusters:  16
# Silhouette Coefficient: 0.117
# Number of clusters:  17
# Silhouette Coefficient: 0.119
# Number of clusters:  18
# Silhouette Coefficient: 0.120
# Number of clusters:  19
# Silhouette Coefficient: 0.121
# Number of clusters:  20
# Silhouette Coefficient: 0.118
# Number of clusters:  21
# Silhouette Coefficient: 0.121
# Number of clusters:  22
# Silhouette Coefficient: 0.123
# Number of clusters:  23
# Silhouette Coefficient: 0.124
# Number of clusters:  24
# Silhouette Coefficient: 0.119
# Number of clusters:  25
# Silhouette Coefficient: 0.121
# Number of clusters:  26
# Silhouette Coefficient: 0.121
# Number of clusters:  27
# Silhouette Coefficient: 0.125
# Number of clusters:  28
# Silhouette Coefficient: 0.124
# Number of clusters:  29
# Silhouette Coefficient: 0.125
# /Users/binyan/Python/anaconda/envs/py34/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
clusterDocuments(X, n_clusters = 23, scaled = True, PCA_X = True, method = 'AgglomerativeClustering')
# Out:
# Number of clusters:  23
# Silhouette Coefficient: 0.124
# [1, 8, 27, 39, 48, 67, 75, 76, 88, 92, 102, 114, 122, 133, 137, 139, 150, 172, 180]
# ['THE TRAGEDY OF JULIUS CAESAR ACT I. ' 'ALLS WELL THAT ENDS WELL ACT V S'
#  'MEASURE FOR MEASURE ACT V. '
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE AC
ACT V. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT III'
#  "LOVE'S LABOUR'S LOST ACT IV." 'THE MERCHANT OF VENICE ACT I. '
#  'THE TRAGEDY OF MACBETH ACT III' "A MIDSUMMER NIGHT'S DREAM ACT IV."]
#
#
# [15, 103]
# ["LOVE'S LABOUR'S LOST ACT III" 'ALLS WELL THAT ENDS WELL ACT IV ']
#
#
# [45, 123]
# ['THE HISTORY OF TROILUS AND CRESSIDA ACT V. '
#  'ALLS WELL THAT ENDS WELL ACT III']
#
#
# 157
# THE SONNETS ACT1609
#
#
# 152
# A LOVER'S COMPLAINT ACT1609
#
#
# [57, 60, 149, 155, 179]
# ['THE TWO GENTLEMEN OF VERONA ACT V. ' "LOVE'S LABOUR'S LOST ACT II."
#  'ALLS WELL THAT ENDS WELL ACT I. ' 'CYMBELINE ACT II.'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT II.']
#
#
# [7, 19, 32, 43, 47, 50]
# ['THE LIFE OF TIMON OF ATHENS ACT V. ' 'THE TRAGEDY OF MACBETH ACT I. '
#  'THE TRAGEDY OF MACBETH ACT IV.'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT IV.'
#  'THE TRAGEDY OF MACBETH ACT V. ' 'THE TRAGEDY OF ROMEO AND JULIET ACT V. ']
#
#
# [49, 121, 128]
# ['AS YOU LIKE IT ACT III' 'MUCH ADO ABOUT NOTHING ACT III'
#  "THE WINTER'S TALE ACT IV."]
#
#
# [34, 36, 37, 64, 74, 86, 101, 119, 120, 153, 169]
# ["THE WINTER'S TALE ACT III" 'KING JOHN ACT I. ' 'KING JOHN ACT III'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT III'
#  'THE FIRST PART OF HENRY THE SIXTH ACT II.'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT IV.'
#  "A MIDSUMMER NIGHT'S DREAM ACT II." 'KING JOHN ACT II.'
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT II.' 'KING JOHN ACT V. '
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT I. ']
# /Users/binyan/Python/anaconda/envs/py34/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
clusterDocuments(X, n_clusters = 8, scaled = True, PCA_X = True, method = 'SpectralClustering', verbose = False)
clusterDocuments(X, scaled = True, PCA_X = True, method = 'Birch', verbose = False)
#clusterDocuments(X, scaled = True, PCA_X = True, method = 'DBSCAN')
clusterDocuments(X, scaled = True, PCA_X = True, method = 'MeanShift', verbose = False)
# Out:
# Number of clusters:  8
# Silhouette Coefficient: -0.172
# Number of clusters:  3
# Silhouette Coefficient: 0.088
# Number of clusters:  7
# Silhouette Coefficient: 0.276
# /Users/binyan/Python/anaconda/envs/py34/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
def print3D(X, x_label, y_label, z_label, title, labels):
    fig = plt.figure(1, figsize=(11, 10))
    plt.clf()
    ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

    plt.cla()
    
    ax.scatter(X[:, 1], X[:, 0], X[:, 2], c=labels.astype(np.float), s=50)
    ax.dist = 11

    ax.w_xaxis.set_ticklabels([])
    ax.w_yaxis.set_ticklabels([])
    ax.w_zaxis.set_ticklabels([])
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.set_zlabel(z_label)
    
pca = PCA(n_components=3)
X_3D_PCA = pca.fit_transform(X)

print3D(X_3D_PCA, 'numberUniqueWords', 'averageSentenceLength', 'numberOfPronoun', 'title', labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-167-0960320b2857> in <module>()
#      19 X_3D_PCA = pca.fit_transform(X)
#      20
# ---> 21 print3D(X_3D_PCA, 'numberUniqueWords', 'averageSentenceLength', 'numberOfPronoun', 'title', labels)
#
# NameError: name 'labels' is not defined
