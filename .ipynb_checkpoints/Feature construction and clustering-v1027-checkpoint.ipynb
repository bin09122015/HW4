# %% [markdown]
# ## Step 1 Construct features using NLTK

# %%
import nltk
from nltk.corpus import stopwords
import string

import json


# Import works.json: title, words, sentences of 38 pieces
with open('works_v1025.json', 'r') as f:
    try:
        works = json.load(f)
    # if the file is empty the ValueError will be thrown
    except ValueError:
        works = {}

# %%
from nltk import FreqDist

def getFreqDist(words):
    nltk_text = nltk.Text(words)
    
    return FreqDist(nltk_text)

# %%
def getCountFrequency(words, freq):
    nltk_text = nltk.Text(words)
    freq_dist = FreqDist(nltk_text)
    
    count = 0
    for key,value in freq_dist.items():
        if value == freq:
            count += 1
    
    return count    

def getHapaxLegomena(words):
    return getCountFrequency(words, 1)

# %%
def getDisLegomena(words):
    return getCountFrequency(words, 2)

# %%
def getNumberUniqueWords(words):
    return len(getFreqDist(words))

# %%
def getWordLengthDistribution(words):
    result = FreqDist()
    for w in words:        
        result[len(w)] += 1
    
    return result

def printFreqDist(freq_dist):
    for key,value in freq_dist.items():
        print (key,value)

# %%
def getSentenceLengthDistribution(sents):
    result = FreqDist()
    for s in sents:        
        result[len(s)] += 1
    
    return result

# %%
def getAverageSentenceLength(words_all, sents):
    
    return len(words_all)/len(sents)

# %%
def getPronounDistribution(sents):
    result = FreqDist()
    pronouns = ['I', 'you', 'he', 'she', 'it', 'we', 'you', 'they', 'thou', 'ye']
    for s in sents:
        count = 0
        for p in pronouns:
            count += s.count(p)
        result[count] += 1
    
    return result

# %%
def getNumberOfPronoun(sentences):
    pronouns = ['I', 'you', 'he', 'she', 'it', 'we', 'you', 'they', 'thou', 'ye']
    count = 0
    for s in sentences:        
        for p in pronouns:
            count += s.count(p)
    
    return count

# %%
def getConjunctionDistribution(sents):
    result = FreqDist()
    conjunctions = ['for', 'and', 'nor', 'but', 'or', 'yet', 'so', 'after', 'although', 'as', 'because', 'before', 'if',
                'once', 'since', 'though', 'unless', 'until', 'when', 'where', 'while', 'whether', 'either', 'neither',
                'as', 'than', 'even', 'then', 'lest', 'rather', 'which', 'who', 'why', 'that', 'till']
    for s in sents:
        count = 0
        for c in conjunctions:
            count += s.count(c)
        result[count] += 1
    
    return result

# %%
def getNumberOfConjunction(sents):
    count = 0
    conjunctions = ['for', 'and', 'nor', 'but', 'or', 'yet', 'so', 'after', 'although', 'as', 'because', 'before', 'if',
                'once', 'since', 'though', 'unless', 'until', 'when', 'where', 'while', 'whether', 'either', 'neither',
                'as', 'than', 'even', 'then', 'lest', 'rather', 'which', 'who', 'why', 'that', 'till']
    for s in sents:
        for c in conjunctions:
            count += s.count(c)
    
    return count

# %%
# %matplotlib inline 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from __future__ import division

# Create a feature table for all acts
# Currently only has some simple features

featureTable = {}

featureTable = {'act': [], 'HapaxLegomena': [], 'DisLegomena': [], 
                'numberUniqueWords': [], 'averageSentenceLength': [], 'numberOfSentences': [],
                'numberOfPronoun': [], 'numberOfConjunction': []}


for act, content in works.items():
    words_nonStemmed = content['words_nonStemmed']
    words_all = content['words_all']
    sentences = content['sentences']
    # Normalize by number of all words
    normalizer = len(words_all)
    featureTable['act'].append(act)
    featureTable['HapaxLegomena'].append(getHapaxLegomena(words_nonStemmed)/normalizer)
    featureTable['DisLegomena'].append(getDisLegomena(words_nonStemmed)/normalizer)
    featureTable['numberUniqueWords'].append(getNumberUniqueWords(words_nonStemmed)/normalizer)
    featureTable['averageSentenceLength'].append(getAverageSentenceLength(words_all, sentences))
    featureTable['numberOfSentences'].append(len(sentences))
    featureTable['numberOfPronoun'].append(getNumberOfPronoun(sentences)/normalizer)
    featureTable['numberOfConjunction'].append(getNumberOfConjunction(sentences)/normalizer)
        

print(len(featureTable['act']))


df = pd.DataFrame(featureTable)
df.set_index(['act'], inplace=True)
df.head()
# Out:
# 223
#                                                 DisLegomena  HapaxLegomena  \
# act
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.        0.037037       0.375661
# THE MERRY WIVES OF WINDSOR ACT V.                  0.030271       0.137423
# KING RICHARD III ACT IV.                           0.025569       0.090466
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.     0.027211       0.107243
# KING RICHARD III ACT III                           0.027092       0.087016
#
#                                                 averageSentenceLength  \
# act
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.                 12.600000
# THE MERRY WIVES OF WINDSOR ACT V.                           11.665625
# KING RICHARD III ACT IV.                                    11.381011
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.              10.849493
# KING RICHARD III ACT III                                    12.848083
#
#                                                 numberOfConjunction  \
# act
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.                0.132275
# THE MERRY WIVES OF WINDSOR ACT V.                          0.131262
# KING RICHARD III ACT IV.                                   0.121127
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.             0.144458
# KING RICHARD III ACT III                                   0.133165
#
#                                                 numberOfPronoun  \
# act
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.            0.121693
# THE MERRY WIVES OF WINDSOR ACT V.                      0.180284
# KING RICHARD III ACT IV.                               0.210076
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.         0.196479
# KING RICHARD III ACT III                               0.214901
#
#                                                 numberOfSentences  \
# act
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.                    15
# THE MERRY WIVES OF WINDSOR ACT V.                             320
# KING RICHARD III ACT IV.                                      811
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.                691
# KING RICHARD III ACT III                                      678
#
#                                                 numberUniqueWords
# act
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.              0.423280
# THE MERRY WIVES OF WINDSOR ACT V.                        0.206268
# KING RICHARD III ACT IV.                                 0.153846
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.           0.170468
# KING RICHARD III ACT III                                 0.149466

# %%
# Filter out wierd acts, e.g. the beginning of a play

df = df[df['averageSentenceLength'] < 30]
df = df[['HapaxLegomena', 'DisLegomena', 'numberUniqueWords', 
        'averageSentenceLength', 'numberOfPronoun', 'numberOfConjunction']]

# %%
pd.scatter_matrix(df, alpha=0.2, figsize=(16, 16), diagonal='kde')
plt.show()
# Out:
# /Users/binyan/Python/anaconda/envs/py34/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# ## Step 2 Construct n-grams using sklearn

# %%
title = []
text = []

for act in df.index:
    content = works[act]
    title.append(act)
    text.append(content['text'])

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from __future__ import print_function

from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer
from sklearn import metrics

from sklearn.cluster import KMeans, MiniBatchKMeans
import numpy as np

# %%
# excluding stop words, n-grams is an input
def getTfidf(ngram_range):
    count_vect = CountVectorizer(ngram_range=ngram_range, stop_words='english')
    X_counts = count_vect.fit_transform(text)

    tfidf_transformer = TfidfTransformer(use_idf=True).fit(X_counts)
    X_tfidf = tfidf_transformer.transform(X_counts)
    return X_tfidf

# %%
randomState = np.random.seed(1)

def getSVD(X_tfidf, n_components):
    
    svd = TruncatedSVD(n_components = n_components, random_state = randomState)
    lsa = make_pipeline(svd, Normalizer(copy=False))
    X = lsa.fit_transform(X_tfidf)

    explained_variance = svd.explained_variance_ratio_.sum()
    print("Explained variance of the SVD step: {}%".format(
        int(explained_variance * 100)))
    
    return X

# %%
# Features from n-grams, use fewer components
X_tfidf = getTfidf(ngram_range = (2,4))
X = getSVD(X_tfidf, n_components = 6)
df_ngrams = pd.DataFrame(data=X, index = title)
df_ngrams.head()
# Out:
# Explained variance of the SVD step: 3%
#                                                        0         1         2  \
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.     0.023576 -0.381097  0.266134
# THE MERRY WIVES OF WINDSOR ACT V.               0.287838 -0.044148  0.019471
# KING RICHARD III ACT IV.                        0.293744 -0.220299 -0.197992
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.  0.610505 -0.005097 -0.176212
# KING RICHARD III ACT III                        0.684685 -0.098980 -0.394108
#
#                                                        3         4         5
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.    -0.560049 -0.662514  0.175509
# THE MERRY WIVES OF WINDSOR ACT V.               0.929150 -0.126159  0.188643
# KING RICHARD III ACT IV.                       -0.094442  0.614376  0.663027
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II. -0.240406  0.427947 -0.596048
# KING RICHARD III ACT III                       -0.523887 -0.244282 -0.178764

# %% [markdown]
# ## Step 3 Combine n-grams and other features

# %%
# Merge all features
df_all = df.join(df_ngrams)
df_all.head()
# Out:
#                                                 HapaxLegomena  DisLegomena  \
# act
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.          0.375661     0.037037
# THE MERRY WIVES OF WINDSOR ACT V.                    0.137423     0.030271
# KING RICHARD III ACT IV.                             0.090466     0.025569
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.       0.107243     0.027211
# KING RICHARD III ACT III                             0.087016     0.027092
#
#                                                 numberUniqueWords  \
# act
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.              0.423280
# THE MERRY WIVES OF WINDSOR ACT V.                        0.206268
# KING RICHARD III ACT IV.                                 0.153846
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.           0.170468
# KING RICHARD III ACT III                                 0.149466
#
#                                                 averageSentenceLength  \
# act
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.                 12.600000
# THE MERRY WIVES OF WINDSOR ACT V.                           11.665625
# KING RICHARD III ACT IV.                                    11.381011
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.              10.849493
# KING RICHARD III ACT III                                    12.848083
#
#                                                 numberOfPronoun  \
# act
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.            0.121693
# THE MERRY WIVES OF WINDSOR ACT V.                      0.180284
# KING RICHARD III ACT IV.                               0.210076
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.         0.196479
# KING RICHARD III ACT III                               0.214901
#
#                                                 numberOfConjunction         0  \
# act
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.                0.132275  0.023576
# THE MERRY WIVES OF WINDSOR ACT V.                          0.131262  0.287838
# KING RICHARD III ACT IV.                                   0.121127  0.293744
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.             0.144458  0.610505
# KING RICHARD III ACT III                                   0.133165  0.684685
#
#                                                        1         2         3  \
# act
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.    -0.381097  0.266134 -0.560049
# THE MERRY WIVES OF WINDSOR ACT V.              -0.044148  0.019471  0.929150
# KING RICHARD III ACT IV.                       -0.220299 -0.197992 -0.094442
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II. -0.005097 -0.176212 -0.240406
# KING RICHARD III ACT III                       -0.098980 -0.394108 -0.523887
#
#                                                        4         5
# act
# THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.    -0.662514  0.175509
# THE MERRY WIVES OF WINDSOR ACT V.              -0.126159  0.188643
# KING RICHARD III ACT IV.                        0.614376  0.663027
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.  0.427947 -0.596048
# KING RICHARD III ACT III                       -0.244282 -0.178764

# %% [markdown]
# ## Step 4 Clustering

# %%
def clusterDocuments(X, n_clusters):

    km = KMeans(n_clusters=n_clusters, init='k-means++', max_iter=500, n_init=5, random_state = randomState)
    km.fit_predict(X)    
    return km.labels_

def printClusters(labels):
    for i in set(labels):
        index = np.squeeze(np.argwhere(labels == i)).tolist()
        print(index)
    
        print(np.array(title)[index])
        print('\n')

# Cluster only using n-grams as features
X_tfidf = getTfidf(ngram_range = (2,4))
X = getSVD(X_tfidf, n_components = 20)
labels = clusterDocuments(X, n_clusters = 20)
printClusters(labels)
# Out:
# Explained variance of the SVD step: 11%
# [31, 36, 43, 45, 51, 71, 99, 102, 119, 163, 185, 187, 192]
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT V. '
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT III'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT I. '
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT II.']
#
#
# [17, 35, 68, 69, 76, 88, 90, 91, 97, 108, 148, 173]
# ['THE TRAGEDY OF JULIUS CAESAR ACT I. ' 'THE TRAGEDY OF CORIOLANUS ACT III'
#  'THE TRAGEDY OF CORIOLANUS ACT II.' 'THE TRAGEDY OF JULIUS CAESAR ACT III'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT III'
#  'THE TRAGEDY OF CORIOLANUS ACT I. '
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT III'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V. '
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.'
#  "THE WINTER'S TALE ACT IV." 'THE TRAGEDY OF TITUS ANDRONICUS ACT V. '
#  'AS YOU LIKE IT ACT IV.']
#
#
# [4, 20, 38, 40, 53, 59, 67, 73, 130, 142, 144, 150, 157, 158]
# ['KING RICHARD III ACT III' 'KING HENRY THE EIGHTH ACT I. '
#  "LOVE'S LABOUR'S LOST ACT IV." 'THE TWO GENTLEMEN OF VERONA ACT V. '
#  'THE MERCHANT OF VENICE ACT III' 'THE TWO GENTLEMEN OF VERONA ACT IV.'
#  "LOVE'S LABOUR'S LOST ACT V. " 'THE TWO GENTLEMEN OF VERONA ACT III'
#  "LOVE'S LABOUR'S LOST ACT II." 'THE TWO GENTLEMEN OF VERONA ACT II.'
#  'THE TWO GENTLEMEN OF VERONA ACT I. '
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT_4|S'
#  'THE TRAGEDY OF MACBETH ACT IV.']
#
#
# [6, 7, 85, 112, 118, 153]
# ['THE TEMPEST ACT V. ' 'KING JOHN ACT II.' 'KING JOHN ACT V. '
#  'KING JOHN ACT III' 'KING JOHN ACT IV.' 'KING JOHN ACT I. ']
#
#
# [9, 27, 72, 110, 135, 154, 155, 167, 170, 172]
# ['THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT V. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT V. '
#  'THE MERCHANT OF VENICE ACT V. '
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III'
#  'AS YOU LIKE IT ACT V. ' 'THE TEMPEST ACT III'
#  'KING HENRY THE EIGHTH ACT V. '
#  'THE FIRST PART OF HENRY THE SIXTH ACT II.'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT I. '
#  "A MIDSUMMER NIGHT'S DREAM ACT III"]

# %% [markdown]
# > By only using n-grams + td-idf + SVD (20 components), acts are grouped mainly according to their topics. Acts of the same play go to the same cluster.

# %%
# Cluster using all features
X = df_all.values
