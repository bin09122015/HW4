# %% [markdown]
# ## Step 1 Construct features using NLTK

# %%
import nltk
from nltk.corpus import stopwords
import string
import json

# %matplotlib inline 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from __future__ import division

randomState = np.random.seed(2)


# Import works.json: title, words, sentences of 38 pieces
with open('works_v1028.json', 'r') as f:
    try:
        works = json.load(f)
    # if the file is empty the ValueError will be thrown
    except ValueError:
        works = {}

# %%
from nltk import FreqDist

def getFreqDist(words):
    nltk_text = nltk.Text(words)
    
    return FreqDist(nltk_text)

# %%
def getCountFrequency(words, freq):
    nltk_text = nltk.Text(words)
    freq_dist = FreqDist(nltk_text)
    
    count = 0
    for key,value in freq_dist.items():
        if value == freq:
            count += 1
    
    return count    

def getHapaxLegomena(words):
    return getCountFrequency(words, 1)

# %%
def getDisLegomena(words):
    return getCountFrequency(words, 2)

# %%
def getNumberUniqueWords(words):
    return len(getFreqDist(words))

# %%
def getWordLengthDistribution(words):
    result = FreqDist()
    for w in words:        
        result[len(w)] += 1
    
    return result

def printFreqDist(freq_dist):
    for key,value in freq_dist.items():
        print (key,value)

# %%
def getSentenceLengthDistribution(sents):
    result = FreqDist()
    for s in sents:        
        result[len(s)] += 1
    
    return result

# %%
def getAverageSentenceLength(words_all, sents):
    
    return len(words_all)/len(sents)

# %%
def getPronounDistribution(sents):
    result = FreqDist()
    pronouns = ['I', 'you', 'he', 'she', 'it', 'we', 'you', 'they', 'thou', 'ye']
    for s in sents:
        count = 0
        for p in pronouns:
            count += s.count(p)
        result[count] += 1
    
    return result

# %%
def getNumberOfPronoun(words):
    pronouns = ['I', 'you', 'he', 'she', 'it', 'we', 'you', 'they', 'thou', 'ye']
    count = 0
         
    for p in pronouns:
        count += words.count(p)
    
    return count

# %%
def getConjunctionDistribution(sents):
    result = FreqDist()
    conjunctions = ['for', 'and', 'nor', 'but', 'or', 'yet', 'so', 'after', 'although', 'as', 'because', 'before', 'if',
                'once', 'since', 'though', 'unless', 'until', 'when', 'where', 'while', 'whether', 'either', 'neither',
                'as', 'than', 'even', 'then', 'lest', 'rather', 'which', 'who', 'why', 'that', 'till']
    for s in sents:
        count = 0
        for c in conjunctions:
            count += s.count(c)
        result[count] += 1
    
    return result

# %%
def getNumberOfConjunction(words):
    count = 0
    conjunctions = ['for', 'and', 'nor', 'but', 'or', 'yet', 'so', 'after', 'although', 'as', 'because', 'before', 'if',
                'once', 'since', 'though', 'unless', 'until', 'when', 'where', 'while', 'whether', 'either', 'neither',
                'as', 'than', 'even', 'then', 'lest', 'rather', 'which', 'who', 'why', 'that', 'till']

    for c in conjunctions:
        count += words.count(c)
    
    return count

# %%
def getNumberOfComma(text):
    return text.count(",")

def getNumberOfDots(text):
    return text.count(".")

def getNumberOfStringList(words, string_list):
    count = 0
    
    for c in string_list:
        count += words.count(c)
    
    return count

def getNumberOfThe(words):
    string_list = ['a', 'an', 'the']
    
    return getNumberOfStringList(words, string_list)

def getNumberOfIn(words):
    string_list = ['in', 'on', 'to', 'of']
    
    return getNumberOfStringList(words, string_list)

def getNumberOfIs(words):
    string_list = ['is', 'are', 'was', 'were']
    
    return getNumberOfStringList(words, string_list)

# %%
# Create a feature table for all acts
# Currently only has some simple features

featureTable = {}

featureTable = {'act': [], 'filename': [], 'HapaxLegomena': [], 'DisLegomena': [], 
                'numberUniqueWords': [], 'averageSentenceLength': [], 'numberOfSentences': [],
                'numberOfPronoun': [], 'numberOfConjunction': [], 'numberOfComma': [], 'numberOfDots': [],
                'numberOfThe': [], 'numberOfIn': [], 'numberOfIs': []}


for act, content in works.items():
    words_nonStemmed = content['words_nonStemmed']
    words_all = content['words_all']
    sentences = content['sentences']
    # Normalize by number of all words
    normalizer = len(words_all)
    featureTable['act'].append(act)
    featureTable['filename'].append(content['filename'])
    featureTable['HapaxLegomena'].append(getHapaxLegomena(words_nonStemmed)/normalizer)
    featureTable['DisLegomena'].append(getDisLegomena(words_nonStemmed)/normalizer)
    featureTable['numberUniqueWords'].append(getNumberUniqueWords(words_nonStemmed)/normalizer)
    featureTable['averageSentenceLength'].append(getAverageSentenceLength(words_all, sentences))
    featureTable['numberOfSentences'].append(len(sentences))
    featureTable['numberOfPronoun'].append(getNumberOfPronoun(words_all)/normalizer)
    featureTable['numberOfConjunction'].append(getNumberOfConjunction(words_all)/normalizer)
    featureTable['numberOfComma'].append(getNumberOfComma(content['text'])/normalizer)
    featureTable['numberOfDots'].append(getNumberOfDots(content['text'])/normalizer)
    featureTable['numberOfThe'].append(getNumberOfThe(words_all)/normalizer)
    featureTable['numberOfIn'].append(getNumberOfIn(words_all)/normalizer)
    featureTable['numberOfIs'].append(getNumberOfIs(words_all)/normalizer)

print(len(featureTable['act']))


df = pd.DataFrame(featureTable)
df.set_index(['act'], inplace=True)
df.head()
# Out:
# 218
#                                 DisLegomena  HapaxLegomena  \
# act
# MUCH ADO ABOUT NOTHING ACT III     0.023053       0.094187
# THE TEMPEST ACT II.                0.029406       0.116904
# AS YOU LIKE IT ACT1601             0.067460       0.285714
# THE MERCHANT OF VENICE ACT V.      0.029228       0.121384
# MEASURE FOR MEASURE ACT1605        0.067961       0.368932
#
#                                 averageSentenceLength filename  numberOfComma  \
# act
# MUCH ADO ABOUT NOTHING ACT III               9.201515   25.txt       0.066030
# THE TEMPEST ACT II.                          9.987387   31.txt       0.068916
# AS YOU LIKE IT ACT1601                      63.000000    4.txt       0.111111
# THE MERCHANT OF VENICE ACT V.               13.412000   22.txt       0.072472
# MEASURE FOR MEASURE ACT1605                 68.666667   21.txt       0.126214
#
#                                 numberOfConjunction  numberOfDots  numberOfIn  \
# act
# MUCH ADO ABOUT NOTHING ACT III             0.091553      0.094681    0.038367
# THE TEMPEST ACT II.                        0.081183      0.079019    0.036623
# AS YOU LIKE IT ACT1601                     0.071429      0.019841    0.051587
# THE MERCHANT OF VENICE ACT V.              0.096928      0.064122    0.041157
# MEASURE FOR MEASURE ACT1605                0.077670      0.019417    0.038835
#
#                                 numberOfIs  numberOfPronoun  \
# act
# MUCH ADO ABOUT NOTHING ACT III    0.019760         0.066030
# THE TEMPEST ACT II.               0.017680         0.050695
# AS YOU LIKE IT ACT1601            0.015873         0.011905
# THE MERCHANT OF VENICE ACT V.     0.019684         0.063525
# MEASURE FOR MEASURE ACT1605       0.019417         0.000000
#
#                                 numberOfSentences  numberOfThe  \
# act
# MUCH ADO ABOUT NOTHING ACT III                660     0.042977
# THE TEMPEST ACT II.                           555     0.037525
# AS YOU LIKE IT ACT1601                          4     0.043651
# THE MERCHANT OF VENICE ACT V.                 250     0.052789
# MEASURE FOR MEASURE ACT1605                     3     0.077670
#
#                                 numberUniqueWords
# act
# MUCH ADO ABOUT NOTHING ACT III           0.155277
# THE TEMPEST ACT II.                      0.183835
# AS YOU LIKE IT ACT1601                   0.380952
# THE MERCHANT OF VENICE ACT V.            0.186102
# MEASURE FOR MEASURE ACT1605              0.451456

# %%
# Filter out wierd acts, e.g. the beginning of a play

# df = df[df['averageSentenceLength'] < 30]

df.drop(["A MIDSUMMER NIGHT'S DREAM ACT1596","ALLS WELL THAT ENDS WELL ACT1603", "AS YOU LIKE IT ACT1601", 
              "CYMBELINE ACT1609","KING HENRY THE EIGHTH ACT1611","KING JOHN ACT1597","KING RICHARD III ACT1593",
             "KING RICHARD THE SECOND ACT1596", "LOVE'S LABOUR'S LOST ACT1595", "MEASURE FOR MEASURE ACT1605",
             "MUCH ADO ABOUT NOTHING ACT1599", "SECOND PART OF KING HENRY IV ACT1598", "THE COMEDY OF ERRORS ACT1593",
             "THE FIRST PART OF HENRY THE SIXTH ACT1592", "THE FIRST PART OF KING HENRY THE FOURTH ACT1598",
             "THE HISTORY OF TROILUS AND CRESSIDA ACT1602", "THE LIFE OF KING HENRY THE FIFTH ACT1599",
             "THE LIFE OF TIMON OF ATHENS ACT1608", "THE MERCHANT OF VENICE ACT1597", "THE MERRY WIVES OF WINDSOR ACT1601",
             "THE SECOND PART OF KING HENRY THE SIXTH ACT1591", "THE TAMING OF THE SHREW ACT1594", "THE TEMPEST ACT1612",
             "THE TRAGEDY OF ANTONY AND CLEOPATRA ACT1607", "THE TRAGEDY OF CORIOLANUS ACT1608",
              "THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT1604","THE TRAGEDY OF JULIUS CAESAR ACT1599",
             "THE TRAGEDY OF KING LEAR ACT1606", "THE TRAGEDY OF MACBETH ACT1606", 
              "THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT1605", "THE TRAGEDY OF ROMEO AND JULIET ACT1595",
             "THE TRAGEDY OF TITUS ANDRONICUS ACT1594", "THE TWO GENTLEMEN OF VERONA ACT1595", "THE WINTER'S TALE ACT1611",
             "TWELFTH NIGHT; OR, WHAT YOU WILL ACT1602", "THE THIRD PART OF KING HENRY THE SIXTH ACT1591"], inplace = True)

df_2 = df[['numberUniqueWords', 'averageSentenceLength']]
df_3 = df[['numberUniqueWords', 'averageSentenceLength', 'numberOfPronoun']]
df = df[['HapaxLegomena', 'DisLegomena', 'numberUniqueWords', 
        'averageSentenceLength', 'numberOfPronoun', 'numberOfConjunction', 'numberOfComma', 'numberOfDots',
                'numberOfThe', 'numberOfIn', 'numberOfIs']]

# %%
pd.scatter_matrix(df, alpha=0.2, figsize=(16, 16), diagonal='kde')
plt.show()
# Out:
# /Users/byan/anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# ## Step 2 Construct n-grams using sklearn

# %%
title = []
text = []

for act in df.index:
    content = works[act]
    title.append(act)
    text.append(content['text'])

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from __future__ import print_function

from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer
from sklearn import metrics

from sklearn.cluster import KMeans, MiniBatchKMeans, AffinityPropagation, AgglomerativeClustering, MeanShift, SpectralClustering, DBSCAN, Birch 
import numpy as np

# %%
# excluding stop words, n-grams is an input
def getTfidf(ngram_range):
    count_vect = CountVectorizer(ngram_range=ngram_range, stop_words='english')
    X_counts = count_vect.fit_transform(text)

    tfidf_transformer = TfidfTransformer(use_idf=True)
    X_tfidf = tfidf_transformer.fit_transform(X_counts)
    return X_tfidf

# %%
def getSVD(X_tfidf, n_components):
    
    svd = TruncatedSVD(n_components = n_components, random_state = randomState)
    lsa = make_pipeline(svd, Normalizer(copy=False))
    X = lsa.fit_transform(X_tfidf)

    explained_variance = svd.explained_variance_ratio_.sum()
    print("Explained variance of the SVD step: {}%".format(
        int(explained_variance * 100)))
    
    return X

# %%
# Features from n-grams, use fewer components
X_tfidf = getTfidf(ngram_range = (3,5))
X = getSVD(X_tfidf, n_components = 6)
df_ngrams = pd.DataFrame(data=X, index = title, 
                         columns=['n-gram 1st component', 'n-gram 2nd compoent', 'n-gram 3rd', 'n-gram 4th', 'n-gram 5th', 'n-gram 6th',])
df_ngrams.head()
# Out:
# Explained variance of the SVD step: 3%
#                                           n-gram 1st component  \
# MUCH ADO ABOUT NOTHING ACT III                        0.405937
# THE TEMPEST ACT II.                                  -0.103271
# THE MERCHANT OF VENICE ACT V.                        -0.454004
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.             -0.016155
# KING HENRY THE EIGHTH ACT III                         0.132491
#
#                                           n-gram 2nd compoent  n-gram 3rd  \
# MUCH ADO ABOUT NOTHING ACT III                      -0.290995   -0.805886
# THE TEMPEST ACT II.                                 -0.462882   -0.506820
# THE MERCHANT OF VENICE ACT V.                        0.381367   -0.372729
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.            -0.345358    0.305755
# KING HENRY THE EIGHTH ACT III                       -0.288136   -0.709480
#
#                                           n-gram 4th  n-gram 5th  n-gram 6th
# MUCH ADO ABOUT NOTHING ACT III             -0.258634   -0.089989   -0.161542
# THE TEMPEST ACT II.                         0.712314    0.054535   -0.088563
# THE MERCHANT OF VENICE ACT V.              -0.611666    0.367832   -0.008759
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.    0.872803    0.123726   -0.099437
# KING HENRY THE EIGHTH ACT III               0.453497    0.384774    0.205795

# %% [markdown]
# ## Step 3 Combine n-grams and other features

# %%
# Merge all features
df_all = df.join(df_ngrams)
df_all.head()
# Out:
#                                           HapaxLegomena  DisLegomena  \
# act
# MUCH ADO ABOUT NOTHING ACT III                 0.094187     0.023053
# THE TEMPEST ACT II.                            0.116904     0.029406
# THE MERCHANT OF VENICE ACT V.                  0.121384     0.029228
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.       0.149921     0.024525
# KING HENRY THE EIGHTH ACT III                  0.124630     0.030172
#
#                                           numberUniqueWords  \
# act
# MUCH ADO ABOUT NOTHING ACT III                     0.155277
# THE TEMPEST ACT II.                                0.183835
# THE MERCHANT OF VENICE ACT V.                      0.186102
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.           0.206487
# KING HENRY THE EIGHTH ACT III                      0.192664
#
#                                           averageSentenceLength  \
# act
# MUCH ADO ABOUT NOTHING ACT III                         9.201515
# THE TEMPEST ACT II.                                    9.987387
# THE MERCHANT OF VENICE ACT V.                         13.412000
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.              10.318367
# KING HENRY THE EIGHTH ACT III                         13.817439
#
#                                           numberOfPronoun  \
# act
# MUCH ADO ABOUT NOTHING ACT III                   0.066030
# THE TEMPEST ACT II.                              0.050695
# THE MERCHANT OF VENICE ACT V.                    0.063525
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.         0.046677
# KING HENRY THE EIGHTH ACT III                    0.050878
#
#                                           numberOfConjunction  numberOfComma  \
# act
# MUCH ADO ABOUT NOTHING ACT III                       0.091553       0.066030
# THE TEMPEST ACT II.                                  0.081183       0.068916
# THE MERCHANT OF VENICE ACT V.                        0.096928       0.072472
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.             0.089003       0.071203
# KING HENRY THE EIGHTH ACT III                        0.078091       0.070795
#
#                                           numberOfDots  numberOfThe  \
# act
# MUCH ADO ABOUT NOTHING ACT III                0.094681     0.042977
# THE TEMPEST ACT II.                           0.079019     0.037525
# THE MERCHANT OF VENICE ACT V.                 0.064122     0.052789
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.      0.077532     0.026108
# KING HENRY THE EIGHTH ACT III                 0.056596     0.046145
#
#                                           numberOfIn  numberOfIs  \
# act
# MUCH ADO ABOUT NOTHING ACT III              0.038367    0.019760
# THE TEMPEST ACT II.                         0.036623    0.017680
# THE MERCHANT OF VENICE ACT V.               0.041157    0.019684
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.    0.039161    0.017405
# KING HENRY THE EIGHTH ACT III               0.051864    0.013015
#
#                                           n-gram 1st component  \
# act
# MUCH ADO ABOUT NOTHING ACT III                        0.405937
# THE TEMPEST ACT II.                                  -0.103271
# THE MERCHANT OF VENICE ACT V.                        -0.454004
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.             -0.016155
# KING HENRY THE EIGHTH ACT III                         0.132491
#
#                                           n-gram 2nd compoent  n-gram 3rd  \
# act
# MUCH ADO ABOUT NOTHING ACT III                      -0.290995   -0.805886
# THE TEMPEST ACT II.                                 -0.462882   -0.506820
# THE MERCHANT OF VENICE ACT V.                        0.381367   -0.372729
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.            -0.345358    0.305755
# KING HENRY THE EIGHTH ACT III                       -0.288136   -0.709480
#
#                                           n-gram 4th  n-gram 5th  n-gram 6th
# act
# MUCH ADO ABOUT NOTHING ACT III             -0.258634   -0.089989   -0.161542
# THE TEMPEST ACT II.                         0.712314    0.054535   -0.088563
# THE MERCHANT OF VENICE ACT V.              -0.611666    0.367832   -0.008759
# TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.    0.872803    0.123726   -0.099437
# KING HENRY THE EIGHTH ACT III               0.453497    0.384774    0.205795

# %% [markdown]
# ## Step 4 Clustering

# %%
def getLabels(X, n_clusters = 8, method = 'KMeans'):
    
    if method == 'KMeans':
        cluster = KMeans(n_clusters=n_clusters, init='k-means++', max_iter=500, 
                         n_init=5, random_state = randomState)   
    elif method == 'AffinityPropagation':
        cluster = AffinityPropagation(max_iter=1000)
    elif method == 'AgglomerativeClustering':
        cluster = AgglomerativeClustering(n_clusters=n_clusters)
    elif method == 'Birch':
        cluster = Birch()
    elif method == 'DBSCAN':
        cluster = DBSCAN(random_state = randomState, eps=0.1, min_samples=3)
    elif method == 'SpectralClustering':
        cluster = SpectralClustering(n_clusters=n_clusters)
    elif method == 'MeanShift':
        cluster = MeanShift()
        

    return cluster.fit_predict(X)
        

def printClusters(labels):
    for i in set(labels):
        index = np.squeeze(np.argwhere(labels == i)).tolist()
        print(index)
    
        print(np.array(title)[index])
        print('\n')
        
def print2D(X, x_label, y_label, title, labels):
    plt.figure(figsize = (9,7))
    plt.scatter(X[:,0], X[:,1], c=labels, marker='+', s=100, linewidths=2)
    plt.ylabel(y_label, fontsize=14, fontweight='bold')
    plt.xlabel(x_label, fontsize=14, fontweight='bold')
    plt.title(title, fontsize=14, fontweight='bold')
    
    ax = plt.gca()
    for i in range(len(labels)):
        if labels.tolist().count(labels[i]) <= 13:
            ax.annotate(df_all.index[i], xy=X[i,:], fontweight='bold')
    
    xmin = min(X[:,0])
    xmax = max(X[:,0])
    ymin = min(X[:,1])
    ymax = max(X[:,1])
    
    xrange = xmax - xmin
    yrange = ymax - ymin
    
    xmin = xmin - xrange/10
    xmax = xmax + xrange/10
    
    ymin = ymin - yrange/10
    ymax = ymax + yrange/10
    
    plt.xlim([xmin, xmax])
    plt.ylim([ymin, ymax])
    plt.show()

# %%
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn import metrics
from sklearn.manifold import MDS

def clusterDocuments(X, scaled = False, PCA_X = False, n_clusters = 8, 
                     method = 'KMeans', visualize = 'PCA', verbose = True):
        
    
    if scaled:
        X = preprocessing.scale(X)
        
    if PCA_X:
        X = PCA().fit_transform(X)
        
    if PCA_X:
        X_2D_PCA = X[:, 0:2]
    else: 
        X_2D_PCA = PCA(n_components=2).fit_transform(X)
        X_2D_MDS = MDS(n_components=2).fit_transform(X)
        
    labels = getLabels(X, n_clusters, method)
        
    if visualize == 'PCA':
        print2D(X_2D_PCA, 'PCA 1st component', 'PCA 2nd component', method, labels)
    elif visualize == 'MDS':
        print2D(X_2D_MDS, 'MDS 1st component', 'MDS 2nd component', method, labels)
        
    
    print('Number of clusters: ', len(set(labels)))
    print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(X, labels, random_state=randomState))
    
    if verbose:
        printClusters(labels)

def visualizeCovariance(X, scaled = False):
    if scaled:
        X = preprocessing.scale(X)
        title = 'Standardized'
    else:
        title = 'Non-Standardized'
    
    pca = PCA(n_components=None)
    pca.fit(X)
    
    covariance = pca.get_covariance()
    
    
    width = 0.5
    ind = np.arange(len(pca.explained_variance_ratio_))

    plt.figure()
    ax = plt.gca()
    ax.bar(ind, pca.explained_variance_ratio_, width, color='gray')
    plt.ylabel('Explained Variance Ratio')
    plt.xlabel('Components')
    plt.title(title, fontweight='bold')
    plt.show()
    
    fig, ax = plt.subplots()
    heatmap = ax.pcolor(covariance, cmap=plt.cm.Blues, alpha=0.8)
    # Format
    fig = plt.gcf()
    fig.set_size_inches(8, 8)
    # turn off the frame
    ax.set_frame_on(False)
    # put the major ticks at the middle of each cell
    ax.set_yticks(np.arange(covariance.shape[0]) + 0.5, minor=False)
    ax.set_xticks(np.arange(covariance.shape[1]) + 0.5, minor=False)
    # want a more natural, table-like display
    ax.invert_yaxis()
    ax.xaxis.tick_top()
    # Set the labels
    # label source:https://en.wikipedia.org/wiki/Basketball_statistics
    labels = df_all.columns
    # note I could have used nba_sort.columns but made "labels" instead
    ax.set_xticklabels(labels, minor=False)
    ax.set_yticklabels(labels, minor=False)
    # rotate the
    plt.xticks(rotation=90)
    ax.grid(False)
    # Turn off all the ticks
    ax = plt.gca()
    for t in ax.xaxis.get_major_ticks():
        t.tick1On = False
        t.tick2On = False
    for t in ax.yaxis.get_major_ticks():
        t.tick1On = False
        t.tick2On = False
    plt.title(title, fontweight='bold', y=0)
    plt.show()

# %%
X = df_all.values
visualizeCovariance(X, scaled = False)
visualizeCovariance(X, scaled = True)
# Out:
# /Users/byan/anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# ### K-Means

# %%
# Cluster using all features
X = df_all.values
for n in np.arange(5,30,1):
    clusterDocuments(X, scaled=True, PCA_X = True, n_clusters = n, method = 'KMeans', visualize = 'None', verbose = False)
# Out:
# Number of clusters:  5
# Silhouette Coefficient: 0.075
# Number of clusters:  6
# Silhouette Coefficient: 0.072
# Number of clusters:  7
# Silhouette Coefficient: 0.081
# Number of clusters:  8
# Silhouette Coefficient: 0.079
# Number of clusters:  9
# Silhouette Coefficient: 0.079
# Number of clusters:  10
# Silhouette Coefficient: 0.079
# Number of clusters:  11
# Silhouette Coefficient: 0.086
# Number of clusters:  12
# Silhouette Coefficient: 0.079
# Number of clusters:  13
# Silhouette Coefficient: 0.076
# Number of clusters:  14
# Silhouette Coefficient: 0.078
# Number of clusters:  15
# Silhouette Coefficient: 0.082
# Number of clusters:  16
# Silhouette Coefficient: 0.088
# Number of clusters:  17
# Silhouette Coefficient: 0.084
# Number of clusters:  18
# Silhouette Coefficient: 0.067
# Number of clusters:  19
# Silhouette Coefficient: 0.083
# Number of clusters:  20
# Silhouette Coefficient: 0.077
# Number of clusters:  21
# Silhouette Coefficient: 0.076
# Number of clusters:  22
# Silhouette Coefficient: 0.077
# Number of clusters:  23
# Silhouette Coefficient: 0.091
# Number of clusters:  24
# Silhouette Coefficient: 0.071
# Number of clusters:  25
# Silhouette Coefficient: 0.082
# Number of clusters:  26
# Silhouette Coefficient: 0.077
# Number of clusters:  27
# Silhouette Coefficient: 0.075
# Number of clusters:  28
# Silhouette Coefficient: 0.077
# Number of clusters:  29
# Silhouette Coefficient: 0.079
# /Users/byan/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
X = df_all.values
clusterDocuments(X, scaled = True, PCA_X = True, n_clusters = 25, method = 'KMeans', visualize = 'PCA', verbose = True)
# Out:
# Number of clusters:  25
# Silhouette Coefficient: 0.080
# [15, 55, 63, 86, 99, 108, 144, 168, 173, 181]
# ['THE TRAGEDY OF CORIOLANUS ACT I. ' 'THE TRAGEDY OF CORIOLANUS ACT II.'
#  'THE TWO GENTLEMEN OF VERONA ACT III' 'CYMBELINE ACT I. '
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.'
#  'THE MERCHANT OF VENICE ACT IV.' 'THE TRAGEDY OF CORIOLANUS ACT III'
#  'CYMBELINE ACT II.' 'THE TWO GENTLEMEN OF VERONA ACT V. '
#  'THE TRAGEDY OF ROMEO AND JULIET ACT I. ']
#
#
# [2, 4, 16, 43, 52, 62, 71, 76, 151, 167, 170]
# ['THE MERCHANT OF VENICE ACT V. ' 'KING HENRY THE EIGHTH ACT III'
#  "LOVE'S LABOUR'S LOST ACT IV." 'THE TRAGEDY OF TITUS ANDRONICUS ACT IV.'
#  'THE LIFE OF TIMON OF ATHENS ACT IV.'
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT IV.'
#  'THE TRAGEDY OF MACBETH ACT III'
#  'THE FIRST PART OF HENRY THE SIXTH ACT I. '
#  'SECOND PART OF KING HENRY IV ACT I. ' 'KING JOHN ACT V. '
#  'KING JOHN ACT IV.']
#
#
# [9, 26, 49, 82, 103, 130, 143, 154, 159]
# ['THE TRAGEDY OF TITUS ANDRONICUS ACT V. '
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT V. ' 'KING JOHN ACT I. '
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT IV.' 'THE TEMPEST ACT IV.'
#  "A MIDSUMMER NIGHT'S DREAM ACT IV."
#  'THE LIFE OF KING HENRY THE FIFTH ACT V. ' 'THE TEMPEST ACT I. '
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT II.']
#
#
# [10, 11, 17, 58, 65, 67, 94, 114, 135, 174]
# ['KING JOHN ACT II.' 'THE TRAGEDY OF TITUS ANDRONICUS ACT 1. '
#  'THE LIFE OF KING HENRY THE FIFTH ACT II.' 'KING JOHN ACT III'
#  'THE FIRST PART OF HENRY THE SIXTH ACT II.'
#  'KING HENRY THE EIGHTH ACT IV.' 'THE TRAGEDY OF MACBETH ACT I. '
#  'KING RICHARD THE SECOND ACT IV.' 'THE TAMING OF THE SHREW ACT III'
#  'THE MERCHANT OF VENICE ACT I. ']
#
#
# [1, 3, 27, 28, 33, 37, 47, 74, 85, 87, 97, 157, 178, 180]
# ['THE TEMPEST ACT II.' 'TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III'
#  'THE LIFE OF TIMON OF ATHENS ACT III' 'THE TRAGEDY OF MACBETH ACT IV.'
#  "THE WINTER'S TALE ACT II." 'THE TRAGEDY OF MACBETH ACT V. '
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT III'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT II.'
#  'THE TRAGEDY OF KING LEAR ACT IV.' 'THE LIFE OF TIMON OF ATHENS ACT II.'
#  'THE TRAGEDY OF KING LEAR ACT II.'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT V. '
#  'THE TRAGEDY OF KING LEAR ACT III']
#
#
# [6, 18, 20, 80, 164]
# ['THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V. '
#  'THE TRAGEDY OF JULIUS CAESAR ACT III'
#  'THE MERRY WIVES OF WINDSOR ACT II.' 'THE TAMING OF THE SHREW ACT V. '
#  'THE TRAGEDY OF JULIUS CAESAR ACT V. ']
#
#
# 32
# ALLS WELL THAT ENDS WELL ACT II.
#
#
# [24, 39, 72, 104, 148, 162]
# ["A LOVER'S COMPLAINT ACT1609" 'THE LIFE OF KING HENRY THE FIFTH ACT I. '
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT I. '
#  'KING HENRY THE EIGHTH ACT II.' 'THE COMEDY OF ERRORS ACT I. '
#  'KING HENRY THE EIGHTH ACT V. ']
#
#
# [21, 34, 36, 42, 50, 79, 101, 102, 122, 127]
# ['AS YOU LIKE IT ACT IV.' 'THE TRAGEDY OF ROMEO AND JULIET ACT II.'
#  'KING RICHARD III ACT III' 'THE TRAGEDY OF CORIOLANUS ACT IV.'
#  'THE TAMING OF THE SHREW ACT I. ' 'KING RICHARD III ACT IV.'
#  'THE MERCHANT OF VENICE ACT II.' 'THE TAMING OF THE SHREW ACT IV.'
#  'THE TRAGEDY OF JULIUS CAESAR ACT II.' 'KING RICHARD THE SECOND ACT V. ']
#
#
# [112, 149]
# ['ALLS WELL THAT ENDS WELL ACT III'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT V. ']
#
#
# 22
# THE SONNETS ACT1609
#
#
# [30, 75, 92, 161, 171, 176]
# ['THE FIRST PART OF KING HENRY THE FOURTH ACT IV.'
#  'THE FIRST PART OF HENRY THE SIXTH ACT V. '
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT I. '
#  "THE WINTER'S TALE ACT III" 'THE HISTORY OF TROILUS AND CRESSIDA ACT III'
#  "A MIDSUMMER NIGHT'S DREAM ACT II."]
#
#
# [40, 54, 56, 60, 70, 145]
# ['THE SECOND PART OF KING HENRY THE SIXTH ACT I. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT II.'
#  'THE FIRST PART OF HENRY THE SIXTH ACT IV.'
#  'THE FIRST PART OF HENRY THE SIXTH ACT III'
#  'KING RICHARD THE SECOND ACT I. ' 'KING RICHARD III ACT V. ']
#
#
# [8, 38, 59, 95, 109, 132, 136, 139, 146, 147, 150, 156, 163]
# ['TWELFTH NIGHT; OR, WHAT YOU WILL ACT I. ' 'MEASURE FOR MEASURE ACT II.'
#  'AS YOU LIKE IT ACT I. ' 'THE TWO GENTLEMEN OF VERONA ACT II.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT III'
#  'KING RICHARD III ACT I. ' "THE WINTER'S TALE ACT IV."
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT IV.'
#  'THE LIFE OF KING HENRY THE FIFTH ACT IV.'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT III' 'CYMBELINE ACT V. '
#  "THE WINTER'S TALE ACT V. " 'MUCH ADO ABOUT NOTHING ACT IV.']
#
#
# [23, 118, 169, 175]
# ["LOVE'S LABOUR'S LOST ACT I. " 'THE TRAGEDY OF MACBETH ACT II.'
#  'THE LIFE OF KING HENRY THE FIFTH ACT III'
#  'ALLS WELL THAT ENDS WELL ACT IV ']
#
#
# [0, 53, 124, 133, 166]
# ['MUCH ADO ABOUT NOTHING ACT III' 'MUCH ADO ABOUT NOTHING ACT II.'
#  'MUCH ADO ABOUT NOTHING ACT I. ' 'AS YOU LIKE IT ACT V. '
#  'AS YOU LIKE IT ACT III']
#
#
# [44, 45, 57, 64, 116, 119, 134, 137, 141, 158]
# ['MEASURE FOR MEASURE ACT V. ' "THE WINTER'S TALE ACT I. "
#  'ALLS WELL THAT ENDS WELL ACT V S'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT V. ' 'KING RICHARD III ACT II.'
#  'THE TRAGEDY OF JULIUS CAESAR ACT I. ' 'ALLS WELL THAT ENDS WELL ACT I. '
#  'THE TAMING OF THE SHREW ACT Il.'
#  'THE TRAGEDY OF ROMEO AND JULIET ACT III'
#  'THE TWO GENTLEMEN OF VERONA ACT IV.']
#
#
# [14, 25, 78, 84, 90, 93, 96, 98, 106, 129, 165, 172]
# ['THE MERRY WIVES OF WINDSOR ACT III'
#  'THE TRAGEDY OF JULIUS CAESAR ACT IV.'
#  'THE MERRY WIVES OF WINDSOR ACT I. '
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.'
#  'SECOND PART OF KING HENRY IV ACT III' 'MUCH ADO ABOUT NOTHING ACT V. '
#  'THE TRAGEDY OF CORIOLANUS ACT V. ' 'SECOND PART OF KING HENRY IV ACT II.'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT II.'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT II.'
#  'KING HENRY THE EIGHTH ACT I. ' 'SECOND PART OF KING HENRY IV ACT V. ']
#
#
# [7, 35, 61, 68, 83, 88, 89]
# ['THE THIRD PART OF KING HENRY THE SIXTH ACT II.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT I. '
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT III'
#  "A MIDSUMMER NIGHT'S DREAM ACT III"
#  'THE TRAGEDY OF ROMEO AND JULIET ACT V. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT III'
#  'KING RICHARD THE SECOND ACT III']
#
#
# [41, 51, 91, 107, 111, 121, 126, 128, 142]
# ['AS YOU LIKE IT ACT II.' 'THE MERCHANT OF VENICE ACT III'
#  'CYMBELINE ACT IV.' 'KING RICHARD THE SECOND ACT II.'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT I. ' 'CYMBELINE ACT III'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT IV.'
#  'SECOND PART OF KING HENRY IV ACT IV.'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT II.']
#
#
# [31, 77, 81, 105, 110, 115, 120, 125, 131, 153]
# ['THE TRAGEDY OF KING LEAR ACT V. ' 'THE LIFE OF TIMON OF ATHENS ACT I. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.'
#  'THE TRAGEDY OF KING LEAR ACT I. ' 'THE TWO GENTLEMEN OF VERONA ACT I. '
#  "LOVE'S LABOUR'S LOST ACT V. "
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT I. '
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT V. '
#  'THE TRAGEDY OF ROMEO AND JULIET ACT IV.'
#  'THE MERRY WIVES OF WINDSOR ACT IV.']
#
#
# [5, 12, 155, 160, 179]
# ['THE TEMPEST ACT V. ' 'THE MERRY WIVES OF WINDSOR ACT V. '
#  'THE TEMPEST ACT III' "LOVE'S LABOUR'S LOST ACT III"
#  "A MIDSUMMER NIGHT'S DREAM ACT V. "]
#
#
# [29, 48, 69, 100, 117, 123, 138]
# ['THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I. '
#  'THE COMEDY OF ERRORS ACT III' 'MEASURE FOR MEASURE ACT I. '
#  'THE COMEDY OF ERRORS ACT IV.' "A MIDSUMMER NIGHT'S DREAM ACT I. "
#  'THE COMEDY OF ERRORS ACT Il.' 'THE COMEDY OF ERRORS ACT V. ']
#
#
# [13, 19, 46, 73, 113, 140, 152, 177]
# ['THE FIRST PART OF KING HENRY THE FOURTH ACT III'
#  "LOVE'S LABOUR'S LOST ACT II."
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT V. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT V. '
#  'ALLS WELL THAT ENDS WELL ACT IV.'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III'
#  'THE LIFE OF TIMON OF ATHENS ACT V. ' 'MEASURE FOR MEASURE ACT III']
#
#
# 66
# ALLS WELL THAT ENDS WELL ACT V.
# /Users/byan/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %% [markdown]
# > By adding the features of average sentence length, number of unique words normalized by total number of words, fequency of conjunctions, and etc., acts are clustered according to the writing style (need to be verified by visualization).

# %% [markdown]
# ### Affinity Propagation

# %%
print('No mormalization')
clusterDocuments(X, scaled = False, PCA_X=False, method = 'AffinityPropagation', visualize = 'None', verbose = False)
print('Normalize to N(0,1)')
clusterDocuments(X, scaled = True, method = 'AffinityPropagation', visualize = 'None', verbose = False)
# Out:
# No mormalization
# Number of clusters:  19
# Silhouette Coefficient: 0.144
# Normalize to N(0,1)
# Number of clusters:  26
# Silhouette Coefficient: 0.054
# /Users/byan/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
clusterDocuments(X, scaled = True, PCA_X = True, method = 'AffinityPropagation')
# Out:
# Number of clusters:  26
# Silhouette Coefficient: 0.054
# [1, 3, 28, 35, 37, 47, 71, 81, 87, 97, 131]
# ['THE TEMPEST ACT II.' 'TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.'
#  'THE LIFE OF TIMON OF ATHENS ACT III'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT I. '
#  "THE WINTER'S TALE ACT II." 'THE TRAGEDY OF MACBETH ACT V. '
#  'THE TRAGEDY OF MACBETH ACT III'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.'
#  'THE TRAGEDY OF KING LEAR ACT IV.' 'THE LIFE OF TIMON OF ATHENS ACT II.'
#  'THE TRAGEDY OF ROMEO AND JULIET ACT IV.']
#
#
# [6, 14, 77, 78, 84, 98, 105, 153]
# ['THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V. '
#  'THE MERRY WIVES OF WINDSOR ACT III' 'THE LIFE OF TIMON OF ATHENS ACT I. '
#  'THE MERRY WIVES OF WINDSOR ACT I. '
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.'
#  'SECOND PART OF KING HENRY IV ACT II.' 'THE TRAGEDY OF KING LEAR ACT I. '
#  'THE MERRY WIVES OF WINDSOR ACT IV.']
#
#
# 22
# THE SONNETS ACT1609
#
#
# 24
# A LOVER'S COMPLAINT ACT1609
#
#
# [27, 31, 74, 79, 85, 106, 141, 157, 178, 180]
# ['THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III'
#  'THE TRAGEDY OF KING LEAR ACT V. '
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT III' 'KING RICHARD III ACT IV.'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT II.'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT II.'
#  'THE TRAGEDY OF ROMEO AND JULIET ACT III'
#  'THE TRAGEDY OF KING LEAR ACT II.'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT V. '
#  'THE TRAGEDY OF KING LEAR ACT III']
#
#
# [9, 21, 29, 48, 69, 100, 108, 116, 117, 127, 134, 136, 138, 139, 150]
# ['THE TRAGEDY OF TITUS ANDRONICUS ACT V. ' 'AS YOU LIKE IT ACT IV.'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I. '
#  'THE COMEDY OF ERRORS ACT III' 'MEASURE FOR MEASURE ACT I. '
#  'THE COMEDY OF ERRORS ACT IV.' 'THE MERCHANT OF VENICE ACT IV.'
#  'KING RICHARD III ACT II.' "A MIDSUMMER NIGHT'S DREAM ACT I. "
#  'KING RICHARD THE SECOND ACT V. ' 'ALLS WELL THAT ENDS WELL ACT I. '
#  "THE WINTER'S TALE ACT IV." 'THE COMEDY OF ERRORS ACT V. '
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT IV.' 'CYMBELINE ACT V. ']
#
#
# [2, 43, 51, 128, 133]
# ['THE MERCHANT OF VENICE ACT V. ' 'THE TRAGEDY OF TITUS ANDRONICUS ACT IV.'
#  'THE MERCHANT OF VENICE ACT III' 'SECOND PART OF KING HENRY IV ACT IV.'
#  'AS YOU LIKE IT ACT V. ']
#
#
# [40, 54, 56, 60, 73, 89, 123, 143, 148]
# ['THE SECOND PART OF KING HENRY THE SIXTH ACT I. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT II.'
#  'THE FIRST PART OF HENRY THE SIXTH ACT IV.'
#  'THE FIRST PART OF HENRY THE SIXTH ACT III'
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT V. '
#  'KING RICHARD THE SECOND ACT III' 'THE COMEDY OF ERRORS ACT Il.'
#  'THE LIFE OF KING HENRY THE FIFTH ACT V. ' 'THE COMEDY OF ERRORS ACT I. ']
#
#
# [10, 11, 26, 36, 58, 61, 159]
# ['KING JOHN ACT II.' 'THE TRAGEDY OF TITUS ANDRONICUS ACT 1. '
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT V. '
#  'KING RICHARD III ACT III' 'KING JOHN ACT III'
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT III'
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT II.']
#
#
# [63, 82, 109, 126, 135, 144, 168, 173]
# ['THE TWO GENTLEMEN OF VERONA ACT III'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT IV.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT III'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT IV.'
#  'THE TAMING OF THE SHREW ACT III' 'THE TRAGEDY OF CORIOLANUS ACT III'
#  'CYMBELINE ACT II.' 'THE TWO GENTLEMEN OF VERONA ACT V. ']
#
#
# 66
# ALLS WELL THAT ENDS WELL ACT V.
#
#
# [39, 72]
# ['THE LIFE OF KING HENRY THE FIFTH ACT I. '
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT I. ']
#
#
# [18, 20, 25, 44, 59, 68, 80, 93, 96, 111, 129, 172, 177]
# ['THE TRAGEDY OF JULIUS CAESAR ACT III'
#  'THE MERRY WIVES OF WINDSOR ACT II.'
#  'THE TRAGEDY OF JULIUS CAESAR ACT IV.' 'MEASURE FOR MEASURE ACT V. '
#  'AS YOU LIKE IT ACT I. ' "A MIDSUMMER NIGHT'S DREAM ACT III"
#  'THE TAMING OF THE SHREW ACT V. ' 'MUCH ADO ABOUT NOTHING ACT V. '
#  'THE TRAGEDY OF CORIOLANUS ACT V. '
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT I. '
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT II.'
#  'SECOND PART OF KING HENRY IV ACT V. ' 'MEASURE FOR MEASURE ACT III']
#
#
# [8, 38, 95, 132, 137, 147, 158, 163]
# ['TWELFTH NIGHT; OR, WHAT YOU WILL ACT I. ' 'MEASURE FOR MEASURE ACT II.'
#  'THE TWO GENTLEMEN OF VERONA ACT II.' 'KING RICHARD III ACT I. '
#  'THE TAMING OF THE SHREW ACT Il.'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT III'
#  'THE TWO GENTLEMEN OF VERONA ACT IV.' 'MUCH ADO ABOUT NOTHING ACT IV.']
#
#
# [15, 16, 33, 86, 99, 146, 174, 181]
# ['THE TRAGEDY OF CORIOLANUS ACT I. ' "LOVE'S LABOUR'S LOST ACT IV."
#  'THE TRAGEDY OF MACBETH ACT IV.' 'CYMBELINE ACT I. '
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.'
#  'THE LIFE OF KING HENRY THE FIFTH ACT IV.'
#  'THE MERCHANT OF VENICE ACT I. ' 'THE TRAGEDY OF ROMEO AND JULIET ACT I. ']
#
#
# [4, 17, 65, 75, 94, 114]
# ['KING HENRY THE EIGHTH ACT III' 'THE LIFE OF KING HENRY THE FIFTH ACT II.'
#  'THE FIRST PART OF HENRY THE SIXTH ACT II.'
#  'THE FIRST PART OF HENRY THE SIXTH ACT V. '
#  'THE TRAGEDY OF MACBETH ACT I. ' 'KING RICHARD THE SECOND ACT IV.']
#
#
# [0, 34, 42, 45, 50, 57, 64, 101, 102, 119, 122, 154, 164, 169]
# ['MUCH ADO ABOUT NOTHING ACT III' 'THE TRAGEDY OF ROMEO AND JULIET ACT II.'
#  'THE TRAGEDY OF CORIOLANUS ACT IV.' "THE WINTER'S TALE ACT I. "
#  'THE TAMING OF THE SHREW ACT I. ' 'ALLS WELL THAT ENDS WELL ACT V S'
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT V. '
#  'THE MERCHANT OF VENICE ACT II.' 'THE TAMING OF THE SHREW ACT IV.'
#  'THE TRAGEDY OF JULIUS CAESAR ACT I. '
#  'THE TRAGEDY OF JULIUS CAESAR ACT II.' 'THE TEMPEST ACT I. '
#  'THE TRAGEDY OF JULIUS CAESAR ACT V. '
#  'THE LIFE OF KING HENRY THE FIFTH ACT III']
#
#
# [23, 53, 110, 115, 120, 124, 125, 166]
# ["LOVE'S LABOUR'S LOST ACT I. " 'MUCH ADO ABOUT NOTHING ACT II.'
#  'THE TWO GENTLEMEN OF VERONA ACT I. ' "LOVE'S LABOUR'S LOST ACT V. "
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT I. '
#  'MUCH ADO ABOUT NOTHING ACT I. '
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT V. '
#  'AS YOU LIKE IT ACT III']
#
#
# [67, 103, 118, 130, 160, 175]
# ['KING HENRY THE EIGHTH ACT IV.' 'THE TEMPEST ACT IV.'
#  'THE TRAGEDY OF MACBETH ACT II.' "A MIDSUMMER NIGHT'S DREAM ACT IV."
#  "LOVE'S LABOUR'S LOST ACT III" 'ALLS WELL THAT ENDS WELL ACT IV ']
#
#
# [13, 41, 46, 55, 90, 121, 140, 156]
# ['THE FIRST PART OF KING HENRY THE FOURTH ACT III' 'AS YOU LIKE IT ACT II.'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT V. '
#  'THE TRAGEDY OF CORIOLANUS ACT II.' 'SECOND PART OF KING HENRY IV ACT III'
#  'CYMBELINE ACT III' 'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III'
#  "THE WINTER'S TALE ACT V. "]
#
#
# [112, 149]
# ['ALLS WELL THAT ENDS WELL ACT III'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT V. ']
#
#
# [19, 32, 83, 113, 142, 152]
# ["LOVE'S LABOUR'S LOST ACT II." 'ALLS WELL THAT ENDS WELL ACT II.'
#  'THE TRAGEDY OF ROMEO AND JULIET ACT V. '
#  'ALLS WELL THAT ENDS WELL ACT IV.'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT II.'
#  'THE LIFE OF TIMON OF ATHENS ACT V. ']
#
#
# [5, 155, 165, 179]
# ['THE TEMPEST ACT V. ' 'THE TEMPEST ACT III'
#  'KING HENRY THE EIGHTH ACT I. ' "A MIDSUMMER NIGHT'S DREAM ACT V. "]
#
#
# [7, 30, 49, 70, 88, 92, 104, 145, 161, 171, 176]
# ['THE THIRD PART OF KING HENRY THE SIXTH ACT II.'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT IV.' 'KING JOHN ACT I. '
#  'KING RICHARD THE SECOND ACT I. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT III'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT I. '
#  'KING HENRY THE EIGHTH ACT II.' 'KING RICHARD III ACT V. '
#  "THE WINTER'S TALE ACT III" 'THE HISTORY OF TROILUS AND CRESSIDA ACT III'
#  "A MIDSUMMER NIGHT'S DREAM ACT II."]
#
#
# 162
# KING HENRY THE EIGHTH ACT V.
#
#
# [12, 52, 62, 76, 91, 107, 151, 167, 170]
# ['THE MERRY WIVES OF WINDSOR ACT V. ' 'THE LIFE OF TIMON OF ATHENS ACT IV.'
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT IV.'
#  'THE FIRST PART OF HENRY THE SIXTH ACT I. ' 'CYMBELINE ACT IV.'
#  'KING RICHARD THE SECOND ACT II.' 'SECOND PART OF KING HENRY IV ACT I. '
#  'KING JOHN ACT V. ' 'KING JOHN ACT IV.']
# /Users/byan/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
clusterDocuments(X, scaled = True, method = 'AffinityPropagation', visualize = 'PCA', verbose = False)
clusterDocuments(X, scaled = True, method = 'AffinityPropagation', visualize = 'MDS', verbose = False)
# Out:
# Number of clusters:  26
# Silhouette Coefficient: 0.054
# /Users/byan/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# Number of clusters:  26
# Silhouette Coefficient: 0.054

# %%
X = df_all.values
for n in np.arange(2,30,1):
    clusterDocuments(X, scaled=True, PCA_X = True, n_clusters = n, method = 'AgglomerativeClustering', visualize = False, verbose = False)
# Out:
# Number of clusters:  2
# Silhouette Coefficient: 0.378
# Number of clusters:  3
# Silhouette Coefficient: 0.082
# Number of clusters:  4
# Silhouette Coefficient: 0.047
# Number of clusters:  5
# Silhouette Coefficient: 0.054
# Number of clusters:  6
# Silhouette Coefficient: 0.060
# Number of clusters:  7
# Silhouette Coefficient: 0.061
# Number of clusters:  8
# Silhouette Coefficient: 0.064
# Number of clusters:  9
# Silhouette Coefficient: 0.073
# Number of clusters:  10
# Silhouette Coefficient: 0.079
# Number of clusters:  11
# Silhouette Coefficient: 0.074
# Number of clusters:  12
# Silhouette Coefficient: 0.076
# Number of clusters:  13
# Silhouette Coefficient: 0.075
# Number of clusters:  14
# Silhouette Coefficient: 0.074
# Number of clusters:  15
# Silhouette Coefficient: 0.079
# Number of clusters:  16
# Silhouette Coefficient: 0.084
# Number of clusters:  17
# Silhouette Coefficient: 0.088
# Number of clusters:  18
# Silhouette Coefficient: 0.089
# Number of clusters:  19
# Silhouette Coefficient: 0.090
# Number of clusters:  20
# Silhouette Coefficient: 0.088
# Number of clusters:  21
# Silhouette Coefficient: 0.091
# Number of clusters:  22
# Silhouette Coefficient: 0.092
# Number of clusters:  23
# Silhouette Coefficient: 0.093
# Number of clusters:  24
# Silhouette Coefficient: 0.094
# Number of clusters:  25
# Silhouette Coefficient: 0.094
# Number of clusters:  26
# Silhouette Coefficient: 0.094
# Number of clusters:  27
# Silhouette Coefficient: 0.096
# Number of clusters:  28
# Silhouette Coefficient: 0.097
# Number of clusters:  29
# Silhouette Coefficient: 0.100
# /Users/byan/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
clusterDocuments(X, n_clusters = 23, scaled = True, PCA_X = True, method = 'AgglomerativeClustering')
# Out:
# Number of clusters:  23
# Silhouette Coefficient: 0.093
# [4, 7, 13, 40, 46, 49, 54, 56, 60, 73, 75, 83, 88, 89, 130, 145, 152]
# ['KING HENRY THE EIGHTH ACT III'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT II.'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT III'
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT I. '
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT V. ' 'KING JOHN ACT I. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT II.'
#  'THE FIRST PART OF HENRY THE SIXTH ACT IV.'
#  'THE FIRST PART OF HENRY THE SIXTH ACT III'
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT V. '
#  'THE FIRST PART OF HENRY THE SIXTH ACT V. '
#  'THE TRAGEDY OF ROMEO AND JULIET ACT V. '
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT III'
#  'KING RICHARD THE SECOND ACT III' "A MIDSUMMER NIGHT'S DREAM ACT IV."
#  'KING RICHARD III ACT V. ' 'THE LIFE OF TIMON OF ATHENS ACT V. ']
#
#
# [39, 67, 72, 104, 148, 162]
# ['THE LIFE OF KING HENRY THE FIFTH ACT I. ' 'KING HENRY THE EIGHTH ACT IV.'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT I. '
#  'KING HENRY THE EIGHTH ACT II.' 'THE COMEDY OF ERRORS ACT I. '
#  'KING HENRY THE EIGHTH ACT V. ']
#
#
# [17, 30, 65, 92, 114, 151, 161, 167, 169, 171, 174, 176]
# ['THE LIFE OF KING HENRY THE FIFTH ACT II.'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT IV.'
#  'THE FIRST PART OF HENRY THE SIXTH ACT II.'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT I. '
#  'KING RICHARD THE SECOND ACT IV.' 'SECOND PART OF KING HENRY IV ACT I. '
#  "THE WINTER'S TALE ACT III" 'KING JOHN ACT V. '
#  'THE LIFE OF KING HENRY THE FIFTH ACT III'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT III'
#  'THE MERCHANT OF VENICE ACT I. ' "A MIDSUMMER NIGHT'S DREAM ACT II."]
#
#
# [15, 55, 63, 76, 82, 86, 108, 109, 144, 168, 173]
# ['THE TRAGEDY OF CORIOLANUS ACT I. ' 'THE TRAGEDY OF CORIOLANUS ACT II.'
#  'THE TWO GENTLEMEN OF VERONA ACT III'
#  'THE FIRST PART OF HENRY THE SIXTH ACT I. '
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT IV.' 'CYMBELINE ACT I. '
#  'THE MERCHANT OF VENICE ACT IV.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT III'
#  'THE TRAGEDY OF CORIOLANUS ACT III' 'CYMBELINE ACT II.'
#  'THE TWO GENTLEMEN OF VERONA ACT V. ']
#
#
# [35, 38, 44, 50, 64, 68, 102, 116, 119, 137, 141]
# ['THE THIRD PART OF KING HENRY THE SIXTH ACT I. '
#  'MEASURE FOR MEASURE ACT II.' 'MEASURE FOR MEASURE ACT V. '
#  'THE TAMING OF THE SHREW ACT I. '
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT V. '
#  "A MIDSUMMER NIGHT'S DREAM ACT III" 'THE TAMING OF THE SHREW ACT IV.'
#  'KING RICHARD III ACT II.' 'THE TRAGEDY OF JULIUS CAESAR ACT I. '
#  'THE TAMING OF THE SHREW ACT Il.'
#  'THE TRAGEDY OF ROMEO AND JULIET ACT III']
#
#
# [1, 3, 20, 27, 28, 77, 81, 85, 87, 97, 105, 106, 131, 153, 157, 177, 178]
# ['THE TEMPEST ACT II.' 'TWELFTH NIGHT; OR, WHAT YOU WILL ACT IV.'
#  'THE MERRY WIVES OF WINDSOR ACT II.'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III'
#  'THE LIFE OF TIMON OF ATHENS ACT III'
#  'THE LIFE OF TIMON OF ATHENS ACT I. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT II.'
#  'THE TRAGEDY OF KING LEAR ACT IV.' 'THE LIFE OF TIMON OF ATHENS ACT II.'
#  'THE TRAGEDY OF KING LEAR ACT I. '
#  'TWELFTH NIGHT; OR, WHAT YOU WILL ACT II.'
#  'THE TRAGEDY OF ROMEO AND JULIET ACT IV.'
#  'THE MERRY WIVES OF WINDSOR ACT IV.' 'THE TRAGEDY OF KING LEAR ACT II.'
#  'MEASURE FOR MEASURE ACT III'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT V. ']
#
#
# [0, 21, 23, 31, 34, 42, 53, 110, 115, 118, 120, 124, 125, 133, 166]
# ['MUCH ADO ABOUT NOTHING ACT III' 'AS YOU LIKE IT ACT IV.'
#  "LOVE'S LABOUR'S LOST ACT I. " 'THE TRAGEDY OF KING LEAR ACT V. '
#  'THE TRAGEDY OF ROMEO AND JULIET ACT II.'
#  'THE TRAGEDY OF CORIOLANUS ACT IV.' 'MUCH ADO ABOUT NOTHING ACT II.'
#  'THE TWO GENTLEMEN OF VERONA ACT I. ' "LOVE'S LABOUR'S LOST ACT V. "
#  'THE TRAGEDY OF MACBETH ACT II.'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT I. '
#  'MUCH ADO ABOUT NOTHING ACT I. '
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT V. '
#  'AS YOU LIKE IT ACT V. ' 'AS YOU LIKE IT ACT III']
#
#
# [19, 113, 142, 175]
# ["LOVE'S LABOUR'S LOST ACT II." 'ALLS WELL THAT ENDS WELL ACT IV.'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT II.'
#  'ALLS WELL THAT ENDS WELL ACT IV ']
#
#
# [10, 11, 70, 128, 143]
# ['KING JOHN ACT II.' 'THE TRAGEDY OF TITUS ANDRONICUS ACT 1. '
#  'KING RICHARD THE SECOND ACT I. ' 'SECOND PART OF KING HENRY IV ACT IV.'
#  'THE LIFE OF KING HENRY THE FIFTH ACT V. ']
#
#
# [6, 14, 78, 84, 96, 98, 129, 172]
# ['THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT V. '
#  'THE MERRY WIVES OF WINDSOR ACT III' 'THE MERRY WIVES OF WINDSOR ACT I. '
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT IV.'
#  'THE TRAGEDY OF CORIOLANUS ACT V. ' 'SECOND PART OF KING HENRY IV ACT II.'
#  'THE FIRST PART OF KING HENRY THE FOURTH ACT II.'
#  'SECOND PART OF KING HENRY IV ACT V. ']
#
#
# [112, 149]
# ['ALLS WELL THAT ENDS WELL ACT III'
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT V. ']
#
#
# [2, 43, 51, 52, 62, 71, 91, 107, 135, 170]
# ['THE MERCHANT OF VENICE ACT V. ' 'THE TRAGEDY OF TITUS ANDRONICUS ACT IV.'
#  'THE MERCHANT OF VENICE ACT III' 'THE LIFE OF TIMON OF ATHENS ACT IV.'
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT IV.'
#  'THE TRAGEDY OF MACBETH ACT III' 'CYMBELINE ACT IV.'
#  'KING RICHARD THE SECOND ACT II.' 'THE TAMING OF THE SHREW ACT III'
#  'KING JOHN ACT IV.']
#
#
# [8, 37, 45, 57, 59, 74, 95, 132, 134, 136, 139, 140, 146, 147, 150, 156, 158, 163]
# ['TWELFTH NIGHT; OR, WHAT YOU WILL ACT I. ' "THE WINTER'S TALE ACT II."
#  "THE WINTER'S TALE ACT I. " 'ALLS WELL THAT ENDS WELL ACT V S'
#  'AS YOU LIKE IT ACT I. ' 'TWELFTH NIGHT; OR, WHAT YOU WILL ACT III'
#  'THE TWO GENTLEMEN OF VERONA ACT II.' 'KING RICHARD III ACT I. '
#  'ALLS WELL THAT ENDS WELL ACT I. ' "THE WINTER'S TALE ACT IV."
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT IV.'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT III'
#  'THE LIFE OF KING HENRY THE FIFTH ACT IV.'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT III' 'CYMBELINE ACT V. '
#  "THE WINTER'S TALE ACT V. " 'THE TWO GENTLEMEN OF VERONA ACT IV.'
#  'MUCH ADO ABOUT NOTHING ACT IV.']
#
#
# [29, 48, 69, 100, 117, 123, 138]
# ['THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I. '
#  'THE COMEDY OF ERRORS ACT III' 'MEASURE FOR MEASURE ACT I. '
#  'THE COMEDY OF ERRORS ACT IV.' "A MIDSUMMER NIGHT'S DREAM ACT I. "
#  'THE COMEDY OF ERRORS ACT Il.' 'THE COMEDY OF ERRORS ACT V. ']
#
#
# [5, 12, 155, 160, 165, 179]
# ['THE TEMPEST ACT V. ' 'THE MERRY WIVES OF WINDSOR ACT V. '
#  'THE TEMPEST ACT III' "LOVE'S LABOUR'S LOST ACT III"
#  'KING HENRY THE EIGHTH ACT I. ' "A MIDSUMMER NIGHT'S DREAM ACT V. "]
#
#
# 22
# THE SONNETS ACT1609
#
#
# [16, 33, 47, 90, 94, 99, 180, 181]
# ["LOVE'S LABOUR'S LOST ACT IV." 'THE TRAGEDY OF MACBETH ACT IV.'
#  'THE TRAGEDY OF MACBETH ACT V. ' 'SECOND PART OF KING HENRY IV ACT III'
#  'THE TRAGEDY OF MACBETH ACT I. '
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT II.'
#  'THE TRAGEDY OF KING LEAR ACT III'
#  'THE TRAGEDY OF ROMEO AND JULIET ACT I. ']
#
#
# 66
# ALLS WELL THAT ENDS WELL ACT V.
#
#
# 24
# A LOVER'S COMPLAINT ACT1609
#
#
# [9, 26, 36, 58, 61, 79, 101, 122, 127, 154, 159]
# ['THE TRAGEDY OF TITUS ANDRONICUS ACT V. '
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT V. '
#  'KING RICHARD III ACT III' 'KING JOHN ACT III'
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT III' 'KING RICHARD III ACT IV.'
#  'THE MERCHANT OF VENICE ACT II.' 'THE TRAGEDY OF JULIUS CAESAR ACT II.'
#  'KING RICHARD THE SECOND ACT V. ' 'THE TEMPEST ACT I. '
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT II.']
#
#
# [32, 103]
# ['ALLS WELL THAT ENDS WELL ACT II.' 'THE TEMPEST ACT IV.']
#
#
# [41, 111, 121, 126]
# ['AS YOU LIKE IT ACT II.'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT I. ' 'CYMBELINE ACT III'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT IV.']
#
#
# [18, 25, 80, 93, 164]
# ['THE TRAGEDY OF JULIUS CAESAR ACT III'
#  'THE TRAGEDY OF JULIUS CAESAR ACT IV.' 'THE TAMING OF THE SHREW ACT V. '
#  'MUCH ADO ABOUT NOTHING ACT V. ' 'THE TRAGEDY OF JULIUS CAESAR ACT V. ']
# /Users/byan/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)

# %%
#clusterDocuments(X, n_clusters = 8, scaled = True, PCA_X = True, method = 'SpectralClustering', verbose = False)
clusterDocuments(X, scaled = True, PCA_X = True, method = 'Birch', verbose = False)
#clusterDocuments(X, scaled = True, PCA_X = True, method = 'DBSCAN')
clusterDocuments(X, scaled = True, PCA_X = True, method = 'MeanShift', verbose = False)
clusterDocuments(X, scaled = True, method = 'MeanShift', visualize = 'MDS', verbose = False)
# Out:
# Number of clusters:  3
# Silhouette Coefficient: 0.082
# Number of clusters:  7
# Silhouette Coefficient: 0.291
# /Users/byan/anaconda/lib/python3.4/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# Number of clusters:  7
# Silhouette Coefficient: 0.291

# %%
def print3D(X, x_label, y_label, z_label, title, labels):
    fig = plt.figure(1, figsize=(11, 10))
    plt.clf()
    ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

    plt.cla()
    
    ax.scatter(X[:, 1], X[:, 0], X[:, 2], c=labels.astype(np.float), s=50)
    ax.dist = 11

    ax.w_xaxis.set_ticklabels([])
    ax.w_yaxis.set_ticklabels([])
    ax.w_zaxis.set_ticklabels([])
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.set_zlabel(z_label)

X_3D = PCA(n_components = 3).fit_transform(preprocessing.scale(X))
labels = getLabels(X_3D)
    
print3D(X_3D, '1st PCA Component', '2nd PCA Component', '3rd PCA Component', '3D plot', labels)
# Out:
# /Users/byan/anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
