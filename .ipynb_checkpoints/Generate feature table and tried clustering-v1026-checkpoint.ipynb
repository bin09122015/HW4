# %%
import nltk
from nltk.corpus import stopwords
import string

import json


# Import works.json: title, words, sentences of 38 pieces
with open('works_v1025.json', 'r') as f:
    try:
        works = json.load(f)
    # if the file is empty the ValueError will be thrown
    except ValueError:
        works = {}

# %%
from nltk import FreqDist

def getFreqDist(words):
    nltk_text = nltk.Text(words)
    
    return FreqDist(nltk_text)

# %%
def getCountFrequency(words, freq):
    nltk_text = nltk.Text(words)
    freq_dist = FreqDist(nltk_text)
    
    count = 0
    for key,value in freq_dist.items():
        if value == freq:
            count += 1
    
    return count    

def getHapaxLegomena(words):
    return getCountFrequency(words, 1)

# %%
def getDisLegomena(words):
    return getCountFrequency(words, 2)

# %%
def getNumberUniqueWords(words):
    return len(getFreqDist(words))

# %%
def getWordLengthDistribution(words):
    result = FreqDist()
    for w in words:        
        result[len(w)] += 1
    
    return result

def printFreqDist(freq_dist):
    for key,value in freq_dist.items():
        print (key,value)

# %%
def getSentenceLengthDistribution(sents):
    result = FreqDist()
    for s in sents:        
        result[len(s)] += 1
    
    return result

# %%
def getAverageSentenceLength(sents):
    results = 0
    for s in sents:        
        results += len(s)
    return results/len(sents)

# %%
def getPronounDistribution(sents):
    result = FreqDist()
    pronouns = ['I', 'you', 'he', 'she', 'it', 'we', 'you', 'they', 'thou', 'ye']
    for s in sents:
        count = 0
        for p in pronouns:
            count += s.count(p)
        result[count] += 1
    
    return result

# %%
def getNumberOfPronoun(sentences):
    pronouns = ['I', 'you', 'he', 'she', 'it', 'we', 'you', 'they', 'thou', 'ye']
    count = 0
    for s in sentences:        
        for p in pronouns:
            count += s.count(p)
    
    return count

# %%
def getConjunctionDistribution(sents):
    result = FreqDist()
    conjunctions = ['for', 'and', 'nor', 'but', 'or', 'yet', 'so', 'after', 'although', 'as', 'because', 'before', 'if',
                'once', 'since', 'though', 'unless', 'until', 'when', 'where', 'while', 'whether', 'either', 'neither',
                'as', 'than', 'even', 'then', 'lest', 'rather', 'which', 'who', 'why', 'that', 'till']
    for s in sents:
        count = 0
        for c in conjunctions:
            count += s.count(c)
        result[count] += 1
    
    return result

# %%
def getNumberOfConjunction(sents):
    count = 0
    conjunctions = ['for', 'and', 'nor', 'but', 'or', 'yet', 'so', 'after', 'although', 'as', 'because', 'before', 'if',
                'once', 'since', 'though', 'unless', 'until', 'when', 'where', 'while', 'whether', 'either', 'neither',
                'as', 'than', 'even', 'then', 'lest', 'rather', 'which', 'who', 'why', 'that', 'till']
    for s in sents:
        for c in conjunctions:
            count += s.count(c)
    
    return count

# %%
# %matplotlib inline 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from __future__ import division

# Create a feature table for all acts
# Currently only has some simple features

featureTable = {}

featureTable = {'act': [], 'HapaxLegomena': [], 'DisLegomena': [], 
                'numberUniqueWords': [], 'averageSentenceLength': [], 'numberOfSentences': [],
                'numberOfPronoun': [], 'numberOfConjunction': []}


for act, content in works.items():
    words_nonStemmed = content['words_nonStemmed']
    words_all = content['words_all']
    sentences = content['sentences']
    # Normalize by number of all words
    normalizer = len(words_all)
    featureTable['act'].append(act)
    featureTable['HapaxLegomena'].append(getHapaxLegomena(words_nonStemmed)/normalizer)
    featureTable['DisLegomena'].append(getDisLegomena(words_nonStemmed)/normalizer)
    featureTable['numberUniqueWords'].append(getNumberUniqueWords(words_nonStemmed)/normalizer)
    featureTable['averageSentenceLength'].append(getAverageSentenceLength(sentences))
    featureTable['numberOfSentences'].append(len(sentences))
    featureTable['numberOfPronoun'].append(getNumberOfPronoun(sentences)/normalizer)
    featureTable['numberOfConjunction'].append(getNumberOfConjunction(sentences)/normalizer)
        

print(len(featureTable['act']))


df = pd.DataFrame(featureTable)
df.set_index(['act'], inplace=True)
df.head()
# Out:
# 223
#                                                 DisLegomena  HapaxLegomena  \
# act
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.      0.026571       0.112787
# THE COMEDY OF ERRORS ACT V.                        0.030214       0.101972
# CYMBELINE ACT II.                                  0.029124       0.130766
# THE LIFE OF KING HENRY THE FIFTH ACT I.            0.038578       0.164650
# THE MERRY WIVES OF WINDSOR ACT II.                 0.019582       0.091480
#
#                                                 averageSentenceLength  \
# act
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.               56.971088
# THE COMEDY OF ERRORS ACT V.                                 55.916890
# CYMBELINE ACT II.                                           51.320879
# THE LIFE OF KING HENRY THE FIFTH ACT I.                    125.408805
# THE MERRY WIVES OF WINDSOR ACT II.                          45.526235
#
#                                                 numberOfConjunction  \
# act
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.              0.134099
# THE COMEDY OF ERRORS ACT V.                                0.120646
# CYMBELINE ACT II.                                          0.124120
# THE LIFE OF KING HENRY THE FIFTH ACT I.                    0.139687
# THE MERRY WIVES OF WINDSOR ACT II.                         0.135321
#
#                                                 numberOfPronoun  \
# act
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.          0.222945
# THE COMEDY OF ERRORS ACT V.                            0.202686
# CYMBELINE ACT II.                                      0.224199
# THE LIFE OF KING HENRY THE FIFTH ACT I.                0.183308
# THE MERRY WIVES OF WINDSOR ACT II.                     0.209265
#
#                                                 numberOfSentences  \
# act
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.                 588
# THE COMEDY OF ERRORS ACT V.                                   373
# CYMBELINE ACT II.                                             455
# THE LIFE OF KING HENRY THE FIFTH ACT I.                       159
# THE MERRY WIVES OF WINDSOR ACT II.                            648
#
#                                                 numberUniqueWords
# act
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.            0.177277
# THE COMEDY OF ERRORS ACT V.                              0.170373
# CYMBELINE ACT II.                                        0.195856
# THE LIFE OF KING HENRY THE FIFTH ACT I.                  0.240797
# THE MERRY WIVES OF WINDSOR ACT II.                       0.146573

# %%
# Filter out wierd acts, e.g. the beginning of a play

df = df[df['averageSentenceLength'] < 168]

# %%
pd.scatter_matrix(df, alpha=0.2, figsize=(16, 16), diagonal='kde')
plt.show()
# Out:
# /Users/binyan/Python/anaconda/envs/py34/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
title = []
text = []

for act in df.index:
    content = works[act]
    title.append(act)
    text.append(content['text'])

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from __future__ import print_function

from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer
from sklearn import metrics

from sklearn.cluster import KMeans, MiniBatchKMeans
import numpy as np

# %%
# excluding stop words, n-grams is an input
def getTfidf(ngram_range):
    count_vect = CountVectorizer(ngram_range=ngram_range, stop_words='english')
    X_counts = count_vect.fit_transform(text)

    tfidf_transformer = TfidfTransformer(use_idf=True).fit(X_counts)
    X_tfidf = tfidf_transformer.transform(X_counts)
    return X_tfidf

# %%
def getSVD(X_tfidf, n_components):

    randomState = np.random.seed(1)
    svd = TruncatedSVD(n_components = n_components, random_state = randomState)
    lsa = make_pipeline(svd, Normalizer(copy=False))
    X = lsa.fit_transform(X_tfidf)

    explained_variance = svd.explained_variance_ratio_.sum()
    print("Explained variance of the SVD step: {}%".format(
        int(explained_variance * 100)))
    
    return X

def clusterDocuments(X, n_clusters):

    km = KMeans(n_clusters=n_clusters, init='k-means++', max_iter=500, n_init=5, random_state = randomState)
    km.fit_predict(X)    
    return km.labels_

def printClusters(labels):
    for i in set(labels):
        index = np.squeeze(np.argwhere(labels == i)).tolist()
        print(index)
    
        print(np.array(title)[index])
        print('\n')

# Cluster only using n-grams as features
X_tfidf = getTfidf(ngram_range = (2,4))
X = getSVD(X_tfidf, n_components = 20)
labels = clusterDocuments(X, n_clusters = 20)
printClusters(labels)
# Out:
# Explained variance of the SVD step: 10%
# [3, 22, 44, 52, 100, 156, 157, 162, 168, 185]
# ['THE LIFE OF KING HENRY THE FIFTH ACT I. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT V. '
#  'THE TRAGEDY OF JULIUS CAESAR ACT II.'
#  'THE TRAGEDY OF HAMLET, PRINCE OF DENMARK ACT I. ' 'CYMBELINE ACT I. '
#  'CYMBELINE ACT V. ' 'AS YOU LIKE IT ACT IV.'
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT III'
#  'ALLS WELL THAT ENDS WELL ACT V S' 'KING JOHN ACT IV.']
#
#
# [1, 119, 134, 164]
# ['THE COMEDY OF ERRORS ACT V. ' 'THE LIFE OF TIMON OF ATHENS ACT I. '
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT I. ' 'KING RICHARD III ACT III']
#
#
# [26, 62, 66, 67, 69, 101, 149, 159]
# ['ALLS WELL THAT ENDS WELL ACT II.'
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT I. ' 'THE TEMPEST ACT III'
#  'KING RICHARD THE SECOND ACT II.' 'THE TRAGEDY OF MACBETH ACT V. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT III'
#  'THE TRAGEDY OF TITUS ANDRONICUS ACT 1. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.']
#
#
# [9, 17, 50, 75, 138, 141, 178]
# ['THE TRAGEDY OF TITUS ANDRONICUS ACT II.'
#  'THE TRAGEDY OF ROMEO AND JULIET ACT IV.'
#  'THE LIFE OF TIMON OF ATHENS ACT III'
#  'THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT III'
#  'KING RICHARD III ACT V. ' 'AS YOU LIKE IT ACT III' 'CYMBELINE ACT IV.']
#
#
# [18, 65, 77, 78, 92, 108, 136, 145, 154, 183, 189]
# ['AS YOU LIKE IT ACT I. ' 'THE THIRD PART OF KING HENRY THE SIXTH ACT III'
#  'ALLS WELL THAT ENDS WELL ACT IV.' 'THE MERRY WIVES OF WINDSOR ACT III'
#  'MUCH ADO ABOUT NOTHING ACT V. '
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT III'
#  "A MIDSUMMER NIGHT'S DREAM ACT III"]

# %%
# Features from n-grams
X = getSVD(X_tfidf, n_components = 6)
df_ngrams = pd.DataFrame(data=X, index = title)
df_ngrams.head()
# Out:
# Explained variance of the SVD step: 2%
#                                                        0         1         2  \
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.   0.044094  0.282588  0.085092
# THE COMEDY OF ERRORS ACT V.                     0.403495 -0.478777  0.211148
# CYMBELINE ACT II.                               0.576668  0.011030  0.277416
# THE LIFE OF KING HENRY THE FIFTH ACT I.         0.528361  0.337756 -0.207171
# THE MERRY WIVES OF WINDSOR ACT II.              0.247342  0.265415 -0.805882
#
#                                                        3         4         5
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.  -0.604066 -0.171877  0.718695
# THE COMEDY OF ERRORS ACT V.                     0.216520  0.586633  0.415165
# CYMBELINE ACT II.                              -0.415623  0.553151 -0.334146
# THE LIFE OF KING HENRY THE FIFTH ACT I.        -0.203890 -0.237694 -0.682470
# THE MERRY WIVES OF WINDSOR ACT II.              0.247963  0.049403 -0.393707

# %%
# Merge all features
df = df[['HapaxLegomena', 'DisLegomena', 'numberUniqueWords', 
        'averageSentenceLength', 'numberOfPronoun', 'numberOfConjunction']]
df_all = df.join(df_ngrams)
df_all.head()
# Out:
#                                                 HapaxLegomena  DisLegomena  \
# act
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.        0.112787     0.026571
# THE COMEDY OF ERRORS ACT V.                          0.101972     0.030214
# CYMBELINE ACT II.                                    0.130766     0.029124
# THE LIFE OF KING HENRY THE FIFTH ACT I.              0.164650     0.038578
# THE MERRY WIVES OF WINDSOR ACT II.                   0.091480     0.019582
#
#                                                 numberUniqueWords  \
# act
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.            0.177277
# THE COMEDY OF ERRORS ACT V.                              0.170373
# CYMBELINE ACT II.                                        0.195856
# THE LIFE OF KING HENRY THE FIFTH ACT I.                  0.240797
# THE MERRY WIVES OF WINDSOR ACT II.                       0.146573
#
#                                                 averageSentenceLength  \
# act
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.               56.971088
# THE COMEDY OF ERRORS ACT V.                                 55.916890
# CYMBELINE ACT II.                                           51.320879
# THE LIFE OF KING HENRY THE FIFTH ACT I.                    125.408805
# THE MERRY WIVES OF WINDSOR ACT II.                          45.526235
#
#                                                 numberOfPronoun  \
# act
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.          0.222945
# THE COMEDY OF ERRORS ACT V.                            0.202686
# CYMBELINE ACT II.                                      0.224199
# THE LIFE OF KING HENRY THE FIFTH ACT I.                0.183308
# THE MERRY WIVES OF WINDSOR ACT II.                     0.209265
#
#                                                 numberOfConjunction         0  \
# act
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.              0.134099  0.044094
# THE COMEDY OF ERRORS ACT V.                                0.120646  0.403495
# CYMBELINE ACT II.                                          0.124120  0.576668
# THE LIFE OF KING HENRY THE FIFTH ACT I.                    0.139687  0.528361
# THE MERRY WIVES OF WINDSOR ACT II.                         0.135321  0.247342
#
#                                                        1         2         3  \
# act
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.   0.282588  0.085092 -0.604066
# THE COMEDY OF ERRORS ACT V.                    -0.478777  0.211148  0.216520
# CYMBELINE ACT II.                               0.011030  0.277416 -0.415623
# THE LIFE OF KING HENRY THE FIFTH ACT I.         0.337756 -0.207171 -0.203890
# THE MERRY WIVES OF WINDSOR ACT II.              0.265415 -0.805882  0.247963
#
#                                                        4         5
# act
# THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I.  -0.171877  0.718695
# THE COMEDY OF ERRORS ACT V.                     0.586633  0.415165
# CYMBELINE ACT II.                               0.553151 -0.334146
# THE LIFE OF KING HENRY THE FIFTH ACT I.        -0.237694 -0.682470
# THE MERRY WIVES OF WINDSOR ACT II.              0.049403 -0.393707

# %%
# Cluster using all features
X = df_all.values
labels = clusterDocuments(X, n_clusters = 8)
printClusters(labels)
# Out:
# [0, 7, 11, 14, 22, 24, 25, 27, 32, 38, 40, 45, 55, 59, 63, 65, 72, 81, 82, 83, 89, 94, 108, 116, 120, 125, 127, 138, 150, 151, 155, 156, 159, 164, 169, 179, 185, 186]
# ['THE TRAGEDY OF OTHELLO, MOOR OF VENICE ACT I. '
#  'THE FIRST PART OF HENRY THE SIXTH ACT III'
#  'THE TAMING OF THE SHREW ACT1594' 'THE MERCHANT OF VENICE ACT II.'
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT V. ' 'AS YOU LIKE IT ACT II.'
#  "THE WINTER'S TALE ACT IV." 'THE TRAGEDY OF CORIOLANUS ACT V. '
#  'THE LIFE OF KING HENRY THE FIFTH ACT III' "THE WINTER'S TALE ACT I. "
#  'THE TEMPEST ACT IV.' 'THE FIRST PART OF KING HENRY THE FOURTH ACT IV.'
#  "A MIDSUMMER NIGHT'S DREAM ACT IV." 'ALLS WELL THAT ENDS WELL ACT I. '
#  'THE MERCHANT OF VENICE ACT IV.'
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT III'
#  'THE FIRST PART OF HENRY THE SIXTH ACT I. '
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT V. '
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT V. '
#  'THE THIRD PART OF KING HENRY THE SIXTH ACT IV.'
#  "A MIDSUMMER NIGHT'S DREAM ACT I. "
#  'THE SECOND PART OF KING HENRY THE SIXTH ACT V. '
#  'THE TRAGEDY OF ROMEO AND JULIET ACT1595'
#  'THE LIFE OF KING HENRY THE FIFTH ACT IV.'
#  'KING RICHARD THE SECOND ACT V. ' 'THE MERCHANT OF VENICE ACT V. '
#  'KING HENRY THE EIGHTH ACT III' 'KING RICHARD III ACT V. '
#  'THE HISTORY OF TROILUS AND CRESSIDA ACT III'
#  "A MIDSUMMER NIGHT'S DREAM ACT V. "
#  'THE FIRST PART OF HENRY THE SIXTH ACT V. ' 'CYMBELINE ACT V. '
#  'THE TRAGEDY OF ANTONY AND CLEOPATRA ACT IV.' 'KING RICHARD III ACT III'
