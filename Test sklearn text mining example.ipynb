# %%
categories = ['alt.atheism', 'soc.religion.christian',
...               'comp.graphics', 'sci.med']

from sklearn.datasets import fetch_20newsgroups
twenty_train = fetch_20newsgroups(subset='train',
...     categories=categories, shuffle=True, random_state=42)
# Out:
# /Users/byan/anaconda/lib/python3.4/site-packages/sklearn/datasets/twenty_newsgroups.py:89: DeprecationWarning: The 'warn' method is deprecated, use 'warning' instead
#   logger.warn("Downloading dataset from %s (14 MB)", URL)
# WARNING:sklearn.datasets.twenty_newsgroups:Downloading dataset from http://people.csail.mit.edu/jrennie/20Newsgroups/20news-bydate.tar.gz (14 MB)

# %%
print(twenty_train.data[0])
# Out:
# From: sd345@city.ac.uk (Michael Collier)
# Subject: Converting images to HP LaserJet III?
# Nntp-Posting-Host: hampton
# Organization: The City University
# Lines: 14
#
# Does anyone know of a good way (standard PC application/PD utility) to
# convert tif/img/tga files into LaserJet III format.  We would also like to
# do the same, converting to HPGL (HP plotter) files.
#
# Please email any response.
#
# Is this the correct group?
#
# Thanks in advance.  Michael.
# --
# Michael Collier (Programmer)                 The Computer Unit,
# Email: M.P.Collier@uk.ac.city                The City University,
# Tel: 071 477-8000 x3769                      London,
# Fax: 071 477-8565                            EC1V 0HB.

# %%
text = []
file = open("20.txt", "r")
text.append(file.read())
file.close()

file = open("21.txt", "r")
text.append(file.read())
file.close()

from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer(ngram_range=(1, 4))
X_train_counts = count_vect.fit_transform(text)
X_train_counts.shape
# Out:
# (2, 110168)

# %%
print(X_train_counts[:,1:10])
# Out:
#   (0, 3)	1
#   (0, 7)	6
#   (0, 4)	1
#   (0, 8)	6
#   (0, 5)	1
#   (0, 6)	1
#   (1, 7)	5
#   (1, 8)	5
#   (1, 0)	1
#   (1, 1)	1
#   (1, 2)	1

# %%
print(count_vect.vocabulary_)
# Out:
# {'in time have napkins': 42886, 'sir amen macduff stands': 77072, 'instance already he': 43308, 'their untaught': 88613, 'sir whom detest': 77430, 'blaspheme the good': 11750, 'servant how now who': 75139, 'and tender fork': 4659, 'can be no better': 14805, 'you isabella': 107969, 'now the future in': 62393, 'bloody instructions': 12009, 'comforts are most good': 17048, 'of direst cruelty make': 62917, 'deign him': 19739, 'to let him suffer': 94453, 'be hanged that': 9597, 'gins': 31361, 'mad st duke': 52724, 'him he will discredit': 38453, 'as birds': 7124, 'which she yet': 102521, 'and the grim': 4726, 'to have had so': 94151, 'of my chaste': 63502, 'hand your tongue': 33790, 'greet us here': 33050, 'the bat': 84728, 'shalt be what': 75911, 'my fit again had': 58336, 'done so by claudio': 22071, 're enter seyton wherefore': 71454, 'that ever yet': 83496, 'the terms for': 87510, 'husband he is': 41113, 'the name of belzebub': 86517, 'purpose what our seemers': 70863, 'the grave and': 85792, 'summer seeming lust and':